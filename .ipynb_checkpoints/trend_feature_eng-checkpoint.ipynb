# %% [markdown]
# # Double Tap with Trend Analysis Feature Engineering

# %% [markdown]
# In this notebook we have reviewed our original double tap hypothesis based on some findings from double tap signals with various stochastic values. We note that the probability of a double tap win is impacted by the 30minute and 4hr trend and the stochastic value and in some case the stochastic can strongly infer a reversal whereby we could make a trade in the opposite direction to the original hypothesis.
#
# This new hypothesis states that: when a 30min candle closes in the opposite direction to the previous candle and both the 30minute and 4hr trend we are given a trade signal on the following stochastic condition.
#
# buy signal if signal candle buy and stoch(r) below 20.
# sell signal if signal candle buy and stoch(r) above 40.
# buy signal if signal candle sell and stoch (r) below 70.

# %% [markdown]
# OUr first job will be to engineer the required features including the following: \
# (see features.txt for tech information)
# **thirty_trend** - the thirty minute trend \
# **four_trend** - the four hour trend \
# **dt_signal** - the basic double tap signal \
# **sent_signal** - the sentiment confirmation \
# **stoch_r** - %D slow moving average stochastic measure (red) \
# **stoch_b** - %K fast moving average stochastic measure (blue) \
# **rsi** - relative strength index \
# **Plot** - 30minute sentiment strength imported from trading view
# **candle_dir** - the closing direction of candle
# **simple_result** - the win / loss outcome of trade based on next candle only \
# **running_result** - the win / loss outcome of trade based on multiple subsequent candles (with sig_stop) \
# **no_sig_result** - the win / loss outcome of trade based on multiple subsequent candles (without sig stops) \
# **cur_sig_result** - the win / loss outcome of trade based on multiple subsequent candles (curated sig stops) \
# **outcome** - the value of the trade following signal

# %%
#Import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#set pandas to show all columns
pd.set_option("display.max_columns", None)

# %%
# !ls
# Out:
# Double_Tap_Feature_Engineering.ipynb gj_4base.csv
# Forex_Data_Analysis.ipynb            gj_4hour_trend.csv
# Forex_Models.ipynb                   gj_4hr.csv
# README.md                            gj_cleandraft.csv
# forex.html                           gj_dt_4hrtrend.csv
# gj30m_sentinc.csv                    gj_dt_trend.csv
# gj4h_sentinc.csv                     gj_thirty_trend.csv
# gj_30_RSI_exp.csv                    gpbjpy_dataframe_gen.ipynb
# gj_30base.csv                        trend_feature_eng.ipynb
# gj_30minsupres.csv

# %%
#Read in our 30minute data
thirty = pd.read_csv("gj_thirty_trend.csv")
thirty.head()
# Out:
#                   time     open     high      low    close         %K  \
# 0  2019-01-06 22:00:00  138.091  138.179  138.011  138.020  81.448525
# 1  2019-01-06 22:30:00  138.020  138.084  137.922  138.074  77.059060
# 2  2019-01-06 23:00:00  138.074  138.302  137.935  138.273  80.000922
# 3  2019-01-06 23:30:00  138.273  138.334  138.168  138.210  81.073987
# 4  2019-01-07 00:00:00  138.210  138.254  138.099  138.228  82.464591
#
#           %D        RSI      Plot
# 0  86.245303  65.524837  0.070389
# 1  82.185586  66.849987  0.061890
# 2  79.502836  71.237596  0.058952
# 3  79.377990  68.161801  0.053267
# 4  81.179833  68.579229  0.047715

# %%
#Read in our 4hour data
four = pd.read_csv("gj_4hour_trend.csv")
four.head()
# Out:
#                   time     open     high      low    close      Plot
# 0  2019-01-06 22:00:00  138.091  138.334  137.922  138.090  0.005608
# 1  2019-01-07 02:00:00  138.090  138.105  137.724  137.932  0.037854
# 2  2019-01-07 06:00:00  137.932  138.102  137.616  137.956  0.065115
# 3  2019-01-07 10:00:00  137.956  138.382  137.796  138.322  0.097300
# 4  2019-01-07 14:00:00  138.322  138.774  138.168  138.738  0.134107

# %% [markdown]
# ## FEATURE ENGINEERING 1.0
#
# ## Create the 30 minute trend feature

# %% [markdown]
# ### Rules
# * if previous candle,to signal candle, has a close higher than previous 4 candle average, then trend is long
# * if previous candle, to signal candle, has a close lower than previous 4 candle average, then trend is short

# %%
#set a a global counter to iterate from within the function
x = 0

def trend_thirty(row):
    global x
    
    open_ = row[1]
    high = row[2]
    low = row[3]
    close = row[4]
    
    a = thirty['close']
    
    #we return unknown for the first 5 rows as we don't have access to enough prior data
    if x < 6:
        x+=1
        return "unknown"
    
    #set a variable to store the average values of previous 4 candles
    close_list = []
    
    #iterate through our four candles and add each closing price to the close list
    for i in a.loc[x-5:x-1]:
        close_list.append(i)
    
    #store the avearge close value in a variable
    ave_close = sum(close_list)/len(close_list)
    
    
    #execute our rules via a conditional statement and return the required trend directions 
    #ensure to iterate the x value for each return statement
    if a.loc[x-1] > ave_close:
        x+=1
        return "bullish"
    elif a.loc[x-1] < ave_close:
        x+=1
        return "bearish"
    else:
        x+=1
        return "flat"

# %%
#create a data frame column from the function
thirty_min = thirty.apply(trend_thirty, axis='columns').to_frame()
#join this new column to our existing thirty dataframe
thirty = thirty.join(thirty_min)
#rename the column to the required feature header
thirty.rename(columns={0: 'thirty_trend'}, inplace=True)
#View the head of our new dataframe
thirty.head(3)
# Out:
#                   time     open     high      low    close         %K  \
# 0  2019-01-06 22:00:00  138.091  138.179  138.011  138.020  81.448525
# 1  2019-01-06 22:30:00  138.020  138.084  137.922  138.074  77.059060
# 2  2019-01-06 23:00:00  138.074  138.302  137.935  138.273  80.000922
#
#           %D        RSI      Plot thirty_trend
# 0  86.245303  65.524837  0.070389      unknown
# 1  82.185586  66.849987  0.061890      unknown
# 2  79.502836  71.237596  0.058952      unknown

# %%
thirty.thirty_trend.value_counts()
# Out:
# bullish    10042
# bearish     9997
# flat          17
# unknown        6
# Name: thirty_trend, dtype: int64

# %%
#undrtake some manual checks to ensure the function has created the correct feature
thirty.iloc[712:720]
# Out:
#                     time     open     high      low    close         %K  \
# 712  2019-01-25 18:00:00  144.632  144.774  144.574  144.748  97.003553
# 713  2019-01-25 18:30:00  144.748  144.797  144.664  144.783  96.764351
# 714  2019-01-25 19:00:00  144.783  144.846  144.592  144.601  91.214069
# 715  2019-01-25 19:30:00  144.601  144.708  144.596  144.696  87.368027
# 716  2019-01-25 20:00:00  144.696  144.732  144.659  144.668  82.298424
# 717  2019-01-25 20:30:00  144.668  144.742  144.638  144.704  85.480383
# 718  2019-01-25 21:00:00  144.704  144.748  144.494  144.524  79.591428
# 719  2019-01-25 21:30:00  144.524  144.600  144.486  144.582  76.462895
#
#             %D        RSI      Plot thirty_trend
# 712  93.965013  74.506980  0.043301      bullish
# 713  95.927452  75.125996  0.049478      bullish
# 714  94.993991  66.133318  0.048079      bullish
# 715  91.782149  68.268460  0.048301      bearish
# 716  86.960173  66.929127  0.046433      bullish
# 717  85.048945  67.803715  0.044687      bearish
# 718  82.456745  59.351951  0.037203      bullish
# 719  80.511569  61.037275  0.031813      bearish

# %% [markdown]
# Now we have created the thirty minute trend feature we need to do the same for the 4 hour timeframe.

# %% [markdown]
# # Create the 4 hour trend feature

# %% [markdown]
# ### Rules
# * If the close of previous, to signal candle, is lower than the close of previous 1 candle and both candle closes are lower than their opens, then trend is bearish.
# * If the close of previous, to signal candle, is lower than the close of previous 1 candle and both candle closes are high than their opens, then trend is bullish.

# %%
#Set a global counter to iterate from within the function
x = 0

def trend_four(row):
    global x #make our x variable accessible for updating within this function
    
    close = four['close']
    open_ = four['open']
    
    #We return unknown for the first few rows as we don't have the historical data
    if x < 4:
        x+=1
        return "unknown"
    
    if close.loc[x-1] < close.loc[x-2] and close.loc[x-1] < open_.loc[x-1] and close.loc[x-2] < open_.loc[x-2]:
        x+=1
        return "bearish"
    elif close.loc[x-1] > close.loc[x-2] and close.loc[x-1] > open_.loc[x-1] and close.loc[x-2] > open_.loc[x-2]:
        x+=1
        return "bullish"
    elif close.loc[x-3] < open_.loc[x-3] and close.loc[x-2] < open_.loc[x-2] and close.loc[x-1] < open_.loc[x-2]:
        x+=1
        return "bearish"
    elif close.loc[x-3] > open_.loc[x-3] and close.loc[x-2] > open_.loc[x-2] and close.loc[x-1] > open_.loc[x-2]:
        x+=1
        return "bullish"
    else:
        x+=1
        return "flat"

# %%
#create a data frame column from the function
four_hour = four.apply(trend_four, axis='columns').to_frame()
#join this new column to our existing thirty dataframe
four = four.join(four_hour)
#rename the column to the required feature header
four.rename(columns={0: 'four_trend'}, inplace=True)
#View the head of our new dataframe
four.head(3)
# Out:
#                   time     open     high      low    close      Plot  \
# 0  2019-01-06 22:00:00  138.091  138.334  137.922  138.090  0.005608
# 1  2019-01-07 02:00:00  138.090  138.105  137.724  137.932  0.037854
# 2  2019-01-07 06:00:00  137.932  138.102  137.616  137.956  0.065115
#
#   four_trend
# 0    unknown
# 1    unknown
# 2    unknown

# %%
four.tail(6)
# Out:
#                      time     open     high      low    close      Plot  \
# 2502  2020-08-13 21:00:00  139.734  139.894  139.602  139.692  0.021159
# 2503  2020-08-14 01:00:00  139.692  139.728  139.560  139.573  0.014485
# 2504  2020-08-14 05:00:00  139.573  139.684  139.346  139.570  0.007972
# 2505  2020-08-14 09:00:00  139.570  140.019  139.368  139.887  0.010346
# 2506  2020-08-14 13:00:00  139.887  140.008  139.420  139.488  0.000200
# 2507  2020-08-14 17:00:00  139.488  139.574  139.435  139.498 -0.008434
#
#      four_trend
# 2502    bearish
# 2503    bearish
# 2504    bearish
# 2505    bearish
# 2506       flat
# 2507       flat

# %%
four.four_trend.value_counts()
# Out:
# flat       955
# bearish    789
# bullish    760
# unknown      4
# Name: four_trend, dtype: int64

# %% [markdown]
# Ok so weve created the four hour sentiment based on our rules and now need to merge this information with the thirty minute dataframe.

# %%
#first let's drop out all columns that are no longer required
four.drop(columns=['open', 'high', 'low', 'close'], inplace=True)

# %%
#We've decided to keep our sentiment plot from the import but this should be renamed to avoid confusion with 30min df
four.rename(columns={'Plot': '4h_plot'}, inplace=True)

# %%
four.head(2)
# Out:
#                   time   4h_plot four_trend
# 0  2019-01-06 22:00:00  0.005608    unknown
# 1  2019-01-07 02:00:00  0.037854    unknown

# %%
thirty.shape
# Out:
# (20062, 10)

# %%
four.shape
# Out:
# (2508, 3)

# %%
#Let's merge the dataframe
thirty = thirty.merge(four, how='left', left_on='time', right_on='time')

# %%
#quick review to see what we've produced. 
#As expected there are a lot of NAN values where 4hr and 30min times don't match up
thirty.loc[800:810]
# Out:
#                     time     open     high      low    close         %K  \
# 800  2019-01-29 14:00:00  144.420  144.468  144.136  144.276  91.040665
# 801  2019-01-29 14:30:00  144.276  144.310  144.101  144.198  81.609689
# 802  2019-01-29 15:00:00  144.198  144.228  144.078  144.200  72.357057
# 803  2019-01-29 15:30:00  144.200  144.206  143.668  143.748  48.806872
# 804  2019-01-29 16:00:00  143.748  143.804  143.464  143.742  34.287327
# 805  2019-01-29 16:30:00  143.742  143.864  143.690  143.762  22.002033
# 806  2019-01-29 17:00:00  143.762  143.928  143.585  143.647  24.707031
# 807  2019-01-29 17:30:00  143.647  143.886  143.592  143.692  23.079427
# 808  2019-01-29 18:00:00  143.692  143.774  143.665  143.743  22.460937
# 809  2019-01-29 18:30:00  143.743  143.836  143.702  143.817  27.994792
# 810  2019-01-29 19:00:00  143.817  144.049  143.762  143.920  35.416667
#
#             %D        RSI      Plot thirty_trend   4h_plot four_trend
# 800  91.235416  60.493056  0.052170      bullish -0.024930    bullish
# 801  88.287334  57.521927  0.050740      bullish       NaN        NaN
# 802  81.669137  57.579459  0.048893      bearish       NaN        NaN
# 803  67.591206  43.304528  0.034448      bearish       NaN        NaN
# 804  51.817085  43.151595  0.022512      bearish       NaN        NaN
# 805  35.032077  43.863264  0.013413      bearish       NaN        NaN
# 806  26.998797  40.707620  0.003006      bearish       NaN        NaN
# 807  23.262830  42.452295 -0.003919      bearish       NaN        NaN
# 808  23.415799  44.447385 -0.007866      bearish -0.062017       flat
# 809  24.511719  47.302169 -0.008812      bullish       NaN        NaN
# 810  28.624132  51.071151 -0.006623      bullish       NaN        NaN

# %%
#Now we fill the NaN values by filling the values forward as the 4hr trend is constant for all the 30mins within 
#that four hour period
thirty['four_trend'] = thirty[["four_trend"]].fillna(method='ffill')

# %%
#We also need to fill the 4h_plot as they have the same Nan issue
thirty['4h_plot'] = thirty[['4h_plot']].fillna(method='ffill')

# %%
# thirty.loc[805:818]
#Looks good
thirty.loc[100:105]
# Out:
#                     time     open     high      low    close         %K  \
# 100  2019-01-09 00:00:00  138.542  138.639  138.464  138.540  92.431191
# 101  2019-01-09 00:30:00  138.540  138.604  138.402  138.478  83.500852
# 102  2019-01-09 01:00:00  138.478  138.606  138.448  138.595  83.205107
# 103  2019-01-09 01:30:00  138.595  138.626  138.515  138.576  84.935357
# 104  2019-01-09 02:00:00  138.576  138.747  138.570  138.692  91.084541
# 105  2019-01-09 02:30:00  138.692  138.865  138.648  138.708  86.418232
#
#             %D        RSI      Plot thirty_trend   4h_plot four_trend
# 100  89.940745  55.330865 -0.016851      bullish  0.198966    bearish
# 101  88.759148  52.003431 -0.012456      bullish  0.198966    bearish
# 102  86.379050  57.230465 -0.005631      bearish  0.198966    bearish
# 103  83.880439  56.160841 -0.000707      bullish  0.198966    bearish
# 104  86.408335  60.958403  0.006314      bullish  0.200412    bullish
# 105  87.479377  61.582899  0.012141      bullish  0.200412    bullish

# %% [markdown]
# Ok so we have now included our multi time frame trend directions to the dataframe. Next up we'll include our basic double tap feature which basically identifies when a 30minute candle has closed in teh opposite direction to the previous thrity minute candle.

# %% [markdown]
# ## Create the thirty minute double tap feature

# %% [markdown]
# ### Rules
# * if a 30min candle closes bullish and the previous candle closed bearish, then we have a bullish signal
# * if a 30min candle closes bearish and the previous candle closed bullish, then we a have a bearish signal
# * else we do not have a basic trade signal

# %%
#first we need to set a direction for our signal candle
def direction(row):
    open_ = row[1]
    close_ = row[4]
    
    if open_ < close_:
        return  'long'
    elif open_ > close_:
        return 'short'
    else:
        return 'neutral'

# %%
can_dir = thirty.apply(direction, axis='columns').to_frame()
thirty = thirty.join(can_dir)
thirty.rename(columns={0: 'candle_dir'}, inplace=True)

# %%
thirty.head()
# Out:
#                   time     open     high      low    close         %K  \
# 0  2019-01-06 22:00:00  138.091  138.179  138.011  138.020  81.448525
# 1  2019-01-06 22:30:00  138.020  138.084  137.922  138.074  77.059060
# 2  2019-01-06 23:00:00  138.074  138.302  137.935  138.273  80.000922
# 3  2019-01-06 23:30:00  138.273  138.334  138.168  138.210  81.073987
# 4  2019-01-07 00:00:00  138.210  138.254  138.099  138.228  82.464591
#
#           %D        RSI      Plot thirty_trend   4h_plot four_trend candle_dir
# 0  86.245303  65.524837  0.070389      unknown  0.005608    unknown      short
# 1  82.185586  66.849987  0.061890      unknown  0.005608    unknown       long
# 2  79.502836  71.237596  0.058952      unknown  0.005608    unknown       long
# 3  79.377990  68.161801  0.053267      unknown  0.005608    unknown      short
# 4  81.179833  68.579229  0.047715      unknown  0.005608    unknown       long

# %%
thirty.candle_dir.value_counts()
# Out:
# long       9984
# short      9935
# neutral     143
# Name: candle_dir, dtype: int64

# %%
#Now we need to check if the candle has closed in the opposite direction to the previous candle hence 
#creating a partial signal
x = 0

def dt_signal(row):
    global x
    
    direction = thirty['candle_dir']
    
    if x == 0:
        x+=1
        return "unknown"
    
    #let's check if we get a double tap confirmation
    if direction.loc[x] == direction.loc[x-1] or direction.loc[x] == 'neutral':
        x += 1
        return "no_trade"
    elif direction.loc[x] == "neutral":
        x += 1
        return "no_trade"
    elif direction.loc[x] == "short":
        x+=1
        return "short"
    else:
        x+=1
        return "long"

# %%
double_tap = thirty.apply(dt_signal, axis='columns').to_frame()
thirty = thirty.join(double_tap)
thirty.rename(columns={0: 'dt_signal'}, inplace=True)

# %%
thirty.head(300)
# Out:
#                     time     open     high      low    close         %K  \
# 0    2019-01-06 22:00:00  138.091  138.179  138.011  138.020  81.448525
# 1    2019-01-06 22:30:00  138.020  138.084  137.922  138.074  77.059060
# 2    2019-01-06 23:00:00  138.074  138.302  137.935  138.273  80.000922
# 3    2019-01-06 23:30:00  138.273  138.334  138.168  138.210  81.073987
# 4    2019-01-07 00:00:00  138.210  138.254  138.099  138.228  82.464591
# ..                   ...      ...      ...      ...      ...        ...
# 295  2019-01-15 01:30:00  139.875  140.053  139.806  139.830  88.205524
# 296  2019-01-15 02:00:00  139.830  139.944  139.794  139.813  83.432074
# 297  2019-01-15 02:30:00  139.813  139.894  139.794  139.865  78.102926
# 298  2019-01-15 03:00:00  139.865  140.060  139.865  139.981  82.965157
# 299  2019-01-15 03:30:00  139.981  140.038  139.943  140.036  90.236207
#
#             %D        RSI      Plot thirty_trend   4h_plot four_trend  \
# 0    86.245303  65.524837  0.070389      unknown  0.005608    unknown
# 1    82.185586  66.849987  0.061890      unknown  0.005608    unknown
# 2    79.502836  71.237596  0.058952      unknown  0.005608    unknown
# 3    79.377990  68.161801  0.053267      unknown  0.005608    unknown
# 4    81.179833  68.579229  0.047715      unknown  0.005608    unknown
# ..         ...        ...       ...          ...       ...        ...
# 295  89.265853  68.267261  0.029658      bullish  0.156551    bullish
# 296  89.114654  67.416881  0.034282      bullish  0.181083       flat
# 297  83.246842  68.701184  0.038472      bullish  0.181083       flat
# 298  81.500052  71.408571  0.043977      bullish  0.181083       flat
# 299  83.768097  72.617991  0.048748      bullish  0.181083       flat
#
#     candle_dir dt_signal
# 0        short   unknown
# 1         long      long
# 2         long  no_trade
# 3        short     short
# 4         long      long
# ..         ...       ...
# 295      short     short
# 296      short  no_trade
# 297       long      long
# 298       long  no_trade
# 299       long  no_trade
#
# [300 rows x 14 columns]

# %%
thirty.dt_signal.value_counts()
# Out:
# no_trade    9474
# short       5296
# long        5291
# unknown        1
# Name: dt_signal, dtype: int64

# %% [markdown]
# Ok, so we've added our basic signal feature that shows where we have a change of direction in the 30minute timeframe. Next we need to show if the direction of this signal candle is at odds to the multi time frame trends.

# %% [markdown]
# ## Create the Sentiment Signal Feature

# %% [markdown]
# ### Rules
#
# * If the dt_signal is closing in the opposite direction to both 30minute and 4hour trends then the sentiment signal equals trade, else no trade.

# %%
def sentiment_signal(row):
    
    thirty = row[9]
    four = row[11]
    sig = row[13]
    
    if sig == "short" and thirty == "bullish" and four == "bullish":
        return "short_trade"
    elif sig == "long" and thirty == "bearish" and four == "bearish":
        return 'long_trade'
    else:
        return "no_trade"

# %%
sentiment = thirty.apply(sentiment_signal, axis='columns').to_frame()
thirty = thirty.join(sentiment)
thirty.rename(columns={0: 'sent_signal'}, inplace=True)

# %%
thirty.head()
# Out:
#                   time     open     high      low    close         %K  \
# 0  2019-01-06 22:00:00  138.091  138.179  138.011  138.020  81.448525
# 1  2019-01-06 22:30:00  138.020  138.084  137.922  138.074  77.059060
# 2  2019-01-06 23:00:00  138.074  138.302  137.935  138.273  80.000922
# 3  2019-01-06 23:30:00  138.273  138.334  138.168  138.210  81.073987
# 4  2019-01-07 00:00:00  138.210  138.254  138.099  138.228  82.464591
#
#           %D        RSI      Plot thirty_trend   4h_plot four_trend  \
# 0  86.245303  65.524837  0.070389      unknown  0.005608    unknown
# 1  82.185586  66.849987  0.061890      unknown  0.005608    unknown
# 2  79.502836  71.237596  0.058952      unknown  0.005608    unknown
# 3  79.377990  68.161801  0.053267      unknown  0.005608    unknown
# 4  81.179833  68.579229  0.047715      unknown  0.005608    unknown
#
#   candle_dir dt_signal sent_signal
# 0      short   unknown    no_trade
# 1       long      long    no_trade
# 2       long  no_trade    no_trade
# 3      short     short    no_trade
# 4       long      long    no_trade

# %%
thirty.sent_signal.value_counts()
# Out:
# no_trade       17489
# long_trade      1325
# short_trade     1248
# Name: sent_signal, dtype: int64

# %% [markdown]
# In eighteen months we have 1325 long and 1248 short sentiment signals which is 2573. That's approx 146 per month and around 30 per week. On that count there are plenty of trade opportunities. What we need to do know is figure out how many of these trade opportunities resulted in wins and how many in losses.

# %% [markdown]
# ## Create the Simple Win / Loss Feature

# %% [markdown]
# ### Rules
# * if a trade reaches a 9 pip advance on the next candle without the stop loss being broken (opposite end of signal candle) then the trade is a win.
# * If a trade reaches the stop loss then the trade is a loss
# * If a the next candle closes in the opposite direction to our signal candle then sig_stop
# * else trade remains oprn and running

# %%
#Set the global variable
x=0

def win_or_loss(row):
    global x
    
    high = thirty['high']
    low = thirty['low']
    signal = thirty['sent_signal']
    close = thirty['close']
    open_ = thirty['open']
    
    #create a variable to hold whether we want a long trade or a short trade
    long_short = ''
    
    #Now check what trade we've been signalled and save it to the variable, unless no signal in which case return NA
    if signal.loc[x] == "short_trade":
        long_short = "short"
    elif signal.loc[x] == "long_trade":
        long_short = "long"
    else: 
        x+=1
        return "no_trade"
    
    #First will state whether a short trade is succesful or not
#     for i, j in enumerate(high[x:x+1]):
    if long_short == "short":
        if high[x+1] > high[x]+0.02:
            x+=1
            return "loss"
        elif low[x+1] < close[x]-0.09:
            x+=1
            return "win"
        elif close[x+1] > open_[x+1]:
            x+=1
            return 'sig_stop'
        else:
            x+=1
            return "running_short"
                
    #Now we'll state whether a long trade is successful or not
#     for i, j in enumerate(low[x:x+1]):
    if long_short == "long":
        if low[x+1] < low[x]-0.02:
            x+=1
            return "loss"
        elif high[x+1] > close[x]+0.09:
            x+=1
            return "win"
        elif close[x+1] < open_[x+1]:
            x+=1
            return 'sig_stop'
        else:
            x+=1
            return "running_long"

# %%
result = thirty.apply(win_or_loss, axis='columns').to_frame()
thirty = thirty.join(result)
thirty.rename(columns={0: 'simple_result'}, inplace=True)

# %%
thirty.loc[800:820]
# Out:
#                     time     open     high      low    close         %K  \
# 800  2019-01-29 14:00:00  144.420  144.468  144.136  144.276  91.040665
# 801  2019-01-29 14:30:00  144.276  144.310  144.101  144.198  81.609689
# 802  2019-01-29 15:00:00  144.198  144.228  144.078  144.200  72.357057
# 803  2019-01-29 15:30:00  144.200  144.206  143.668  143.748  48.806872
# 804  2019-01-29 16:00:00  143.748  143.804  143.464  143.742  34.287327
# 805  2019-01-29 16:30:00  143.742  143.864  143.690  143.762  22.002033
# 806  2019-01-29 17:00:00  143.762  143.928  143.585  143.647  24.707031
# 807  2019-01-29 17:30:00  143.647  143.886  143.592  143.692  23.079427
# 808  2019-01-29 18:00:00  143.692  143.774  143.665  143.743  22.460937
# 809  2019-01-29 18:30:00  143.743  143.836  143.702  143.817  27.994792
# 810  2019-01-29 19:00:00  143.817  144.049  143.762  143.920  35.416667
# 811  2019-01-29 19:30:00  143.920  143.976  143.093  143.138  27.409904
# 812  2019-01-29 20:00:00  143.138  143.200  142.776  143.121  22.636309
# 813  2019-01-29 20:30:00  143.121  143.374  142.740  142.991  12.634380
# 814  2019-01-29 21:00:00  142.991  143.072  142.820  142.898  14.913675
# 815  2019-01-29 21:30:00  142.898  143.000  142.836  142.944  12.766278
# 816  2019-01-29 22:00:00  142.944  142.972  142.814  142.840  10.198218
# 817  2019-01-29 22:30:00  142.840  143.042  142.840  143.032  14.279355
# 818  2019-01-29 23:00:00  143.032  143.176  143.027  143.175  20.786620
# 819  2019-01-29 23:30:00  143.175  143.178  142.943  143.130  28.444105
# 820  2019-01-30 00:00:00  143.130  143.148  143.048  143.082  29.717341
#
#             %D        RSI      Plot thirty_trend   4h_plot four_trend  \
# 800  91.235416  60.493056  0.052170      bullish -0.024930    bullish
# 801  88.287334  57.521927  0.050740      bullish -0.024930    bullish
# 802  81.669137  57.579459  0.048893      bearish -0.024930    bullish
# 803  67.591206  43.304528  0.034448      bearish -0.024930    bullish
# 804  51.817085  43.151595  0.022512      bearish -0.024930    bullish
# 805  35.032077  43.863264  0.013413      bearish -0.024930    bullish
# 806  26.998797  40.707620  0.003006      bearish -0.024930    bullish
# 807  23.262830  42.452295 -0.003919      bearish -0.024930    bullish
# 808  23.415799  44.447385 -0.007866      bearish -0.062017       flat
# 809  24.511719  47.302169 -0.008812      bullish -0.062017       flat
# 810  28.624132  51.071151 -0.006623      bullish -0.062017       flat
# 811  30.273788  32.226211 -0.025988      bullish -0.062017       flat
# 812  28.487626  31.950204 -0.041061      bearish -0.062017       flat
# 813  20.893531  29.845150 -0.055602      bearish -0.062017       flat
# 814  16.728121  28.403418 -0.068475      bearish -0.062017       flat
# 815  13.438111  30.199511 -0.076059      bearish -0.062017       flat
# 816  12.626057  28.461116 -0.083447      bearish -0.088021    bearish
# 817  12.414617  35.807680 -0.082525      bearish -0.088021    bearish
# 818  15.088064  40.692736 -0.076462      bullish -0.088021    bearish
# 819  21.170027  39.669664 -0.071566      bullish -0.088021    bearish
# 820  26.316022  38.556149 -0.067713      bullish -0.088021    bearish
#
#     candle_dir dt_signal  sent_signal simple_result
# 800      short     short  short_trade           win
# 801      short  no_trade     no_trade      no_trade
# 802       long      long     no_trade      no_trade
# 803      short     short     no_trade      no_trade
# 804      short  no_trade     no_trade      no_trade
# 805       long      long     no_trade      no_trade
# 806      short     short     no_trade      no_trade
# 807       long      long     no_trade      no_trade
# 808       long  no_trade     no_trade      no_trade
# 809       long  no_trade     no_trade      no_trade
# 810       long  no_trade     no_trade      no_trade
# 811      short     short     no_trade      no_trade
# 812      short  no_trade     no_trade      no_trade
# 813      short  no_trade     no_trade      no_trade
# 814      short  no_trade     no_trade      no_trade
# 815       long      long     no_trade      no_trade
# 816      short     short     no_trade      no_trade
# 817       long      long   long_trade           win
# 818       long  no_trade     no_trade      no_trade
# 819      short     short     no_trade      no_trade
# 820      short  no_trade     no_trade      no_trade

# %%
thirty.simple_result.value_counts()
# Out:
# no_trade         17489
# win                793
# sig_stop           693
# loss               530
# running_long       290
# running_short      267
# Name: simple_result, dtype: int64

# %%
#let's quickly check what our win/loss class is made up of
thirty.loc[thirty["simple_result"]=='loss'].sent_signal.value_counts()
# Out:
# long_trade     272
# short_trade    258
# Name: sent_signal, dtype: int64

# %%
# thirty.drop(columns=['simple_result'], inplace=True)

# %% [markdown]
# So we've create a simple result feature which states whether we achieve a 9 pip gain or a stop out in the very next candle. This is great as this win signifies our TP1 where we'd have a partial close to secure profits. At this stage we'd move our stops to break even to ensure we eliminate further risk.
#
# What we want to create next is a strategy for the incomplete trades labelled running - short/long. For this we'll need to review the next few candles to see if there is a new signal, a stop out or a win!

# %% [markdown]
# ## Create the Running Win / Loss Feature

# %% [markdown]
# ### Rules
# * if the simple win / loss is win and if we can secure another 10 pips over next 4 candles before our break even tapped: then win,  else we remain at win
# * if the simple win / loss is running_long or running_short and we can secure 10 pips over the next 4 candles before our break even is tapped and there is no change in signal direction: then win, else if we're stopped then loss, else if we're stopped by a signal change then "sig_stop", else remain as a runner.
#
# *We imagine that this approach will reduce the runners although we may end up with considerable signal stops. We have yet to fully realise how to approach new signals if the trade has not reached TP1. For now let's see what our final numbers look like before choosing an approach*

# %%
x=0

def running_result(row):
    global x
    
    #We'll add a print report to show the progress we're making mid function execute
    if x%50 == 0: 
        print("processing row {}".format(x))
    
    #First we store our features in variables for use when iterating
    simple = thirty['simple_result']
    open_ = thirty['open']
    high = thirty['high']
    low = thirty['low']
    close = thirty['close']
    signal = thirty['sent_signal']
    
    #Create a variable to store whether the current trade is long, short or no trade
    long_short = ''
    
    if signal.loc[x] == "short_trade":
        long_short = "short"
    elif signal.loc[x] == "long_trade":
        long_short = "long"
    else: 
        x+=1
        return "no_trade"
    
    #set counters 
    short_count = 0
    long_count = 0
    
    #set an empty list to store our individual candle outcomes
    can_list = []
    
    #First we check the first part of our rules... what do our wins convert to?
    for i, (j, k, l, m) in enumerate(zip(open_[x+2:], high[x+2:], low[x+2:], close[x+2:])):
        
        
        if len(can_list) < 4 and long_short == 'short' and simple[x] == 'win':
            if high[x] < k:
                can_list.append('loss')
                    
            elif close[x] - l > 0.10:
                can_list.append('win')
                    
            else:
                can_list.append('runner')
                    
                    
        elif len(can_list) < 4 and long_short == 'long' and simple[x] == 'win':
            if low[x] > l:
                can_list.append('loss')
                    
            elif k - close[x] > 0.10:
                can_list.append('win')
                    
            else:
                can_list.append('runner')
        
        elif simple[x] == 'loss':
            x+=1
            return 'no_runner'
        
        elif simple[x] == 'sig_stop':
            x+=1
            return 'no_runner'
        
        
                    
                    
    #Next we create a new loop to check the runners to see what they convert to
    for i, (j, k, l, m, n) in enumerate(zip(open_[x+2:], high[x+2:], low[x+2:], close[x+2:], simple[x+2:])):
        
        if len(can_list) < 4 and long_short == 'short' and simple[x] == 'running_short':
            if high[x] < k:
                can_list.append('loss')
                    
            elif close[x] - l > 0.10:
                can_list.append('win')
                
            #if the candle closes in opposite direction to trade, then we get a new signal and close trade
            elif m > j: #close greater than open meaning a bull candle formed
                can_list.append('sig_stop')
                    
            else:
                can_list.append('runner')
                    
        elif len(can_list) < 4 and long_short == 'long' and simple[x] == 'running_long':
            if low[x] > l:
                can_list.append('loss')
                    
            elif k - close[x] > 0.10:
                can_list.append('win')
                    
            elif m < j:
                can_list.append('sig_stop')
                    
            else:
                can_list.append('runner') 
                
    
    #Now we check what order the results are sent to our can list. If we get a loss first then the trade will lose
    # if get a win first then the trade has made a win, if we get a sig_stop first then we've been stopped by a new
    #signal. Else if none of these things happen our trade remains as a runner
    
    if len(can_list)==4: #If our container has stored the next 3 candle outcomes, proceed. 
        if can_list[0] == 'loss':
            x+=1 #increment x by one
            return 'loss' #and return the trade outcome
        elif can_list[0] == 'win':
            x+=1
            return 'win'
        elif can_list[0] == 'sig_stop':
            x+=1
            return 'sig_stop'
        elif can_list[0] == 'runner' and can_list[1] == 'loss':
            x+=1
            return 'loss'
        elif can_list[0] == 'runner' and can_list[1] == 'win':
            x+=1
            return 'win'
        elif can_list[0] == 'runner' and can_list[1] == 'sig_stop':
            x+=1
            return 'sig_stop'
        elif can_list[1] == 'runner' and can_list[2] == 'loss':
            x+=1
            return 'loss'
        elif can_list[1] == 'runner' and can_list[2] == 'win':
            x+=1
            return 'win'
        elif can_list[1] == 'runner' and can_list[2] == 'sig_stop':
            x+=1
            return 'sig_stop'
        elif can_list[2] == 'runner' and can_list[3] =='loss':
            x+=1
            return 'loss'
        elif can_list[2] == 'runner' and can_list[3] =='win':
            x+=1
            return 'win'
        elif can_list[2] == 'runner' and can_list[3] =='sig_stop':
            x+=1
            return 'sig_stop'
        else:
            x+=1
            return 'runner'

# %%
running = thirty.apply(running_result, axis='columns').to_frame()
thirty = thirty.join(running)
thirty.rename(columns={0: 'running_result'}, inplace=True)
# Out:
# processing row 0
# processing row 50
# processing row 100
# processing row 150
# processing row 200
# processing row 250
# processing row 300
# processing row 350
# processing row 400
# processing row 450
# processing row 500
# processing row 550
# processing row 600
# processing row 650
# processing row 700
# processing row 750
# processing row 800
# processing row 850
# processing row 900
# processing row 950
# processing row 1000
# processing row 1050
# processing row 1100
# processing row 1150
# processing row 1200
# processing row 1250
# processing row 1300
# processing row 1350
# processing row 1400
# processing row 1450
# processing row 1500
# processing row 1550
# processing row 1600
# processing row 1650
# processing row 1700
# processing row 1750
# processing row 1800
# processing row 1850
# processing row 1900
# processing row 1950
# processing row 2000
# processing row 2050
# processing row 2100
# processing row 2150
# processing row 2200
# processing row 2250
# processing row 2300
# processing row 2350
# processing row 2400
# processing row 2450
# processing row 2500
# processing row 2550
# processing row 2600
# processing row 2650
# processing row 2700
# processing row 2750
# processing row 2800
# processing row 2850
# processing row 2900
# processing row 2950
# processing row 3000
# processing row 3050
# processing row 3100
# processing row 3150
# processing row 3200
# processing row 3250
# processing row 3300
# processing row 3350
# processing row 3400
# processing row 3450
# processing row 3500
# processing row 3550
# processing row 3600
# processing row 3650
# processing row 3700
# processing row 3750
# processing row 3800
# processing row 3850
# processing row 3900
# processing row 3950
# processing row 4000
# processing row 4050
# processing row 4100
# processing row 4150
# processing row 4200
# processing row 4250
# processing row 4300
# processing row 4350
# processing row 4400
# processing row 4450
# processing row 4500
# processing row 4550
# processing row 4600
# processing row 4650
# processing row 4700
# processing row 4750
# processing row 4800
# processing row 4850
# processing row 4900
# processing row 4950
# processing row 5000
# processing row 5050
# processing row 5100
# processing row 5150
# processing row 5200
# processing row 5250
# processing row 5300
# processing row 5350
# processing row 5400
# processing row 5450
# processing row 5500
# processing row 5550
# processing row 5600
# processing row 5650
# processing row 5700
# processing row 5750
# processing row 5800
# processing row 5850
# processing row 5900
# processing row 5950
# processing row 6000
# processing row 6050
# processing row 6100
# processing row 6150
# processing row 6200
# processing row 6250
# processing row 6300
# processing row 6350
# processing row 6400
# processing row 6450
# processing row 6500
# processing row 6550
# processing row 6600
# processing row 6650
# processing row 6700
# processing row 6750
# processing row 6800
# processing row 6850
# processing row 6900
# processing row 6950
# processing row 7000
# processing row 7050
# processing row 7100
# processing row 7150
# processing row 7200
# processing row 7250
# processing row 7300
# processing row 7350
# processing row 7400
# processing row 7450
# processing row 7500
# processing row 7550
# processing row 7600
# processing row 7650
# processing row 7700
# processing row 7750
# processing row 7800
# processing row 7850
# processing row 7900
# processing row 7950
# processing row 8000
# processing row 8050
# processing row 8100
# processing row 8150
# processing row 8200
# processing row 8250
# processing row 8300
# processing row 8350
# processing row 8400
# processing row 8450
# processing row 8500
# processing row 8550
# processing row 8600
# processing row 8650
# processing row 8700
# processing row 8750
# processing row 8800
# processing row 8850
# processing row 8900
# processing row 8950
# processing row 9000
# processing row 9050
# processing row 9100
# processing row 9150
# processing row 9200
# processing row 9250
# processing row 9300
# processing row 9350
# processing row 9400
# processing row 9450
# processing row 9500
# processing row 9550
# processing row 9600
# processing row 9650
# processing row 9700
# processing row 9750
# processing row 9800
# processing row 9850
# processing row 9900
# processing row 9950
# processing row 10000
# processing row 10050
# processing row 10100
# processing row 10150
# processing row 10200
# processing row 10250
# processing row 10300
# processing row 10350
# processing row 10400
# processing row 10450
# processing row 10500
# processing row 10550
# processing row 10600
# processing row 10650
# processing row 10700
# processing row 10750
# processing row 10800
# processing row 10850
# processing row 10900
# processing row 10950
# processing row 11000
# processing row 11050
# processing row 11100
# processing row 11150
# processing row 11200
# processing row 11250
# processing row 11300
# processing row 11350
# processing row 11400
# processing row 11450
# processing row 11500
# processing row 11550
# processing row 11600
# processing row 11650
# processing row 11700
# processing row 11750
# processing row 11800
# processing row 11850
# processing row 11900
# processing row 11950
# processing row 12000
# processing row 12050
# processing row 12100
# processing row 12150
# processing row 12200
# processing row 12250
# processing row 12300
# processing row 12350
# processing row 12400
# processing row 12450
# processing row 12500
# processing row 12550
# processing row 12600
# processing row 12650
# processing row 12700
# processing row 12750
# processing row 12800
# processing row 12850
# processing row 12900
# processing row 12950
# processing row 13000
# processing row 13050
# processing row 13100
# processing row 13150
# processing row 13200
# processing row 13250
# processing row 13300
# processing row 13350
# processing row 13400
# processing row 13450
# processing row 13500
# processing row 13550
# processing row 13600
# processing row 13650
# processing row 13700
# processing row 13750
# processing row 13800
# processing row 13850
# processing row 13900
# processing row 13950
# processing row 14000
# processing row 14050
# processing row 14100
# processing row 14150
# processing row 14200
# processing row 14250
# processing row 14300
# processing row 14350
# processing row 14400
# processing row 14450
# processing row 14500
# processing row 14550
# processing row 14600
# processing row 14650
# processing row 14700
# processing row 14750
# processing row 14800
# processing row 14850
# processing row 14900
# processing row 14950
# processing row 15000
# processing row 15050
# processing row 15100
# processing row 15150
# processing row 15200
# processing row 15250
# processing row 15300
# processing row 15350
# processing row 15400
# processing row 15450
# processing row 15500
# processing row 15550
# processing row 15600
# processing row 15650
# processing row 15700
# processing row 15750
# processing row 15800
# processing row 15850
# processing row 15900
# processing row 15950
# processing row 16000
# processing row 16050
# processing row 16100
# processing row 16150
# processing row 16200
# processing row 16250
# processing row 16300
# processing row 16350
# processing row 16400
# processing row 16450
# processing row 16500
# processing row 16550
# processing row 16600
# processing row 16650
# processing row 16700
# processing row 16750
# processing row 16800
# processing row 16850
# processing row 16900
# processing row 16950
# processing row 17000
# processing row 17050
# processing row 17100
# processing row 17150
# processing row 17200
# processing row 17250
# processing row 17300
# processing row 17350
# processing row 17400
# processing row 17450
# processing row 17500
# processing row 17550
# processing row 17600
# processing row 17650
# processing row 17700
# processing row 17750
# processing row 17800
# processing row 17850
# processing row 17900
# processing row 17950
# processing row 18000
# processing row 18050
# processing row 18100
# processing row 18150
# processing row 18200
# processing row 18250
# processing row 18300
# processing row 18350
# processing row 18400
# processing row 18450
# processing row 18500
# processing row 18550
# processing row 18600
# processing row 18650
# processing row 18700
# processing row 18750
# processing row 18800
# processing row 18850
# processing row 18900
# processing row 18950
# processing row 19000
# processing row 19050
# processing row 19100
# processing row 19150
# processing row 19200
# processing row 19250
# processing row 19300
# processing row 19350
# processing row 19400
# processing row 19450
# processing row 19500
# processing row 19550
# processing row 19600
# processing row 19650
# processing row 19700
# processing row 19750
# processing row 19800
# processing row 19850
# processing row 19900
# processing row 19950
# processing row 20000
# processing row 20050

# %%
thirty.tail()
# Out:
#                       time     open     high      low    close         %K  \
# 20057  2020-08-14 18:30:00  139.516  139.554  139.472  139.496  17.139677
# 20058  2020-08-14 19:00:00  139.496  139.551  139.484  139.511  14.635504
# 20059  2020-08-14 19:30:00  139.511  139.520  139.466  139.480  12.694627
# 20060  2020-08-14 20:00:00  139.480  139.550  139.480  139.537  16.142521
# 20061  2020-08-14 20:30:00  139.537  139.555  139.435  139.498  17.644182
#
#               %D        RSI      Plot thirty_trend   4h_plot four_trend  \
# 20057  17.139677  42.368890 -0.017203      bullish -0.008434       flat
# 20058  16.564645  43.486229 -0.017296      bearish -0.008434       flat
# 20059  14.823269  41.687407 -0.017934      bearish -0.008434       flat
# 20060  14.490884  46.102152 -0.016597      bearish -0.008434       flat
# 20061  15.493777  43.666230 -0.016342      bullish -0.008434       flat
#
#       candle_dir dt_signal sent_signal simple_result running_result
# 20057      short  no_trade    no_trade      no_trade       no_trade
# 20058       long      long    no_trade      no_trade       no_trade
# 20059      short     short    no_trade      no_trade       no_trade
# 20060       long      long    no_trade      no_trade       no_trade
# 20061      short     short    no_trade      no_trade       no_trade

# %%
thirty.simple_result.value_counts()
# Out:
# no_trade         17489
# win                793
# sig_stop           693
# loss               530
# running_long       290
# running_short      267
# Name: simple_result, dtype: int64

# %%
thirty.running_result.value_counts()
# Out:
# no_trade     17489
# no_runner     1223
# win            835
# sig_stop       250
# loss           239
# runner          26
# Name: running_result, dtype: int64

# %% [markdown]
# So now we have our results added we'd like to know what the overall profit and loss is on each trade. We'll add this feature in the next function.

# %% [markdown]
# ## Create the Profit and Loss Feature

# %% [markdown]
# ### Rules
# * values are measured in pips
# * If simple result and running result are wins; then profit is 17. DONE
# * If simple result is a loss; loss is equal to signal candle close-high for shorts and low-close for longs. DONE
# * If simple result is a win and running result is a loss; profit is 7. DONE
# * if simple result is a runner and runner result is a loss; loss is close-high for shorts and low-close for longs. DONE
# * If simple result is a sig stop: value is close of signal candle to the close of the sig stop candle. For long trades its sigstop-signal and for short trades signal-sigstop.
# * If simple result is a runner and running result is a sig stop; value is the distance from the close of signal candle to the close of the sig stop candle. For long trades its sigstop-signal and for short trades signal-sigstop.
# * if simple result is a win and runner result is a runner; value is 7. DONE
# * if simple result is a runner and runner result is a runner; value is 0. DONE

# %%
thirty.iloc[86:94]
# Out:
#                    time     open     high      low    close         %K  \
# 86  2019-01-08 17:00:00  138.147  138.160  137.984  138.024   3.122522
# 87  2019-01-08 17:30:00  138.024  138.166  138.013  138.164   8.604319
# 88  2019-01-08 18:00:00  138.164  138.194  138.111  138.168  13.520750
# 89  2019-01-08 18:30:00  138.168  138.204  138.104  138.110  16.621808
# 90  2019-01-08 19:00:00  138.110  138.137  138.046  138.136  16.600871
# 91  2019-01-08 19:30:00  138.136  138.200  138.115  138.184  18.582914
# 92  2019-01-08 20:00:00  138.184  138.245  138.132  138.242  24.643778
# 93  2019-01-08 20:30:00  138.242  138.382  138.219  138.350  33.536834
#
#            %D        RSI      Plot thirty_trend   4h_plot four_trend  \
# 86   4.009453  28.333109 -0.094162      bearish  0.208666       flat
# 87   5.238092  35.127450 -0.094432      bearish  0.208666       flat
# 88   8.415864  35.316137 -0.093246      bearish  0.199396    bearish
# 89  12.915626  33.781816 -0.092593      bullish  0.199396    bearish
# 90  15.581143  35.142119 -0.090060      bearish  0.199396    bearish
# 91  17.268531  37.687125 -0.085481      bullish  0.199396    bearish
# 92  19.942521  40.714366 -0.079087      bullish  0.199396    bearish
# 93  25.587842  45.977278 -0.070006      bullish  0.199396    bearish
#
#    candle_dir dt_signal sent_signal simple_result running_result
# 86      short  no_trade    no_trade      no_trade       no_trade
# 87       long      long    no_trade      no_trade       no_trade
# 88       long  no_trade    no_trade      no_trade       no_trade
# 89      short     short    no_trade      no_trade       no_trade
# 90       long      long  long_trade  running_long            win
# 91       long  no_trade    no_trade      no_trade       no_trade
# 92       long  no_trade    no_trade      no_trade       no_trade
# 93       long  no_trade    no_trade      no_trade       no_trade

# %%
thirty.columns
# Out:
# Index(['time', 'open', 'high', 'low', 'close', '%K', '%D', 'RSI', 'Plot',
#        'thirty_trend', '4h_plot', 'four_trend', 'candle_dir', 'dt_signal',
#        'sent_signal', 'simple_result', 'running_result'],
#       dtype='object')

# %%
thirty.sent_signal.value_counts()
# Out:
# no_trade       17489
# long_trade      1325
# short_trade     1248
# Name: sent_signal, dtype: int64

# %%
x=0

def profit(row):
    global x
    
    #We'll add a print report to show the progress we're making mid function execute
    if x%2 == 0: 
        print("processing row {}".format(x))
    
    simple = thirty['simple_result']
    running = thirty['running_result']
    open_ = thirty['open']
    high = thirty['high']
    low = thirty['low']
    close = thirty['close']
    signal = thirty['sent_signal']
    
    long_short = ''
    
    if signal[x] == "short_trade":
        long_short = "short"
    elif signal[x] == 'long_trade':
        long_short = 'long'
    else:
        x+=1
        return 0

    
    #Let's start to initiate our Rules
    if simple[x] == 'win' and running[x] == 'win':
        x+=1
        return 0.17
    elif simple[x] == 'win' and running[x] == 'loss':
        x+=1
        return 0.07
    elif simple[x] == 'loss' and long_short == 'short':
        value = close[x] - (high[x]+0.02)
        x+=1
        return value
    elif simple[x] == 'loss' and long_short == 'long':
        value = (low[x]-0.02) - close[x]
        x+=1
        return value
    elif simple[x] == "running_long" and running[x] == 'loss':
        value = (low[x]-0.02) - close[x]
        x+=1
        return value
    elif simple[x] == 'running_short' and running[x] == 'loss':
        value = close[x] - (high[x]+0.02)
        x+=1
        return value
    elif simple[x] == "running_long" and running[x] == 'win':
        x+=1
        return 0.07
    elif simple[x] == 'running_short' and running[x] == 'win':
        x+=1
        return 0.07
    elif simple[x] == 'win' and running[x] == 'runner':
        x+=1
        return 0.07
    elif simple[x] == 'running_short' and running[x] == 'runner':
        x+=1
        return 0.00
    elif simple[x] == 'running_long' and running[x] == 'runner':
        x+=1
        return 0.00
    elif simple[x] == 'sig_stop'and long_short == 'short':
        value = close[x] - close[x+1]
        x+=1
        return value
    elif simple[x] == 'sig_stop' and long_short == 'long':
        value = close[x+1] - close[x]
        x+=1
        return value
        
        
        
    
   
    #we now just need to code for signal stops in the running results feature as follows
    for i, (j, k) in enumerate(zip(close[x+2:x+6], open_[x+2:x+6])):
        
        if running[x] == 'sig_stop' and long_short == 'long':
            
            if j < k:
                value = j - close[x]
                x+=1
                return value
                                            
        
        elif running[x] == 'sig_stop' and long_short == 'short':
            
            if j > k:
                value = close[x] - j 
                x+=1
                return value
        
        else: 
            x+=1
            return 0

# %%
value = thirty.apply(profit, axis='columns').to_frame()
thirty = thirty.join(value)
thirty.rename(columns={0: 'profit'}, inplace=True)
# Out:
# processing row 0
# processing row 2
# processing row 4
# processing row 6
# processing row 8
# processing row 10
# processing row 12
# processing row 14
# processing row 16
# processing row 18
# processing row 20
# processing row 22
# processing row 24
# processing row 26
# processing row 28
# processing row 30
# processing row 32
# processing row 34
# processing row 36
# processing row 38
# processing row 40
# processing row 42
# processing row 44
# processing row 46
# processing row 48
# processing row 50
# processing row 52
# processing row 54
# processing row 56
# processing row 58
# processing row 60
# processing row 62
# processing row 64
# processing row 66
# processing row 68
# processing row 70
# processing row 72
# processing row 74
# processing row 76
# processing row 78
# processing row 80
# processing row 82
# processing row 84
# processing row 86
# processing row 88
# processing row 90
# processing row 92
# processing row 94
# processing row 96
# processing row 98
# processing row 100
# processing row 102
# processing row 104
# processing row 106
# processing row 108
# processing row 110
# processing row 112
# processing row 114
# processing row 116
# processing row 118
# processing row 120
# processing row 122
# processing row 124
# processing row 126
# processing row 128
# processing row 130
# processing row 132
# processing row 134
# processing row 136
# processing row 138
# processing row 140
# processing row 142
# processing row 144
# processing row 146
# processing row 148
# processing row 150
# processing row 152
# processing row 154
# processing row 156
# processing row 158
# processing row 160
# processing row 162
# processing row 164
# processing row 166
# processing row 168
# processing row 170
# processing row 172
# processing row 174
# processing row 176
# processing row 178
# processing row 180
# processing row 182
# processing row 184
# processing row 186
# processing row 188
# processing row 190
# processing row 192
# processing row 194
# processing row 196
# processing row 198
# processing row 200
# processing row 202
# processing row 204
# processing row 206
# processing row 208
# processing row 210
# processing row 212
# processing row 214
# processing row 216
# processing row 218
# processing row 220
# processing row 222
# processing row 224
# processing row 226
# processing row 228
# processing row 230
# processing row 232
# processing row 234
# processing row 236
# processing row 238
# processing row 240
# processing row 242
# processing row 244
# processing row 246
# processing row 248
# processing row 250
# processing row 252
# processing row 254
# processing row 256
# processing row 258
# processing row 260
# processing row 262
# processing row 264
# processing row 266
# processing row 268
# processing row 270
# processing row 272
# processing row 274
# processing row 276
# processing row 278
# processing row 280
# processing row 282
# processing row 284
# processing row 286
# processing row 288
# processing row 290
# processing row 292
# processing row 294
# processing row 296
# processing row 298
# processing row 300
# processing row 302
# processing row 304
# processing row 306
# processing row 308
# processing row 310
# processing row 312
# processing row 314
# processing row 316
# processing row 318
# processing row 320
# processing row 322
# processing row 324
# processing row 326
# processing row 328
# processing row 330
# processing row 332
# processing row 334
# processing row 336
# processing row 338
# processing row 340
# processing row 342
# processing row 344
# processing row 346
# processing row 348
# processing row 350
# processing row 352
# processing row 354
# processing row 356
# processing row 358
# processing row 360
# processing row 362
# processing row 364
# processing row 366
# processing row 368
# processing row 370
# processing row 372
# processing row 374
# processing row 376
# processing row 378
# processing row 380
# processing row 382
# processing row 384
# processing row 386
# processing row 388
# processing row 390
# processing row 392
# processing row 394
# processing row 396
# processing row 398
# processing row 400
# processing row 402
# processing row 404
# processing row 406
# processing row 408
# processing row 410
# processing row 412
# processing row 414
# processing row 416
# processing row 418
# processing row 420
# processing row 422
# processing row 424
# processing row 426
# processing row 428
# processing row 430
# processing row 432
# processing row 434
# processing row 436
# processing row 438
# processing row 440
# processing row 442
# processing row 444
# processing row 446
# processing row 448
# processing row 450
# processing row 452
# processing row 454
# processing row 456
# processing row 458
# processing row 460
# processing row 462
# processing row 464
# processing row 466
# processing row 468
# processing row 470
# processing row 472
# processing row 474
# processing row 476
# processing row 478
# processing row 480
# processing row 482
# processing row 484
# processing row 486
# processing row 488
# processing row 490
# processing row 492
# processing row 494
# processing row 496
# processing row 498
# processing row 500
# processing row 502
# processing row 504
# processing row 506
# processing row 508
# processing row 510
# processing row 512
# processing row 514
# processing row 516
# processing row 518
# processing row 520
# processing row 522
# processing row 524
# processing row 526
# processing row 528
# processing row 530
# processing row 532
# processing row 534
# processing row 536
# processing row 538
# processing row 540
# processing row 542
# processing row 544
# processing row 546
# processing row 548
# processing row 550
# processing row 552
# processing row 554
# processing row 556
# processing row 558
# processing row 560
# processing row 562
# processing row 564
# processing row 566
# processing row 568
# processing row 570
# processing row 572
# processing row 574
# processing row 576
# processing row 578
# processing row 580
# processing row 582
# processing row 584
# processing row 586
# processing row 588
# processing row 590
# processing row 592
# processing row 594
# processing row 596
# processing row 598
# processing row 600
# processing row 602
# processing row 604
# processing row 606
# processing row 608
# processing row 610
# processing row 612
# processing row 614
# processing row 616
# processing row 618
# processing row 620
# processing row 622
# processing row 624
# processing row 626
# processing row 628
# processing row 630
# processing row 632
# processing row 634
# processing row 636
# processing row 638
# processing row 640
# processing row 642
# processing row 644
# processing row 646
# processing row 648
# processing row 650
# processing row 652
# processing row 654
# processing row 656
# processing row 658
# processing row 660
# processing row 662
# processing row 664
# processing row 666
# processing row 668
# processing row 670
# processing row 672
# processing row 674
# processing row 676
# processing row 678
# processing row 680
# processing row 682
# processing row 684
# processing row 686
# processing row 688
# processing row 690
# processing row 692
# processing row 694
# processing row 696
# processing row 698
# processing row 700
# processing row 702
# processing row 704
# processing row 706
# processing row 708
# processing row 710
# processing row 712
# processing row 714
# processing row 716
# processing row 718
# processing row 720
# processing row 722
# processing row 724
# processing row 726
# processing row 728
# processing row 730
# processing row 732
# processing row 734
# processing row 736
# processing row 738
# processing row 740
# processing row 742
# processing row 744
# processing row 746
# processing row 748
# processing row 750
# processing row 752
# processing row 754
# processing row 756
# processing row 758
# processing row 760
# processing row 762
# processing row 764
# processing row 766
# processing row 768
# processing row 770
# processing row 772
# processing row 774
# processing row 776
# processing row 778
# processing row 780
# processing row 782
# processing row 784
# processing row 786
# processing row 788
# processing row 790
# processing row 792
# processing row 794
# processing row 796
# processing row 798
# processing row 800
# processing row 802
# processing row 804
# processing row 806
# processing row 808
# processing row 810
# processing row 812
# processing row 814
# processing row 816
# processing row 818
# processing row 820
# processing row 822
# processing row 824
# processing row 826
# processing row 828
# processing row 830
# processing row 832
# processing row 834
# processing row 836
# processing row 838
# processing row 840
# processing row 842
# processing row 844
# processing row 846
# processing row 848
# processing row 850
# processing row 852
# processing row 854
# processing row 856
# processing row 858
# processing row 860
# processing row 862
# processing row 864
# processing row 866
# processing row 868
# processing row 870
# processing row 872
# processing row 874
# processing row 876
# processing row 878
# processing row 880
# processing row 882
# processing row 884
# processing row 886
# processing row 888
# processing row 890
# processing row 892
# processing row 894
# processing row 896
# processing row 898
# processing row 900
# processing row 902
# processing row 904
# processing row 906
# processing row 908
# processing row 910
# processing row 912
# processing row 914
# processing row 916
# processing row 918
# processing row 920
# processing row 922
# processing row 924
# processing row 926
# processing row 928
# processing row 930
# processing row 932
# processing row 934
# processing row 936
# processing row 938
# processing row 940
# processing row 942
# processing row 944
# processing row 946
# processing row 948
# processing row 950
# processing row 952
# processing row 954
# processing row 956
# processing row 958
# processing row 960
# processing row 962
# processing row 964
# processing row 966
# processing row 968
# processing row 970
# processing row 972
# processing row 974
# processing row 976
# processing row 978
# processing row 980
# processing row 982
# processing row 984
# processing row 986
# processing row 988
# processing row 990
# processing row 992
# processing row 994
# processing row 996
# processing row 998
# processing row 1000
# processing row 1002
# processing row 1004
# processing row 1006
# processing row 1008
# processing row 1010
# processing row 1012
# processing row 1014
# processing row 1016
# processing row 1018
# processing row 1020
# processing row 1022
# processing row 1024
# processing row 1026
# processing row 1028
# processing row 1030
# processing row 1032
# processing row 1034
# processing row 1036
# processing row 1038
# processing row 1040
# processing row 1042
# processing row 1044
# processing row 1046
# processing row 1048
# processing row 1050
# processing row 1052
# processing row 1054
# processing row 1056
# processing row 1058
# processing row 1060
# processing row 1062
# processing row 1064
# processing row 1066
# processing row 1068
# processing row 1070
# processing row 1072
# processing row 1074
# processing row 1076
# processing row 1078
# processing row 1080
# processing row 1082
# processing row 1084
# processing row 1086
# processing row 1088
# processing row 1090
# processing row 1092
# processing row 1094
# processing row 1096
# processing row 1098
# processing row 1100
# processing row 1102
# processing row 1104
# processing row 1106
# processing row 1108
# processing row 1110
# processing row 1112
# processing row 1114
# processing row 1116
# processing row 1118
# processing row 1120
# processing row 1122
# processing row 1124
# processing row 1126
# processing row 1128
# processing row 1130
# processing row 1132
# processing row 1134
# processing row 1136
# processing row 1138
# processing row 1140
# processing row 1142
# processing row 1144
# processing row 1146
# processing row 1148
# processing row 1150
# processing row 1152
# processing row 1154
# processing row 1156
# processing row 1158
# processing row 1160
# processing row 1162
# processing row 1164
# processing row 1166
# processing row 1168
# processing row 1170
# processing row 1172
# processing row 1174
# processing row 1176
# processing row 1178
# processing row 1180
# processing row 1182
# processing row 1184
# processing row 1186
# processing row 1188
# processing row 1190
# processing row 1192
# processing row 1194
# processing row 1196
# processing row 1198
# processing row 1200
# processing row 1202
# processing row 1204
# processing row 1206
# processing row 1208
# processing row 1210
# processing row 1212
# processing row 1214
# processing row 1216
# processing row 1218
# processing row 1220
# processing row 1222
# processing row 1224
# processing row 1226
# processing row 1228
# processing row 1230
# processing row 1232
# processing row 1234
# processing row 1236
# processing row 1238
# processing row 1240
# processing row 1242
# processing row 1244
# processing row 1246
# processing row 1248
# processing row 1250
# processing row 1252
# processing row 1254
# processing row 1256
# processing row 1258
# processing row 1260
# processing row 1262
# processing row 1264
# processing row 1266
# processing row 1268
# processing row 1270
# processing row 1272
# processing row 1274
# processing row 1276
# processing row 1278
# processing row 1280
# processing row 1282
# processing row 1284
# processing row 1286
# processing row 1288
# processing row 1290
# processing row 1292
# processing row 1294
# processing row 1296
# processing row 1298
# processing row 1300
# processing row 1302
# processing row 1304
# processing row 1306
# processing row 1308
# processing row 1310
# processing row 1312
# processing row 1314
# processing row 1316
# processing row 1318
# processing row 1320
# processing row 1322
# processing row 1324
# processing row 1326
# processing row 1328
# processing row 1330
# processing row 1332
# processing row 1334
# processing row 1336
# processing row 1338
# processing row 1340
# processing row 1342
# processing row 1344
# processing row 1346
# processing row 1348
# processing row 1350
# processing row 1352
# processing row 1354
# processing row 1356
# processing row 1358
# processing row 1360
# processing row 1362
# processing row 1364
# processing row 1366
# processing row 1368
# processing row 1370
# processing row 1372
# processing row 1374
# processing row 1376
# processing row 1378
# processing row 1380
# processing row 1382
# processing row 1384
# processing row 1386
# processing row 1388
# processing row 1390
# processing row 1392
# processing row 1394
# processing row 1396
# processing row 1398
# processing row 1400
# processing row 1402
# processing row 1404
# processing row 1406
# processing row 1408
# processing row 1410
# processing row 1412
# processing row 1414
# processing row 1416
# processing row 1418
# processing row 1420
# processing row 1422
# processing row 1424
# processing row 1426
# processing row 1428
# processing row 1430
# processing row 1432
# processing row 1434
# processing row 1436
# processing row 1438
# processing row 1440
# processing row 1442
# processing row 1444
# processing row 1446
# processing row 1448
# processing row 1450
# processing row 1452
# processing row 1454
# processing row 1456
# processing row 1458
# processing row 1460
# processing row 1462
# processing row 1464
# processing row 1466
# processing row 1468
# processing row 1470
# processing row 1472
# processing row 1474
# processing row 1476
# processing row 1478
# processing row 1480
# processing row 1482
# processing row 1484
# processing row 1486
# processing row 1488
# processing row 1490
# processing row 1492
# processing row 1494
# processing row 1496
# processing row 1498
# processing row 1500
# processing row 1502
# processing row 1504
# processing row 1506
# processing row 1508
# processing row 1510
# processing row 1512
# processing row 1514
# processing row 1516
# processing row 1518
# processing row 1520
# processing row 1522
# processing row 1524
# processing row 1526
# processing row 1528
# processing row 1530
# processing row 1532
# processing row 1534
# processing row 1536
# processing row 1538
# processing row 1540
# processing row 1542
# processing row 1544
# processing row 1546
# processing row 1548
# processing row 1550
# processing row 1552
# processing row 1554
# processing row 1556
# processing row 1558
# processing row 1560
# processing row 1562
# processing row 1564
# processing row 1566
# processing row 1568
# processing row 1570
# processing row 1572
# processing row 1574
# processing row 1576
# processing row 1578
# processing row 1580
# processing row 1582
# processing row 1584
# processing row 1586
# processing row 1588
# processing row 1590
# processing row 1592
# processing row 1594
# processing row 1596
# processing row 1598
# processing row 1600
# processing row 1602
# processing row 1604
# processing row 1606
# processing row 1608
# processing row 1610
# processing row 1612
# processing row 1614
# processing row 1616
# processing row 1618
# processing row 1620
# processing row 1622
# processing row 1624
# processing row 1626
# processing row 1628
# processing row 1630
# processing row 1632
# processing row 1634
# processing row 1636
# processing row 1638
# processing row 1640
# processing row 1642
# processing row 1644
# processing row 1646
# processing row 1648
# processing row 1650
# processing row 1652
# processing row 1654
# processing row 1656
# processing row 1658
# processing row 1660
# processing row 1662
# processing row 1664
# processing row 1666
# processing row 1668
# processing row 1670
# processing row 1672
# processing row 1674
# processing row 1676
# processing row 1678
# processing row 1680
# processing row 1682
# processing row 1684
# processing row 1686
# processing row 1688
# processing row 1690
# processing row 1692
# processing row 1694
# processing row 1696
# processing row 1698
# processing row 1700
# processing row 1702
# processing row 1704
# processing row 1706
# processing row 1708
# processing row 1710
# processing row 1712
# processing row 1714
# processing row 1716
# processing row 1718
# processing row 1720
# processing row 1722
# processing row 1724
# processing row 1726
# processing row 1728
# processing row 1730
# processing row 1732
# processing row 1734
# processing row 1736
# processing row 1738
# processing row 1740
# processing row 1742
# processing row 1744
# processing row 1746
# processing row 1748
# processing row 1750
# processing row 1752
# processing row 1754
# processing row 1756
# processing row 1758
# processing row 1760
# processing row 1762
# processing row 1764
# processing row 1766
# processing row 1768
# processing row 1770
# processing row 1772
# processing row 1774
# processing row 1776
# processing row 1778
# processing row 1780
# processing row 1782
# processing row 1784
# processing row 1786
# processing row 1788
# processing row 1790
# processing row 1792
# processing row 1794
# processing row 1796
# processing row 1798
# processing row 1800
# processing row 1802
# processing row 1804
# processing row 1806
# processing row 1808
# processing row 1810
# processing row 1812
# processing row 1814
# processing row 1816
# processing row 1818
# processing row 1820
# processing row 1822
# processing row 1824
# processing row 1826
# processing row 1828
# processing row 1830
# processing row 1832
# processing row 1834
# processing row 1836
# processing row 1838
# processing row 1840
# processing row 1842
# processing row 1844
# processing row 1846
# processing row 1848
# processing row 1850
# processing row 1852
# processing row 1854
# processing row 1856
# processing row 1858
# processing row 1860
# processing row 1862
# processing row 1864
# processing row 1866
# processing row 1868
# processing row 1870
# processing row 1872
# processing row 1874
# processing row 1876
# processing row 1878
# processing row 1880
# processing row 1882
# processing row 1884
# processing row 1886
# processing row 1888
# processing row 1890
# processing row 1892
# processing row 1894
# processing row 1896
# processing row 1898
# processing row 1900
# processing row 1902
# processing row 1904
# processing row 1906
# processing row 1908
# processing row 1910
# processing row 1912
# processing row 1914
# processing row 1916
# processing row 1918
# processing row 1920
# processing row 1922
# processing row 1924
# processing row 1926
# processing row 1928
# processing row 1930
# processing row 1932
# processing row 1934
# processing row 1936
# processing row 1938
# processing row 1940
# processing row 1942
# processing row 1944
# processing row 1946
# processing row 1948
# processing row 1950
# processing row 1952
# processing row 1954
# processing row 1956
# processing row 1958
# processing row 1960
# processing row 1962
# processing row 1964
# processing row 1966
# processing row 1968
# processing row 1970
# processing row 1972
# processing row 1974
# processing row 1976
# processing row 1978
# processing row 1980
# processing row 1982
# processing row 1984
# processing row 1986
# processing row 1988
# processing row 1990
# processing row 1992
# processing row 1994
# processing row 1996
# processing row 1998
# processing row 2000
# processing row 2002
# processing row 2004
# processing row 2006
# processing row 2008
# processing row 2010
# processing row 2012
# processing row 2014
# processing row 2016
# processing row 2018
# processing row 2020
# processing row 2022
# processing row 2024
# processing row 2026
# processing row 2028
# processing row 2030
# processing row 2032
# processing row 2034
# processing row 2036
# processing row 2038
# processing row 2040
# processing row 2042
# processing row 2044
# processing row 2046
# processing row 2048
# processing row 2050
# processing row 2052
# processing row 2054
# processing row 2056
# processing row 2058
# processing row 2060
# processing row 2062
# processing row 2064
# processing row 2066
# processing row 2068
# processing row 2070
# processing row 2072
# processing row 2074
# processing row 2076
# processing row 2078
# processing row 2080
# processing row 2082
# processing row 2084
# processing row 2086
# processing row 2088
# processing row 2090
# processing row 2092
# processing row 2094
# processing row 2096
# processing row 2098
# processing row 2100
# processing row 2102
# processing row 2104
# processing row 2106
# processing row 2108
# processing row 2110
# processing row 2112
# processing row 2114
# processing row 2116
# processing row 2118
# processing row 2120
# processing row 2122
# processing row 2124
# processing row 2126
# processing row 2128
# processing row 2130
# processing row 2132
# processing row 2134
# processing row 2136
# processing row 2138
# processing row 2140
# processing row 2142
# processing row 2144
# processing row 2146
# processing row 2148
# processing row 2150
# processing row 2152
# processing row 2154
# processing row 2156
# processing row 2158
# processing row 2160
# processing row 2162
# processing row 2164
# processing row 2166
# processing row 2168
# processing row 2170
# processing row 2172
# processing row 2174
# processing row 2176
# processing row 2178
# processing row 2180
# processing row 2182
# processing row 2184
# processing row 2186
# processing row 2188
# processing row 2190
# processing row 2192
# processing row 2194
# processing row 2196
# processing row 2198
# processing row 2200
# processing row 2202
# processing row 2204
# processing row 2206
# processing row 2208
# processing row 2210
# processing row 2212
# processing row 2214
# processing row 2216
# processing row 2218
# processing row 2220
# processing row 2222
# processing row 2224
# processing row 2226
# processing row 2228
# processing row 2230
# processing row 2232
# processing row 2234
# processing row 2236
# processing row 2238
# processing row 2240
# processing row 2242
# processing row 2244
# processing row 2246
# processing row 2248
# processing row 2250
# processing row 2252
# processing row 2254
# processing row 2256
# processing row 2258
# processing row 2260
# processing row 2262
# processing row 2264
# processing row 2266
# processing row 2268
# processing row 2270
# processing row 2272
# processing row 2274
# processing row 2276
# processing row 2278
# processing row 2280
# processing row 2282
# processing row 2284
# processing row 2286
# processing row 2288
# processing row 2290
# processing row 2292
# processing row 2294
# processing row 2296
# processing row 2298
# processing row 2300
# processing row 2302
# processing row 2304
# processing row 2306
# processing row 2308
# processing row 2310
# processing row 2312
# processing row 2314
# processing row 2316
# processing row 2318
# processing row 2320
# processing row 2322
# processing row 2324
# processing row 2326
# processing row 2328
# processing row 2330
# processing row 2332
# processing row 2334
# processing row 2336
# processing row 2338
# processing row 2340
# processing row 2342
# processing row 2344
# processing row 2346
# processing row 2348
# processing row 2350
# processing row 2352
# processing row 2354
# processing row 2356
# processing row 2358
# processing row 2360
# processing row 2362
# processing row 2364
# processing row 2366
# processing row 2368
# processing row 2370
# processing row 2372
# processing row 2374
# processing row 2376
# processing row 2378
# processing row 2380
# processing row 2382
# processing row 2384
# processing row 2386
# processing row 2388
# processing row 2390
# processing row 2392
# processing row 2394
# processing row 2396
# processing row 2398
# processing row 2400
# processing row 2402
# processing row 2404
# processing row 2406
# processing row 2408
# processing row 2410
# processing row 2412
# processing row 2414
# processing row 2416
# processing row 2418
# processing row 2420
# processing row 2422
# processing row 2424
# processing row 2426
# processing row 2428
# processing row 2430
# processing row 2432
# processing row 2434
# processing row 2436
# processing row 2438
# processing row 2440
# processing row 2442
# processing row 2444
# processing row 2446
# processing row 2448
# processing row 2450
# processing row 2452
# processing row 2454
# processing row 2456
# processing row 2458
# processing row 2460
# processing row 2462
# processing row 2464
# processing row 2466
# processing row 2468
# processing row 2470
# processing row 2472
# processing row 2474
# processing row 2476
# processing row 2478
# processing row 2480
# processing row 2482
# processing row 2484
# processing row 2486
# processing row 2488
# processing row 2490
# processing row 2492
# processing row 2494
# processing row 2496
# processing row 2498
# processing row 2500
# processing row 2502
# processing row 2504
# processing row 2506
# processing row 2508
# processing row 2510
# processing row 2512
# processing row 2514
# processing row 2516
# processing row 2518
# processing row 2520
# processing row 2522
# processing row 2524
# processing row 2526
# processing row 2528
# processing row 2530
# processing row 2532
# processing row 2534
# processing row 2536
# processing row 2538
# processing row 2540
# processing row 2542
# processing row 2544
# processing row 2546
# processing row 2548
# processing row 2550
# processing row 2552
# processing row 2554
# processing row 2556
# processing row 2558
# processing row 2560
# processing row 2562
# processing row 2564
# processing row 2566
# processing row 2568
# processing row 2570
# processing row 2572
# processing row 2574
# processing row 2576
# processing row 2578
# processing row 2580
# processing row 2582
# processing row 2584
# processing row 2586
# processing row 2588
# processing row 2590
# processing row 2592
# processing row 2594
# processing row 2596
# processing row 2598
# processing row 2600
# processing row 2602
# processing row 2604
# processing row 2606
# processing row 2608
# processing row 2610
# processing row 2612
# processing row 2614
# processing row 2616
# processing row 2618
# processing row 2620
# processing row 2622
# processing row 2624
# processing row 2626
# processing row 2628
# processing row 2630
# processing row 2632
# processing row 2634
# processing row 2636
# processing row 2638
# processing row 2640
# processing row 2642
# processing row 2644
# processing row 2646
# processing row 2648
# processing row 2650
# processing row 2652
# processing row 2654
# processing row 2656
# processing row 2658
# processing row 2660
# processing row 2662
# processing row 2664
# processing row 2666
# processing row 2668
# processing row 2670
# processing row 2672
# processing row 2674
# processing row 2676
# processing row 2678
# processing row 2680
# processing row 2682
# processing row 2684
# processing row 2686
# processing row 2688
# processing row 2690
# processing row 2692
# processing row 2694
# processing row 2696
# processing row 2698
# processing row 2700
# processing row 2702
# processing row 2704
# processing row 2706
# processing row 2708
# processing row 2710
# processing row 2712
# processing row 2714
# processing row 2716
# processing row 2718
# processing row 2720
# processing row 2722
# processing row 2724
# processing row 2726
# processing row 2728
# processing row 2730
# processing row 2732
# processing row 2734
# processing row 2736
# processing row 2738
# processing row 2740
# processing row 2742
# processing row 2744
# processing row 2746
# processing row 2748
# processing row 2750
# processing row 2752
# processing row 2754
# processing row 2756
# processing row 2758
# processing row 2760
# processing row 2762
# processing row 2764
# processing row 2766
# processing row 2768
# processing row 2770
# processing row 2772
# processing row 2774
# processing row 2776
# processing row 2778
# processing row 2780
# processing row 2782
# processing row 2784
# processing row 2786
# processing row 2788
# processing row 2790
# processing row 2792
# processing row 2794
# processing row 2796
# processing row 2798
# processing row 2800
# processing row 2802
# processing row 2804
# processing row 2806
# processing row 2808
# processing row 2810
# processing row 2812
# processing row 2814
# processing row 2816
# processing row 2818
# processing row 2820
# processing row 2822
# processing row 2824
# processing row 2826
# processing row 2828
# processing row 2830
# processing row 2832
# processing row 2834
# processing row 2836
# processing row 2838
# processing row 2840
# processing row 2842
# processing row 2844
# processing row 2846
# processing row 2848
# processing row 2850
# processing row 2852
# processing row 2854
# processing row 2856
# processing row 2858
# processing row 2860
# processing row 2862
# processing row 2864
# processing row 2866
# processing row 2868
# processing row 2870
# processing row 2872
# processing row 2874
# processing row 2876
# processing row 2878
# processing row 2880
# processing row 2882
# processing row 2884
# processing row 2886
# processing row 2888
# processing row 2890
# processing row 2892
# processing row 2894
# processing row 2896
# processing row 2898
# processing row 2900
# processing row 2902
# processing row 2904
# processing row 2906
# processing row 2908
# processing row 2910
# processing row 2912
# processing row 2914
# processing row 2916
# processing row 2918
# processing row 2920
# processing row 2922
# processing row 2924
# processing row 2926
# processing row 2928
# processing row 2930
# processing row 2932
# processing row 2934
# processing row 2936
# processing row 2938
# processing row 2940
# processing row 2942
# processing row 2944
# processing row 2946
# processing row 2948
# processing row 2950
# processing row 2952
# processing row 2954
# processing row 2956
# processing row 2958
# processing row 2960
# processing row 2962
# processing row 2964
# processing row 2966
# processing row 2968
# processing row 2970
# processing row 2972
# processing row 2974
# processing row 2976
# processing row 2978
# processing row 2980
# processing row 2982
# processing row 2984
# processing row 2986
# processing row 2988
# processing row 2990
# processing row 2992
# processing row 2994
# processing row 2996
# processing row 2998
# processing row 3000
# processing row 3002
# processing row 3004
# processing row 3006
# processing row 3008
# processing row 3010
# processing row 3012
# processing row 3014
# processing row 3016
# processing row 3018
# processing row 3020
# processing row 3022
# processing row 3024
# processing row 3026
# processing row 3028
# processing row 3030
# processing row 3032
# processing row 3034
# processing row 3036
# processing row 3038
# processing row 3040
# processing row 3042
# processing row 3044
# processing row 3046
# processing row 3048
# processing row 3050
# processing row 3052
# processing row 3054
# processing row 3056
# processing row 3058
# processing row 3060
# processing row 3062
# processing row 3064
# processing row 3066
# processing row 3068
# processing row 3070
# processing row 3072
# processing row 3074
# processing row 3076
# processing row 3078
# processing row 3080
# processing row 3082
# processing row 3084
# processing row 3086
# processing row 3088
# processing row 3090
# processing row 3092
# processing row 3094
# processing row 3096
# processing row 3098
# processing row 3100
# processing row 3102
# processing row 3104
# processing row 3106
# processing row 3108
# processing row 3110
# processing row 3112
# processing row 3114
# processing row 3116
# processing row 3118
# processing row 3120
# processing row 3122
# processing row 3124
# processing row 3126
# processing row 3128
# processing row 3130
# processing row 3132
# processing row 3134
# processing row 3136
# processing row 3138
# processing row 3140
# processing row 3142
# processing row 3144
# processing row 3146
# processing row 3148
# processing row 3150
# processing row 3152
# processing row 3154
# processing row 3156
# processing row 3158
# processing row 3160
# processing row 3162
# processing row 3164
# processing row 3166
# processing row 3168
# processing row 3170
# processing row 3172
# processing row 3174
# processing row 3176
# processing row 3178
# processing row 3180
# processing row 3182
# processing row 3184
# processing row 3186
# processing row 3188
# processing row 3190
# processing row 3192
# processing row 3194
# processing row 3196
# processing row 3198
# processing row 3200
# processing row 3202
# processing row 3204
# processing row 3206
# processing row 3208
# processing row 3210
# processing row 3212
# processing row 3214
# processing row 3216
# processing row 3218
# processing row 3220
# processing row 3222
# processing row 3224
# processing row 3226
# processing row 3228
# processing row 3230
# processing row 3232
# processing row 3234
# processing row 3236
# processing row 3238
# processing row 3240
# processing row 3242
# processing row 3244
# processing row 3246
# processing row 3248
# processing row 3250
# processing row 3252
# processing row 3254
# processing row 3256
# processing row 3258
# processing row 3260
# processing row 3262
# processing row 3264
# processing row 3266
# processing row 3268
# processing row 3270
# processing row 3272
# processing row 3274
# processing row 3276
# processing row 3278
# processing row 3280
# processing row 3282
# processing row 3284
# processing row 3286
# processing row 3288
# processing row 3290
# processing row 3292
# processing row 3294
# processing row 3296
# processing row 3298
# processing row 3300
# processing row 3302
# processing row 3304
# processing row 3306
# processing row 3308
# processing row 3310
# processing row 3312
# processing row 3314
# processing row 3316
# processing row 3318
# processing row 3320
# processing row 3322
# processing row 3324
# processing row 3326
# processing row 3328
# processing row 3330
# processing row 3332
# processing row 3334
# processing row 3336
# processing row 3338
# processing row 3340
# processing row 3342
# processing row 3344
# processing row 3346
# processing row 3348
# processing row 3350
# processing row 3352
# processing row 3354
# processing row 3356
# processing row 3358
# processing row 3360
# processing row 3362
# processing row 3364
# processing row 3366
# processing row 3368
# processing row 3370
# processing row 3372
# processing row 3374
# processing row 3376
# processing row 3378
# processing row 3380
# processing row 3382
# processing row 3384
# processing row 3386
# processing row 3388
# processing row 3390
# processing row 3392
# processing row 3394
# processing row 3396
# processing row 3398
# processing row 3400
# processing row 3402
# processing row 3404
# processing row 3406
# processing row 3408
# processing row 3410
# processing row 3412
# processing row 3414
# processing row 3416
# processing row 3418
# processing row 3420
# processing row 3422
# processing row 3424
# processing row 3426
# processing row 3428
# processing row 3430
# processing row 3432
# processing row 3434
# processing row 3436
# processing row 3438
# processing row 3440
# processing row 3442
# processing row 3444
# processing row 3446
# processing row 3448
# processing row 3450
# processing row 3452
# processing row 3454
# processing row 3456
# processing row 3458
# processing row 3460
# processing row 3462
# processing row 3464
# processing row 3466
# processing row 3468
# processing row 3470
# processing row 3472
# processing row 3474
# processing row 3476
# processing row 3478
# processing row 3480
# processing row 3482
# processing row 3484
# processing row 3486
# processing row 3488
# processing row 3490
# processing row 3492
# processing row 3494
# processing row 3496
# processing row 3498
# processing row 3500
# processing row 3502
# processing row 3504
# processing row 3506
# processing row 3508
# processing row 3510
# processing row 3512
# processing row 3514
# processing row 3516
# processing row 3518
# processing row 3520
# processing row 3522
# processing row 3524
# processing row 3526
# processing row 3528
# processing row 3530
# processing row 3532
# processing row 3534
# processing row 3536
# processing row 3538
# processing row 3540
# processing row 3542
# processing row 3544
# processing row 3546
# processing row 3548
# processing row 3550
# processing row 3552
# processing row 3554
# processing row 3556
# processing row 3558
# processing row 3560
# processing row 3562
# processing row 3564
# processing row 3566
# processing row 3568
# processing row 3570
# processing row 3572
# processing row 3574
# processing row 3576
# processing row 3578
# processing row 3580
# processing row 3582
# processing row 3584
# processing row 3586
# processing row 3588
# processing row 3590
# processing row 3592
# processing row 3594
# processing row 3596
# processing row 3598
# processing row 3600
# processing row 3602
# processing row 3604
# processing row 3606
# processing row 3608
# processing row 3610
# processing row 3612
# processing row 3614
# processing row 3616
# processing row 3618
# processing row 3620
# processing row 3622
# processing row 3624
# processing row 3626
# processing row 3628
# processing row 3630
# processing row 3632
# processing row 3634
# processing row 3636
# processing row 3638
# processing row 3640
# processing row 3642
# processing row 3644
# processing row 3646
# processing row 3648
# processing row 3650
# processing row 3652
# processing row 3654
# processing row 3656
# processing row 3658
# processing row 3660
# processing row 3662
# processing row 3664
# processing row 3666
# processing row 3668
# processing row 3670
# processing row 3672
# processing row 3674
# processing row 3676
# processing row 3678
# processing row 3680
# processing row 3682
# processing row 3684
# processing row 3686
# processing row 3688
# processing row 3690
# processing row 3692
# processing row 3694
# processing row 3696
# processing row 3698
# processing row 3700
# processing row 3702
# processing row 3704
# processing row 3706
# processing row 3708
# processing row 3710
# processing row 3712
# processing row 3714
# processing row 3716
# processing row 3718
# processing row 3720
# processing row 3722
# processing row 3724
# processing row 3726
# processing row 3728
# processing row 3730
# processing row 3732
# processing row 3734
# processing row 3736
# processing row 3738
# processing row 3740
# processing row 3742
# processing row 3744
# processing row 3746
# processing row 3748
# processing row 3750
# processing row 3752
# processing row 3754
# processing row 3756
# processing row 3758
# processing row 3760
# processing row 3762
# processing row 3764
# processing row 3766
# processing row 3768
# processing row 3770
# processing row 3772
# processing row 3774
# processing row 3776
# processing row 3778
# processing row 3780
# processing row 3782
# processing row 3784
# processing row 3786
# processing row 3788
# processing row 3790
# processing row 3792
# processing row 3794
# processing row 3796
# processing row 3798
# processing row 3800
# processing row 3802
# processing row 3804
# processing row 3806
# processing row 3808
# processing row 3810
# processing row 3812
# processing row 3814
# processing row 3816
# processing row 3818
# processing row 3820
# processing row 3822
# processing row 3824
# processing row 3826
# processing row 3828
# processing row 3830
# processing row 3832
# processing row 3834
# processing row 3836
# processing row 3838
# processing row 3840
# processing row 3842
# processing row 3844
# processing row 3846
# processing row 3848
# processing row 3850
# processing row 3852
# processing row 3854
# processing row 3856
# processing row 3858
# processing row 3860
# processing row 3862
# processing row 3864
# processing row 3866
# processing row 3868
# processing row 3870
# processing row 3872
# processing row 3874
# processing row 3876
# processing row 3878
# processing row 3880
# processing row 3882
# processing row 3884
# processing row 3886
# processing row 3888
# processing row 3890
# processing row 3892
# processing row 3894
# processing row 3896
# processing row 3898
# processing row 3900
# processing row 3902
# processing row 3904
# processing row 3906
# processing row 3908
# processing row 3910
# processing row 3912
# processing row 3914
# processing row 3916
# processing row 3918
# processing row 3920
# processing row 3922
# processing row 3924
# processing row 3926
# processing row 3928
# processing row 3930
# processing row 3932
# processing row 3934
# processing row 3936
# processing row 3938
# processing row 3940
# processing row 3942
# processing row 3944
# processing row 3946
# processing row 3948
# processing row 3950
# processing row 3952
# processing row 3954
# processing row 3956
# processing row 3958
# processing row 3960
# processing row 3962
# processing row 3964
# processing row 3966
# processing row 3968
# processing row 3970
# processing row 3972
# processing row 3974
# processing row 3976
# processing row 3978
# processing row 3980
# processing row 3982
# processing row 3984
# processing row 3986
# processing row 3988
# processing row 3990
# processing row 3992
# processing row 3994
# processing row 3996
# processing row 3998
# processing row 4000
# processing row 4002
# processing row 4004
# processing row 4006
# processing row 4008
# processing row 4010
# processing row 4012
# processing row 4014
# processing row 4016
# processing row 4018
# processing row 4020
# processing row 4022
# processing row 4024
# processing row 4026
# processing row 4028
# processing row 4030
# processing row 4032
# processing row 4034
# processing row 4036
# processing row 4038
# processing row 4040
# processing row 4042
# processing row 4044
# processing row 4046
# processing row 4048
# processing row 4050
# processing row 4052
# processing row 4054
# processing row 4056
# processing row 4058
# processing row 4060
# processing row 4062
# processing row 4064
# processing row 4066
# processing row 4068
# processing row 4070
# processing row 4072
# processing row 4074
# processing row 4076
# processing row 4078
# processing row 4080
# processing row 4082
# processing row 4084
# processing row 4086
# processing row 4088
# processing row 4090
# processing row 4092
# processing row 4094
# processing row 4096
# processing row 4098
# processing row 4100
# processing row 4102
# processing row 4104
# processing row 4106
# processing row 4108
# processing row 4110
# processing row 4112
# processing row 4114
# processing row 4116
# processing row 4118
# processing row 4120
# processing row 4122
# processing row 4124
# processing row 4126
# processing row 4128
# processing row 4130
# processing row 4132
# processing row 4134
# processing row 4136
# processing row 4138
# processing row 4140
# processing row 4142
# processing row 4144
# processing row 4146
# processing row 4148
# processing row 4150
# processing row 4152
# processing row 4154
# processing row 4156
# processing row 4158
# processing row 4160
# processing row 4162
# processing row 4164
# processing row 4166
# processing row 4168
# processing row 4170
# processing row 4172
# processing row 4174
# processing row 4176
# processing row 4178
# processing row 4180
# processing row 4182
# processing row 4184
# processing row 4186
# processing row 4188
# processing row 4190
# processing row 4192
# processing row 4194
# processing row 4196
# processing row 4198
# processing row 4200
# processing row 4202
# processing row 4204
# processing row 4206
# processing row 4208
# processing row 4210
# processing row 4212
# processing row 4214
# processing row 4216
# processing row 4218
# processing row 4220
# processing row 4222
# processing row 4224
# processing row 4226
# processing row 4228
# processing row 4230
# processing row 4232
# processing row 4234
# processing row 4236
# processing row 4238
# processing row 4240
# processing row 4242
# processing row 4244
# processing row 4246
# processing row 4248
# processing row 4250
# processing row 4252
# processing row 4254
# processing row 4256
# processing row 4258
# processing row 4260
# processing row 4262
# processing row 4264
# processing row 4266
# processing row 4268
# processing row 4270
# processing row 4272
# processing row 4274
# processing row 4276
# processing row 4278
# processing row 4280
# processing row 4282
# processing row 4284
# processing row 4286
# processing row 4288
# processing row 4290
# processing row 4292
# processing row 4294
# processing row 4296
# processing row 4298
# processing row 4300
# processing row 4302
# processing row 4304
# processing row 4306
# processing row 4308
# processing row 4310
# processing row 4312
# processing row 4314
# processing row 4316
# processing row 4318
# processing row 4320
# processing row 4322
# processing row 4324
# processing row 4326
# processing row 4328
# processing row 4330
# processing row 4332
# processing row 4334
# processing row 4336
# processing row 4338
# processing row 4340
# processing row 4342
# processing row 4344
# processing row 4346
# processing row 4348
# processing row 4350
# processing row 4352
# processing row 4354
# processing row 4356
# processing row 4358
# processing row 4360
# processing row 4362
# processing row 4364
# processing row 4366
# processing row 4368
# processing row 4370
# processing row 4372
# processing row 4374
# processing row 4376
# processing row 4378
# processing row 4380
# processing row 4382
# processing row 4384
# processing row 4386
# processing row 4388
# processing row 4390
# processing row 4392
# processing row 4394
# processing row 4396
# processing row 4398
# processing row 4400
# processing row 4402
# processing row 4404
# processing row 4406
# processing row 4408
# processing row 4410
# processing row 4412
# processing row 4414
# processing row 4416
# processing row 4418
# processing row 4420
# processing row 4422
# processing row 4424
# processing row 4426
# processing row 4428
# processing row 4430
# processing row 4432
# processing row 4434
# processing row 4436
# processing row 4438
# processing row 4440
# processing row 4442
# processing row 4444
# processing row 4446
# processing row 4448
# processing row 4450
# processing row 4452
# processing row 4454
# processing row 4456
# processing row 4458
# processing row 4460
# processing row 4462
# processing row 4464
# processing row 4466
# processing row 4468
# processing row 4470
# processing row 4472
# processing row 4474
# processing row 4476
# processing row 4478
# processing row 4480
# processing row 4482
# processing row 4484
# processing row 4486
# processing row 4488
# processing row 4490
# processing row 4492
# processing row 4494
# processing row 4496
# processing row 4498
# processing row 4500
# processing row 4502
# processing row 4504
# processing row 4506
# processing row 4508
# processing row 4510
# processing row 4512
# processing row 4514
# processing row 4516
# processing row 4518
# processing row 4520
# processing row 4522
# processing row 4524
# processing row 4526
# processing row 4528
# processing row 4530
# processing row 4532
# processing row 4534
# processing row 4536
# processing row 4538
# processing row 4540
# processing row 4542
# processing row 4544
# processing row 4546
# processing row 4548
# processing row 4550
# processing row 4552
# processing row 4554
# processing row 4556
# processing row 4558
# processing row 4560
# processing row 4562
# processing row 4564
# processing row 4566
# processing row 4568
# processing row 4570
# processing row 4572
# processing row 4574
# processing row 4576
# processing row 4578
# processing row 4580
# processing row 4582
# processing row 4584
# processing row 4586
# processing row 4588
# processing row 4590
# processing row 4592
# processing row 4594
# processing row 4596
# processing row 4598
# processing row 4600
# processing row 4602
# processing row 4604
# processing row 4606
# processing row 4608
# processing row 4610
# processing row 4612
# processing row 4614
# processing row 4616
# processing row 4618
# processing row 4620
# processing row 4622
# processing row 4624
# processing row 4626
# processing row 4628
# processing row 4630
# processing row 4632
# processing row 4634
# processing row 4636
# processing row 4638
# processing row 4640
# processing row 4642
# processing row 4644
# processing row 4646
# processing row 4648
# processing row 4650
# processing row 4652
# processing row 4654
# processing row 4656
# processing row 4658
# processing row 4660
# processing row 4662
# processing row 4664
# processing row 4666
# processing row 4668
# processing row 4670
# processing row 4672
# processing row 4674
# processing row 4676
# processing row 4678
# processing row 4680
# processing row 4682
# processing row 4684
# processing row 4686
# processing row 4688
# processing row 4690
# processing row 4692
# processing row 4694
# processing row 4696
# processing row 4698
# processing row 4700
# processing row 4702
# processing row 4704
# processing row 4706
# processing row 4708
# processing row 4710
# processing row 4712
# processing row 4714
# processing row 4716
# processing row 4718
# processing row 4720
# processing row 4722
# processing row 4724
# processing row 4726
# processing row 4728
# processing row 4730
# processing row 4732
# processing row 4734
# processing row 4736
# processing row 4738
# processing row 4740
# processing row 4742
# processing row 4744
# processing row 4746
# processing row 4748
# processing row 4750
# processing row 4752
# processing row 4754
# processing row 4756
# processing row 4758
# processing row 4760
# processing row 4762
# processing row 4764
# processing row 4766
# processing row 4768
# processing row 4770
# processing row 4772
# processing row 4774
# processing row 4776
# processing row 4778
# processing row 4780
# processing row 4782
# processing row 4784
# processing row 4786
# processing row 4788
# processing row 4790
# processing row 4792
# processing row 4794
# processing row 4796
# processing row 4798
# processing row 4800
# processing row 4802
# processing row 4804
# processing row 4806
# processing row 4808
# processing row 4810
# processing row 4812
# processing row 4814
# processing row 4816
# processing row 4818
# processing row 4820
# processing row 4822
# processing row 4824
# processing row 4826
# processing row 4828
# processing row 4830
# processing row 4832
# processing row 4834
# processing row 4836
# processing row 4838
# processing row 4840
# processing row 4842
# processing row 4844
# processing row 4846
# processing row 4848
# processing row 4850
# processing row 4852
# ...
# processing row 18540
# processing row 18542
# processing row 18544
# processing row 18546
# processing row 18548
# processing row 18550
# processing row 18552
# processing row 18554
# processing row 18556
# processing row 18558
# processing row 18560
# processing row 18562
# processing row 18564
# processing row 18566
# processing row 18568
# processing row 18570
# processing row 18572
# processing row 18574
# processing row 18576
# processing row 18578
# processing row 18580
# processing row 18582
# processing row 18584
# processing row 18586
# processing row 18588
# processing row 18590
# processing row 18592
# processing row 18594
# processing row 18596
# processing row 18598
# processing row 18600
# processing row 18602
# processing row 18604
# processing row 18606
# processing row 18608
# processing row 18610
# processing row 18612
# processing row 18614
# processing row 18616
# processing row 18618
# processing row 18620
# processing row 18622
# processing row 18624
# processing row 18626
# processing row 18628
# processing row 18630
# processing row 18632
# processing row 18634
# processing row 18636
# processing row 18638
# processing row 18640
# processing row 18642
# processing row 18644
# processing row 18646
# processing row 18648
# processing row 18650
# processing row 18652
# processing row 18654
# processing row 18656
# processing row 18658
# processing row 18660
# processing row 18662
# processing row 18664
# processing row 18666
# processing row 18668
# processing row 18670
# processing row 18672
# processing row 18674
# processing row 18676
# processing row 18678
# processing row 18680
# processing row 18682
# processing row 18684
# processing row 18686
# processing row 18688
# processing row 18690
# processing row 18692
# processing row 18694
# processing row 18696
# processing row 18698
# processing row 18700
# processing row 18702
# processing row 18704
# processing row 18706
# processing row 18708
# processing row 18710
# processing row 18712
# processing row 18714
# processing row 18716
# processing row 18718
# processing row 18720
# processing row 18722
# processing row 18724
# processing row 18726
# processing row 18728
# processing row 18730
# processing row 18732
# processing row 18734
# processing row 18736
# processing row 18738
# processing row 18740
# processing row 18742
# processing row 18744
# processing row 18746
# processing row 18748
# processing row 18750
# processing row 18752
# processing row 18754
# processing row 18756
# processing row 18758
# processing row 18760
# processing row 18762
# processing row 18764
# processing row 18766
# processing row 18768
# processing row 18770
# processing row 18772
# processing row 18774
# processing row 18776
# processing row 18778
# processing row 18780
# processing row 18782
# processing row 18784
# processing row 18786
# processing row 18788
# processing row 18790
# processing row 18792
# processing row 18794
# processing row 18796
# processing row 18798
# processing row 18800
# processing row 18802
# processing row 18804
# processing row 18806
# processing row 18808
# processing row 18810
# processing row 18812
# processing row 18814
# processing row 18816
# processing row 18818
# processing row 18820
# processing row 18822
# processing row 18824
# processing row 18826
# processing row 18828
# processing row 18830
# processing row 18832
# processing row 18834
# processing row 18836
# processing row 18838
# processing row 18840
# processing row 18842
# processing row 18844
# processing row 18846
# processing row 18848
# processing row 18850
# processing row 18852
# processing row 18854
# processing row 18856
# processing row 18858
# processing row 18860
# processing row 18862
# processing row 18864
# processing row 18866
# processing row 18868
# processing row 18870
# processing row 18872
# processing row 18874
# processing row 18876
# processing row 18878
# processing row 18880
# processing row 18882
# processing row 18884
# processing row 18886
# processing row 18888
# processing row 18890
# processing row 18892
# processing row 18894
# processing row 18896
# processing row 18898
# processing row 18900
# processing row 18902
# processing row 18904
# processing row 18906
# processing row 18908
# processing row 18910
# processing row 18912
# processing row 18914
# processing row 18916
# processing row 18918
# processing row 18920
# processing row 18922
# processing row 18924
# processing row 18926
# processing row 18928
# processing row 18930
# processing row 18932
# processing row 18934
# processing row 18936
# processing row 18938
# processing row 18940
# processing row 18942
# processing row 18944
# processing row 18946
# processing row 18948
# processing row 18950
# processing row 18952
# processing row 18954
# processing row 18956
# processing row 18958
# processing row 18960
# processing row 18962
# processing row 18964
# processing row 18966
# processing row 18968
# processing row 18970
# processing row 18972
# processing row 18974
# processing row 18976
# processing row 18978
# processing row 18980
# processing row 18982
# processing row 18984
# processing row 18986
# processing row 18988
# processing row 18990
# processing row 18992
# processing row 18994
# processing row 18996
# processing row 18998
# processing row 19000
# processing row 19002
# processing row 19004
# processing row 19006
# processing row 19008
# processing row 19010
# processing row 19012
# processing row 19014
# processing row 19016
# processing row 19018
# processing row 19020
# processing row 19022
# processing row 19024
# processing row 19026
# processing row 19028
# processing row 19030
# processing row 19032
# processing row 19034
# processing row 19036
# processing row 19038
# processing row 19040
# processing row 19042
# processing row 19044
# processing row 19046
# processing row 19048
# processing row 19050
# processing row 19052
# processing row 19054
# processing row 19056
# processing row 19058
# processing row 19060
# processing row 19062
# processing row 19064
# processing row 19066
# processing row 19068
# processing row 19070
# processing row 19072
# processing row 19074
# processing row 19076
# processing row 19078
# processing row 19080
# processing row 19082
# processing row 19084
# processing row 19086
# processing row 19088
# processing row 19090
# processing row 19092
# processing row 19094
# processing row 19096
# processing row 19098
# processing row 19100
# processing row 19102
# processing row 19104
# processing row 19106
# processing row 19108
# processing row 19110
# processing row 19112
# processing row 19114
# processing row 19116
# processing row 19118
# processing row 19120
# processing row 19122
# processing row 19124
# processing row 19126
# processing row 19128
# processing row 19130
# processing row 19132
# processing row 19134
# processing row 19136
# processing row 19138
# processing row 19140
# processing row 19142
# processing row 19144
# processing row 19146
# processing row 19148
# processing row 19150
# processing row 19152
# processing row 19154
# processing row 19156
# processing row 19158
# processing row 19160
# processing row 19162
# processing row 19164
# processing row 19166
# processing row 19168
# processing row 19170
# processing row 19172
# processing row 19174
# processing row 19176
# processing row 19178
# processing row 19180
# processing row 19182
# processing row 19184
# processing row 19186
# processing row 19188
# processing row 19190
# processing row 19192
# processing row 19194
# processing row 19196
# processing row 19198
# processing row 19200
# processing row 19202
# processing row 19204
# processing row 19206
# processing row 19208
# processing row 19210
# processing row 19212
# processing row 19214
# processing row 19216
# processing row 19218
# processing row 19220
# processing row 19222
# processing row 19224
# processing row 19226
# processing row 19228
# processing row 19230
# processing row 19232
# processing row 19234
# processing row 19236
# processing row 19238
# processing row 19240
# processing row 19242
# processing row 19244
# processing row 19246
# processing row 19248
# processing row 19250
# processing row 19252
# processing row 19254
# processing row 19256
# processing row 19258
# processing row 19260
# processing row 19262
# processing row 19264
# processing row 19266
# processing row 19268
# processing row 19270
# processing row 19272
# processing row 19274
# processing row 19276
# processing row 19278
# processing row 19280
# processing row 19282
# processing row 19284
# processing row 19286
# processing row 19288
# processing row 19290
# processing row 19292
# processing row 19294
# processing row 19296
# processing row 19298
# processing row 19300
# processing row 19302
# processing row 19304
# processing row 19306
# processing row 19308
# processing row 19310
# processing row 19312
# processing row 19314
# processing row 19316
# processing row 19318
# processing row 19320
# processing row 19322
# processing row 19324
# processing row 19326
# processing row 19328
# processing row 19330
# processing row 19332
# processing row 19334
# processing row 19336
# processing row 19338
# processing row 19340
# processing row 19342
# processing row 19344
# processing row 19346
# processing row 19348
# processing row 19350
# processing row 19352
# processing row 19354
# processing row 19356
# processing row 19358
# processing row 19360
# processing row 19362
# processing row 19364
# processing row 19366
# processing row 19368
# processing row 19370
# processing row 19372
# processing row 19374
# processing row 19376
# processing row 19378
# processing row 19380
# processing row 19382
# processing row 19384
# processing row 19386
# processing row 19388
# processing row 19390
# processing row 19392
# processing row 19394
# processing row 19396
# processing row 19398
# processing row 19400
# processing row 19402
# processing row 19404
# processing row 19406
# processing row 19408
# processing row 19410
# processing row 19412
# processing row 19414
# processing row 19416
# processing row 19418
# processing row 19420
# processing row 19422
# processing row 19424
# processing row 19426
# processing row 19428
# processing row 19430
# processing row 19432
# processing row 19434
# processing row 19436
# processing row 19438
# processing row 19440
# processing row 19442
# processing row 19444
# processing row 19446
# processing row 19448
# processing row 19450
# processing row 19452
# processing row 19454
# processing row 19456
# processing row 19458
# processing row 19460
# processing row 19462
# processing row 19464
# processing row 19466
# processing row 19468
# processing row 19470
# processing row 19472
# processing row 19474
# processing row 19476
# processing row 19478
# processing row 19480
# processing row 19482
# processing row 19484
# processing row 19486
# processing row 19488
# processing row 19490
# processing row 19492
# processing row 19494
# processing row 19496
# processing row 19498
# processing row 19500
# processing row 19502
# processing row 19504
# processing row 19506
# processing row 19508
# processing row 19510
# processing row 19512
# processing row 19514
# processing row 19516
# processing row 19518
# processing row 19520
# processing row 19522
# processing row 19524
# processing row 19526
# processing row 19528
# processing row 19530
# processing row 19532
# processing row 19534
# processing row 19536
# processing row 19538
# processing row 19540
# processing row 19542
# processing row 19544
# processing row 19546
# processing row 19548
# processing row 19550
# processing row 19552
# processing row 19554
# processing row 19556
# processing row 19558
# processing row 19560
# processing row 19562
# processing row 19564
# processing row 19566
# processing row 19568
# processing row 19570
# processing row 19572
# processing row 19574
# processing row 19576
# processing row 19578
# processing row 19580
# processing row 19582
# processing row 19584
# processing row 19586
# processing row 19588
# processing row 19590
# processing row 19592
# processing row 19594
# processing row 19596
# processing row 19598
# processing row 19600
# processing row 19602
# processing row 19604
# processing row 19606
# processing row 19608
# processing row 19610
# processing row 19612
# processing row 19614
# processing row 19616
# processing row 19618
# processing row 19620
# processing row 19622
# processing row 19624
# processing row 19626
# processing row 19628
# processing row 19630
# processing row 19632
# processing row 19634
# processing row 19636
# processing row 19638
# processing row 19640
# processing row 19642
# processing row 19644
# processing row 19646
# processing row 19648
# processing row 19650
# processing row 19652
# processing row 19654
# processing row 19656
# processing row 19658
# processing row 19660
# processing row 19662
# processing row 19664
# processing row 19666
# processing row 19668
# processing row 19670
# processing row 19672
# processing row 19674
# processing row 19676
# processing row 19678
# processing row 19680
# processing row 19682
# processing row 19684
# processing row 19686
# processing row 19688
# processing row 19690
# processing row 19692
# processing row 19694
# processing row 19696
# processing row 19698
# processing row 19700
# processing row 19702
# processing row 19704
# processing row 19706
# processing row 19708
# processing row 19710
# processing row 19712
# processing row 19714
# processing row 19716
# processing row 19718
# processing row 19720
# processing row 19722
# processing row 19724
# processing row 19726
# processing row 19728
# processing row 19730
# processing row 19732
# processing row 19734
# processing row 19736
# processing row 19738
# processing row 19740
# processing row 19742
# processing row 19744
# processing row 19746
# processing row 19748
# processing row 19750
# processing row 19752
# processing row 19754
# processing row 19756
# processing row 19758
# processing row 19760
# processing row 19762
# processing row 19764
# processing row 19766
# processing row 19768
# processing row 19770
# processing row 19772
# processing row 19774
# processing row 19776
# processing row 19778
# processing row 19780
# processing row 19782
# processing row 19784
# processing row 19786
# processing row 19788
# processing row 19790
# processing row 19792
# processing row 19794
# processing row 19796
# processing row 19798
# processing row 19800
# processing row 19802
# processing row 19804
# processing row 19806
# processing row 19808
# processing row 19810
# processing row 19812
# processing row 19814
# processing row 19816
# processing row 19818
# processing row 19820
# processing row 19822
# processing row 19824
# processing row 19826
# processing row 19828
# processing row 19830
# processing row 19832
# processing row 19834
# processing row 19836
# processing row 19838
# processing row 19840
# processing row 19842
# processing row 19844
# processing row 19846
# processing row 19848
# processing row 19850
# processing row 19852
# processing row 19854
# processing row 19856
# processing row 19858
# processing row 19860
# processing row 19862
# processing row 19864
# processing row 19866
# processing row 19868
# processing row 19870
# processing row 19872
# processing row 19874
# processing row 19876
# processing row 19878
# processing row 19880
# processing row 19882
# processing row 19884
# processing row 19886
# processing row 19888
# processing row 19890
# processing row 19892
# processing row 19894
# processing row 19896
# processing row 19898
# processing row 19900
# processing row 19902
# processing row 19904
# processing row 19906
# processing row 19908
# processing row 19910
# processing row 19912
# processing row 19914
# processing row 19916
# processing row 19918
# processing row 19920
# processing row 19922
# processing row 19924
# processing row 19926
# processing row 19928
# processing row 19930
# processing row 19932
# processing row 19934
# processing row 19936
# processing row 19938
# processing row 19940
# processing row 19942
# processing row 19944
# processing row 19946
# processing row 19948
# processing row 19950
# processing row 19952
# processing row 19954
# processing row 19956
# processing row 19958
# processing row 19960
# processing row 19962
# processing row 19964
# processing row 19966
# processing row 19968
# processing row 19970
# processing row 19972
# processing row 19974
# processing row 19976
# processing row 19978
# processing row 19980
# processing row 19982
# processing row 19984
# processing row 19986
# processing row 19988
# processing row 19990
# processing row 19992
# processing row 19994
# processing row 19996
# processing row 19998
# processing row 20000
# processing row 20002
# processing row 20004
# processing row 20006
# processing row 20008
# processing row 20010
# processing row 20012
# processing row 20014
# processing row 20016
# processing row 20018
# processing row 20020
# processing row 20022
# processing row 20024
# processing row 20026
# processing row 20028
# processing row 20030
# processing row 20032
# processing row 20034
# processing row 20036
# processing row 20038
# processing row 20040
# processing row 20042
# processing row 20044
# processing row 20046
# processing row 20048
# processing row 20050
# processing row 20052
# processing row 20054
# processing row 20056
# processing row 20058
# processing row 20060

# %%
print(thirty.shape)
thirty.head()
# Out:
# (20062, 18)
#                   time     open     high      low    close         %K  \
# 0  2019-01-06 22:00:00  138.091  138.179  138.011  138.020  81.448525
# 1  2019-01-06 22:30:00  138.020  138.084  137.922  138.074  77.059060
# 2  2019-01-06 23:00:00  138.074  138.302  137.935  138.273  80.000922
# 3  2019-01-06 23:30:00  138.273  138.334  138.168  138.210  81.073987
# 4  2019-01-07 00:00:00  138.210  138.254  138.099  138.228  82.464591
#
#           %D        RSI      Plot thirty_trend   4h_plot four_trend  \
# 0  86.245303  65.524837  0.070389      unknown  0.005608    unknown
# 1  82.185586  66.849987  0.061890      unknown  0.005608    unknown
# 2  79.502836  71.237596  0.058952      unknown  0.005608    unknown
# 3  79.377990  68.161801  0.053267      unknown  0.005608    unknown
# 4  81.179833  68.579229  0.047715      unknown  0.005608    unknown
#
#   candle_dir dt_signal sent_signal simple_result running_result  profit
# 0      short   unknown    no_trade      no_trade       no_trade     0.0
# 1       long      long    no_trade      no_trade       no_trade     0.0
# 2       long  no_trade    no_trade      no_trade       no_trade     0.0
# 3      short     short    no_trade      no_trade       no_trade     0.0
# 4       long      long    no_trade      no_trade       no_trade     0.0

# %% [markdown]
# ## Review the profit stats from each of our results

# %%
#simple result masks
sig = thirty[thirty['simple_result']=='sig_stop']
win = thirty[thirty['simple_result']=='win']
loss = thirty[thirty['simple_result']=='loss']
long_run = thirty[thirty['simple_result']=='running_long']
short_run = thirty[thirty['simple_result']=='running_short']

# %%
print(f"The best sig_stop profit is {round(sig.profit.max(), 2)}, the worst is {round(sig.profit.min(),2)} and the \
average is {round(sig.profit.mean(), 2)} \n")

print(f"The best win profit is {round(win.profit.max(), 2)}, the worst is {round(win.profit.min(),2)} and the \
average is {round(win.profit.mean(), 2)} \n")

print((f"The best loss profit is {round(loss.profit.max(), 2)}, the worst is {round(loss.profit.min(),2)} and the \
average is {round(loss.profit.mean(), 2)} \n"))


print(f"The best long running profit is {round(long_run.profit.max(), 2)}, the worst is \
{round(long_run.profit.min(),2)} and the average is {round(long_run.profit.mean(), 2)} \n")

print(f"The best short running profit is {round(short_run.profit.max(), 2)}, the worst is \
{round(short_run.profit.min(),2)} and the average is {round(short_run.profit.mean(), 2)}")
# Out:
# The best sig_stop profit is -0.0, the worst is -0.43 and the average is -0.05
#
# The best win profit is 0.17, the worst is 0.07 and the average is 0.15
#
# The best loss profit is -0.02, the worst is -0.82 and the average is -0.11
#
# The best long running profit is 0.07, the worst is -0.29 and the average is 0.01
#
# The best short running profit is 0.07, the worst is -0.23 and the average is 0.01

# %%
#Now some running result masks
sig = thirty[thirty['running_result']=='sig_stop']
win = thirty[thirty['running_result']=='win']
loss = thirty[thirty['running_result']=='loss']
no_runner = thirty[thirty['running_result']=='no_runner']
runner = thirty[thirty['running_result']=='runner']

print('**RUNNING RESULT OUTCOMES** \n')

print(f"The best sig_stop profit is {round(sig.profit.max(), 2)}, the worst is {round(sig.profit.min(),2)} and the \
average is {round(sig.profit.mean(), 2)} \n")

print(f"The best win profit is {round(win.profit.max(), 2)}, the worst is {round(win.profit.min(),2)} and the \
average is {round(win.profit.mean(), 2)} \n")

print((f"The best loss profit is {round(loss.profit.max(), 2)}, the worst is {round(loss.profit.min(),2)} and the \
average is {round(loss.profit.mean(), 2)} \n"))


print(f"The best no running profit is {round(no_runner.profit.max(), 2)}, the worst is \
{round(no_runner.profit.min(),2)} and the average is {round(no_runner.profit.mean(), 2)} \n")

print(f"The best runner profit is {round(runner.profit.max(), 2)}, the worst is \
{round(runner.profit.min(),2)} and the average is {round(runner.profit.mean(), 2)}")
# Out:
# **RUNNING RESULT OUTCOMES**
#
# The best sig_stop profit is 0.07, the worst is -0.15 and the average is -0.0
#
# The best win profit is 0.17, the worst is 0.07 and the average is 0.15
#
# The best loss profit is 0.07, the worst is -0.29 and the average is 0.01
#
# The best no running profit is -0.0, the worst is -0.82 and the average is -0.08
#
# The best runner profit is 0.07, the worst is 0.0 and the average is 0.07

# %% [markdown]
# The most complex metric is a signal stop during the running result. The numbers above broadly make sense we should end up with some wins and some losses however the average of bang on 0 is slightly suspicious. Let's investigate that.

# %%
win_sig = thirty[thirty.running_result=='sig_stop']
win_sig = win_sig[win_sig.profit > -0.001]
win_sig = win_sig[win_sig.profit < 0.001]

# %%
print(f"We have only {win_sig.shape[0]} rows with a profit of zero, this small quantity seems appropriate")
# Out:
# We have only 6 rows with a profit of zero, this small quantity seems appropriate

# %% [markdown]
# ## Overall Profit

# %%
#What profit would this trade strategy have resulted in for this time period?
print(f"The double tap with opposite trend analysis would have resulted in {thirty.profit.sum()} gain")
print("That is ~ 2860 pips which on 0.1 size is £2k, on 1.0 size is £19k and on 10.0 is £190k")
# Out:
# The double tap with opposite trend analysis would have resulted in 28.591999999992865 gain
# That is ~ 2860 pips which on 0.1 size is £2k, and on 1.0 size is £19k

# %% [markdown]
# When reviewing these potential gains we must also remember that we've limited our wins whilst letting losses play to their maximum. In principle some of the wins could have run out for 10s of pips based on us selling a proportion of our original position and holding a runner with stops re-positioned with minimal risk.

# %% [markdown]
# We can see that without any extra investigation that playing in the face of 4hr and 30minute sentiment seems like a good idea for small wins. The philosophy being that markets take a breather and if a support or resistance is formed on a 30minute candle there seems to be a decent chance that a further retrace will follow!

# %% [markdown]
# Now we must review whether the stochastic and RSI features can be used to further tune this approach. Ideally we would attempt to reduce our chances of hitting a losing trade.

# %% [markdown]
# ## Final clean and export

# %%
#Let's remove the no trade class from our sent_signal feature as we won't need this for our data viz section
data = thirty[thirty['sent_signal']!='no_trade']

# %%
data.sent_signal.value_counts()
# Out:
# long_trade     1325
# short_trade    1248
# Name: sent_signal, dtype: int64

# %%
#Now we should reset the index to provide a less confusing dataset for future use. 
data.reset_index(inplace=True)

# %%
#Now we'll drop out any redundant columns and also rename any features that need this!
data.drop(columns=['index'], inplace=True)
data.rename(columns={'%K': 'fast_stoch', 
                     '%D': 'slow_stoch',
                     'RSI': 'rsi',
                     'Plot': '30_sent',
                     '4h_plot': '4h_sent'}, inplace=True)

# %%
data.head(3)
# Out:
#                   time     open     high      low    close  fast_stoch  \
# 0  2019-01-07 14:00:00  138.322  138.408  138.268  138.272   91.285107
# 1  2019-01-07 15:30:00  138.578  138.687  138.346  138.492   89.649879
# 2  2019-01-07 18:30:00  138.802  138.824  138.532  138.622   86.898499
#
#    slow_stoch        rsi   30_sent thirty_trend   4h_sent four_trend  \
# 0   86.681139  60.939545 -0.018425      bullish  0.134107    bullish
# 1   90.104441  64.826891  0.002249      bullish  0.134107    bullish
# 2   91.325175  61.871256  0.022497      bullish  0.167150    bullish
#
#   candle_dir dt_signal  sent_signal  simple_result running_result  profit
# 0      short     short  short_trade            win           loss   0.070
# 1      short     short  short_trade            win            win   0.170
# 2      short     short  short_trade  running_short       sig_stop  -0.059

# %%
#All looks ok, so let's export as .csv file

data.to_csv("dt_trend_clean.csv", index=False)

# %% [markdown]
# ##  FEATURE ENGINEERING 1.1

# %% [markdown]
# In this set of feature engineering we're going to delve into some strategy tuning options and add a few more independent variables to enable us to understand the data and see if there is more value to extract from this trading strategy.

# %% [markdown]
# Some features that we're looking to add: \
# **value** - the sterling value of the profits and losses (based on non restricted losses and two take profit levels) \
# **size** - the notional value of the trade size based on a factor of 2 for losses. \
# **non_sig_result** - results if we ignore signal stops and keep trades open until win or stop loss. \
# **restricted_loss** - losing positions restricted (inc partial closes at 7pips) \
# **time based** - various time based features

# %% [markdown]
# We'll create a copy of our thirty data set to build our second set of features

# %%
thirtyA = thirty

# %%
thirtyA.head()
# Out:
#                   time     open     high      low    close         %K  \
# 0  2019-01-06 22:00:00  138.091  138.179  138.011  138.020  81.448525
# 1  2019-01-06 22:30:00  138.020  138.084  137.922  138.074  77.059060
# 2  2019-01-06 23:00:00  138.074  138.302  137.935  138.273  80.000922
# 3  2019-01-06 23:30:00  138.273  138.334  138.168  138.210  81.073987
# 4  2019-01-07 00:00:00  138.210  138.254  138.099  138.228  82.464591
#
#           %D        RSI      Plot thirty_trend   4h_plot four_trend  \
# 0  86.245303  65.524837  0.070389      unknown  0.005608    unknown
# 1  82.185586  66.849987  0.061890      unknown  0.005608    unknown
# 2  79.502836  71.237596  0.058952      unknown  0.005608    unknown
# 3  79.377990  68.161801  0.053267      unknown  0.005608    unknown
# 4  81.179833  68.579229  0.047715      unknown  0.005608    unknown
#
#   candle_dir dt_signal sent_signal simple_result running_result  profit
# 0      short   unknown    no_trade      no_trade       no_trade     0.0
# 1       long      long    no_trade      no_trade       no_trade     0.0
# 2       long  no_trade    no_trade      no_trade       no_trade     0.0
# 3      short     short    no_trade      no_trade       no_trade     0.0
# 4       long      long    no_trade      no_trade       no_trade     0.0

# %% [markdown]
# ## Ignore Signal Stops

# %% [markdown]
# ### Rules
# For this feature we'll ignore signal stops and keep trades open until either a stop loss is hit or a winnnig margin is achieved. The code will largely re_gurgitate the simple_result code, but leaving out the sig stop conditions. This feature measures what happens on the next candle only.
#
# * if a trade reaches a 9 pip advance on the next candle without the stop loss being broken (opposite end of signal candle) then the trade is a win.
# * If a trade reaches the stop loss then the trade is a loss
# * else trade remains oprn and running

# %%
#Set the global variable
x=0

def no_sigstop(row):
    global x
    
    if x%20 == 0: 
        print("processing row {}".format(x))
    
    #create series from required features for access later in function
    high = thirtyA['high']
    low = thirtyA['low']
    signal = thirtyA['sent_signal']
    close = thirtyA['close']
    open_ = thirtyA['open']
    
    #create a variable to hold whether we have a long trade or a short trade
    long_short = ''
    
    #Now check what trade we've been signalled and save it to long_short, unless no signal in which case return NA
    if signal.loc[x] == "short_trade":
        long_short = "short"
    elif signal.loc[x] == "long_trade":
        long_short = "long"
    else: 
        x+=1
        return "no_trade"
    
    #First will state whether a short trade is succesful or not
#     for i, j in enumerate(high[x:x+1]):
    if long_short == "short":
        if high[x+1] > high[x]+0.02:
            x+=1
            return "loss"
        elif low[x+1] < close[x]-0.09:
            x+=1
            return "win"
        else:
            x+=1
            return "running_short"
                
    #Now we'll state whether a long trade is successful or not
#     for i, j in enumerate(low[x:x+1]):
    if long_short == "long":
        if low[x+1] < low[x]-0.02:
            x+=1
            return "loss"
        elif high[x+1] > close[x]+0.09:
            x+=1
            return "win"
        else:
            x+=1
            return "running_long"

# %%
value = thirtyA.apply(no_sigstop, axis='columns').to_frame()
thirtyA = thirtyA.join(value)
thirtyA.rename(columns={0: 'no_sig_stop'}, inplace=True)
# Out:
# processing row 0
# processing row 20
# processing row 40
# processing row 60
# processing row 80
# processing row 100
# processing row 120
# processing row 140
# processing row 160
# processing row 180
# processing row 200
# processing row 220
# processing row 240
# processing row 260
# processing row 280
# processing row 300
# processing row 320
# processing row 340
# processing row 360
# processing row 380
# processing row 400
# processing row 420
# processing row 440
# processing row 460
# processing row 480
# processing row 500
# processing row 520
# processing row 540
# processing row 560
# processing row 580
# processing row 600
# processing row 620
# processing row 640
# processing row 660
# processing row 680
# processing row 700
# processing row 720
# processing row 740
# processing row 760
# processing row 780
# processing row 800
# processing row 820
# processing row 840
# processing row 860
# processing row 880
# processing row 900
# processing row 920
# processing row 940
# processing row 960
# processing row 980
# processing row 1000
# processing row 1020
# processing row 1040
# processing row 1060
# processing row 1080
# processing row 1100
# processing row 1120
# processing row 1140
# processing row 1160
# processing row 1180
# processing row 1200
# processing row 1220
# processing row 1240
# processing row 1260
# processing row 1280
# processing row 1300
# processing row 1320
# processing row 1340
# processing row 1360
# processing row 1380
# processing row 1400
# processing row 1420
# processing row 1440
# processing row 1460
# processing row 1480
# processing row 1500
# processing row 1520
# processing row 1540
# processing row 1560
# processing row 1580
# processing row 1600
# processing row 1620
# processing row 1640
# processing row 1660
# processing row 1680
# processing row 1700
# processing row 1720
# processing row 1740
# processing row 1760
# processing row 1780
# processing row 1800
# processing row 1820
# processing row 1840
# processing row 1860
# processing row 1880
# processing row 1900
# processing row 1920
# processing row 1940
# processing row 1960
# processing row 1980
# processing row 2000
# processing row 2020
# processing row 2040
# processing row 2060
# processing row 2080
# processing row 2100
# processing row 2120
# processing row 2140
# processing row 2160
# processing row 2180
# processing row 2200
# processing row 2220
# processing row 2240
# processing row 2260
# processing row 2280
# processing row 2300
# processing row 2320
# processing row 2340
# processing row 2360
# processing row 2380
# processing row 2400
# processing row 2420
# processing row 2440
# processing row 2460
# processing row 2480
# processing row 2500
# processing row 2520
# processing row 2540
# processing row 2560
# processing row 2580
# processing row 2600
# processing row 2620
# processing row 2640
# processing row 2660
# processing row 2680
# processing row 2700
# processing row 2720
# processing row 2740
# processing row 2760
# processing row 2780
# processing row 2800
# processing row 2820
# processing row 2840
# processing row 2860
# processing row 2880
# processing row 2900
# processing row 2920
# processing row 2940
# processing row 2960
# processing row 2980
# processing row 3000
# processing row 3020
# processing row 3040
# processing row 3060
# processing row 3080
# processing row 3100
# processing row 3120
# processing row 3140
# processing row 3160
# processing row 3180
# processing row 3200
# processing row 3220
# processing row 3240
# processing row 3260
# processing row 3280
# processing row 3300
# processing row 3320
# processing row 3340
# processing row 3360
# processing row 3380
# processing row 3400
# processing row 3420
# processing row 3440
# processing row 3460
# processing row 3480
# processing row 3500
# processing row 3520
# processing row 3540
# processing row 3560
# processing row 3580
# processing row 3600
# processing row 3620
# processing row 3640
# processing row 3660
# processing row 3680
# processing row 3700
# processing row 3720
# processing row 3740
# processing row 3760
# processing row 3780
# processing row 3800
# processing row 3820
# processing row 3840
# processing row 3860
# processing row 3880
# processing row 3900
# processing row 3920
# processing row 3940
# processing row 3960
# processing row 3980
# processing row 4000
# processing row 4020
# processing row 4040
# processing row 4060
# processing row 4080
# processing row 4100
# processing row 4120
# processing row 4140
# processing row 4160
# processing row 4180
# processing row 4200
# processing row 4220
# processing row 4240
# processing row 4260
# processing row 4280
# processing row 4300
# processing row 4320
# processing row 4340
# processing row 4360
# processing row 4380
# processing row 4400
# processing row 4420
# processing row 4440
# processing row 4460
# processing row 4480
# processing row 4500
# processing row 4520
# processing row 4540
# processing row 4560
# processing row 4580
# processing row 4600
# processing row 4620
# processing row 4640
# processing row 4660
# processing row 4680
# processing row 4700
# processing row 4720
# processing row 4740
# processing row 4760
# processing row 4780
# processing row 4800
# processing row 4820
# processing row 4840
# processing row 4860
# processing row 4880
# processing row 4900
# processing row 4920
# processing row 4940
# processing row 4960
# processing row 4980
# processing row 5000
# processing row 5020
# processing row 5040
# processing row 5060
# processing row 5080
# processing row 5100
# processing row 5120
# processing row 5140
# processing row 5160
# processing row 5180
# processing row 5200
# processing row 5220
# processing row 5240
# processing row 5260
# processing row 5280
# processing row 5300
# processing row 5320
# processing row 5340
# processing row 5360
# processing row 5380
# processing row 5400
# processing row 5420
# processing row 5440
# processing row 5460
# processing row 5480
# processing row 5500
# processing row 5520
# processing row 5540
# processing row 5560
# processing row 5580
# processing row 5600
# processing row 5620
# processing row 5640
# processing row 5660
# processing row 5680
# processing row 5700
# processing row 5720
# processing row 5740
# processing row 5760
# processing row 5780
# processing row 5800
# processing row 5820
# processing row 5840
# processing row 5860
# processing row 5880
# processing row 5900
# processing row 5920
# processing row 5940
# processing row 5960
# processing row 5980
# processing row 6000
# processing row 6020
# processing row 6040
# processing row 6060
# processing row 6080
# processing row 6100
# processing row 6120
# processing row 6140
# processing row 6160
# processing row 6180
# processing row 6200
# processing row 6220
# processing row 6240
# processing row 6260
# processing row 6280
# processing row 6300
# processing row 6320
# processing row 6340
# processing row 6360
# processing row 6380
# processing row 6400
# processing row 6420
# processing row 6440
# processing row 6460
# processing row 6480
# processing row 6500
# processing row 6520
# processing row 6540
# processing row 6560
# processing row 6580
# processing row 6600
# processing row 6620
# processing row 6640
# processing row 6660
# processing row 6680
# processing row 6700
# processing row 6720
# processing row 6740
# processing row 6760
# processing row 6780
# processing row 6800
# processing row 6820
# processing row 6840
# processing row 6860
# processing row 6880
# processing row 6900
# processing row 6920
# processing row 6940
# processing row 6960
# processing row 6980
# processing row 7000
# processing row 7020
# processing row 7040
# processing row 7060
# processing row 7080
# processing row 7100
# processing row 7120
# processing row 7140
# processing row 7160
# processing row 7180
# processing row 7200
# processing row 7220
# processing row 7240
# processing row 7260
# processing row 7280
# processing row 7300
# processing row 7320
# processing row 7340
# processing row 7360
# processing row 7380
# processing row 7400
# processing row 7420
# processing row 7440
# processing row 7460
# processing row 7480
# processing row 7500
# processing row 7520
# processing row 7540
# processing row 7560
# processing row 7580
# processing row 7600
# processing row 7620
# processing row 7640
# processing row 7660
# processing row 7680
# processing row 7700
# processing row 7720
# processing row 7740
# processing row 7760
# processing row 7780
# processing row 7800
# processing row 7820
# processing row 7840
# processing row 7860
# processing row 7880
# processing row 7900
# processing row 7920
# processing row 7940
# processing row 7960
# processing row 7980
# processing row 8000
# processing row 8020
# processing row 8040
# processing row 8060
# processing row 8080
# processing row 8100
# processing row 8120
# processing row 8140
# processing row 8160
# processing row 8180
# processing row 8200
# processing row 8220
# processing row 8240
# processing row 8260
# processing row 8280
# processing row 8300
# processing row 8320
# processing row 8340
# processing row 8360
# processing row 8380
# processing row 8400
# processing row 8420
# processing row 8440
# processing row 8460
# processing row 8480
# processing row 8500
# processing row 8520
# processing row 8540
# processing row 8560
# processing row 8580
# processing row 8600
# processing row 8620
# processing row 8640
# processing row 8660
# processing row 8680
# processing row 8700
# processing row 8720
# processing row 8740
# processing row 8760
# processing row 8780
# processing row 8800
# processing row 8820
# processing row 8840
# processing row 8860
# processing row 8880
# processing row 8900
# processing row 8920
# processing row 8940
# processing row 8960
# processing row 8980
# processing row 9000
# processing row 9020
# processing row 9040
# processing row 9060
# processing row 9080
# processing row 9100
# processing row 9120
# processing row 9140
# processing row 9160
# processing row 9180
# processing row 9200
# processing row 9220
# processing row 9240
# processing row 9260
# processing row 9280
# processing row 9300
# processing row 9320
# processing row 9340
# processing row 9360
# processing row 9380
# processing row 9400
# processing row 9420
# processing row 9440
# processing row 9460
# processing row 9480
# processing row 9500
# processing row 9520
# processing row 9540
# processing row 9560
# processing row 9580
# processing row 9600
# processing row 9620
# processing row 9640
# processing row 9660
# processing row 9680
# processing row 9700
# processing row 9720
# processing row 9740
# processing row 9760
# processing row 9780
# processing row 9800
# processing row 9820
# processing row 9840
# processing row 9860
# processing row 9880
# processing row 9900
# processing row 9920
# processing row 9940
# processing row 9960
# processing row 9980
# processing row 10000
# processing row 10020
# processing row 10040
# processing row 10060
# processing row 10080
# processing row 10100
# processing row 10120
# processing row 10140
# processing row 10160
# processing row 10180
# processing row 10200
# processing row 10220
# processing row 10240
# processing row 10260
# processing row 10280
# processing row 10300
# processing row 10320
# processing row 10340
# processing row 10360
# processing row 10380
# processing row 10400
# processing row 10420
# processing row 10440
# processing row 10460
# processing row 10480
# processing row 10500
# processing row 10520
# processing row 10540
# processing row 10560
# processing row 10580
# processing row 10600
# processing row 10620
# processing row 10640
# processing row 10660
# processing row 10680
# processing row 10700
# processing row 10720
# processing row 10740
# processing row 10760
# processing row 10780
# processing row 10800
# processing row 10820
# processing row 10840
# processing row 10860
# processing row 10880
# processing row 10900
# processing row 10920
# processing row 10940
# processing row 10960
# processing row 10980
# processing row 11000
# processing row 11020
# processing row 11040
# processing row 11060
# processing row 11080
# processing row 11100
# processing row 11120
# processing row 11140
# processing row 11160
# processing row 11180
# processing row 11200
# processing row 11220
# processing row 11240
# processing row 11260
# processing row 11280
# processing row 11300
# processing row 11320
# processing row 11340
# processing row 11360
# processing row 11380
# processing row 11400
# processing row 11420
# processing row 11440
# processing row 11460
# processing row 11480
# processing row 11500
# processing row 11520
# processing row 11540
# processing row 11560
# processing row 11580
# processing row 11600
# processing row 11620
# processing row 11640
# processing row 11660
# processing row 11680
# processing row 11700
# processing row 11720
# processing row 11740
# processing row 11760
# processing row 11780
# processing row 11800
# processing row 11820
# processing row 11840
# processing row 11860
# processing row 11880
# processing row 11900
# processing row 11920
# processing row 11940
# processing row 11960
# processing row 11980
# processing row 12000
# processing row 12020
# processing row 12040
# processing row 12060
# processing row 12080
# processing row 12100
# processing row 12120
# processing row 12140
# processing row 12160
# processing row 12180
# processing row 12200
# processing row 12220
# processing row 12240
# processing row 12260
# processing row 12280
# processing row 12300
# processing row 12320
# processing row 12340
# processing row 12360
# processing row 12380
# processing row 12400
# processing row 12420
# processing row 12440
# processing row 12460
# processing row 12480
# processing row 12500
# processing row 12520
# processing row 12540
# processing row 12560
# processing row 12580
# processing row 12600
# processing row 12620
# processing row 12640
# processing row 12660
# processing row 12680
# processing row 12700
# processing row 12720
# processing row 12740
# processing row 12760
# processing row 12780
# processing row 12800
# processing row 12820
# processing row 12840
# processing row 12860
# processing row 12880
# processing row 12900
# processing row 12920
# processing row 12940
# processing row 12960
# processing row 12980
# processing row 13000
# processing row 13020
# processing row 13040
# processing row 13060
# processing row 13080
# processing row 13100
# processing row 13120
# processing row 13140
# processing row 13160
# processing row 13180
# processing row 13200
# processing row 13220
# processing row 13240
# processing row 13260
# processing row 13280
# processing row 13300
# processing row 13320
# processing row 13340
# processing row 13360
# processing row 13380
# processing row 13400
# processing row 13420
# processing row 13440
# processing row 13460
# processing row 13480
# processing row 13500
# processing row 13520
# processing row 13540
# processing row 13560
# processing row 13580
# processing row 13600
# processing row 13620
# processing row 13640
# processing row 13660
# processing row 13680
# processing row 13700
# processing row 13720
# processing row 13740
# processing row 13760
# processing row 13780
# processing row 13800
# processing row 13820
# processing row 13840
# processing row 13860
# processing row 13880
# processing row 13900
# processing row 13920
# processing row 13940
# processing row 13960
# processing row 13980
# processing row 14000
# processing row 14020
# processing row 14040
# processing row 14060
# processing row 14080
# processing row 14100
# processing row 14120
# processing row 14140
# processing row 14160
# processing row 14180
# processing row 14200
# processing row 14220
# processing row 14240
# processing row 14260
# processing row 14280
# processing row 14300
# processing row 14320
# processing row 14340
# processing row 14360
# processing row 14380
# processing row 14400
# processing row 14420
# processing row 14440
# processing row 14460
# processing row 14480
# processing row 14500
# processing row 14520
# processing row 14540
# processing row 14560
# processing row 14580
# processing row 14600
# processing row 14620
# processing row 14640
# processing row 14660
# processing row 14680
# processing row 14700
# processing row 14720
# processing row 14740
# processing row 14760
# processing row 14780
# processing row 14800
# processing row 14820
# processing row 14840
# processing row 14860
# processing row 14880
# processing row 14900
# processing row 14920
# processing row 14940
# processing row 14960
# processing row 14980
# processing row 15000
# processing row 15020
# processing row 15040
# processing row 15060
# processing row 15080
# processing row 15100
# processing row 15120
# processing row 15140
# processing row 15160
# processing row 15180
# processing row 15200
# processing row 15220
# processing row 15240
# processing row 15260
# processing row 15280
# processing row 15300
# processing row 15320
# processing row 15340
# processing row 15360
# processing row 15380
# processing row 15400
# processing row 15420
# processing row 15440
# processing row 15460
# processing row 15480
# processing row 15500
# processing row 15520
# processing row 15540
# processing row 15560
# processing row 15580
# processing row 15600
# processing row 15620
# processing row 15640
# processing row 15660
# processing row 15680
# processing row 15700
# processing row 15720
# processing row 15740
# processing row 15760
# processing row 15780
# processing row 15800
# processing row 15820
# processing row 15840
# processing row 15860
# processing row 15880
# processing row 15900
# processing row 15920
# processing row 15940
# processing row 15960
# processing row 15980
# processing row 16000
# processing row 16020
# processing row 16040
# processing row 16060
# processing row 16080
# processing row 16100
# processing row 16120
# processing row 16140
# processing row 16160
# processing row 16180
# processing row 16200
# processing row 16220
# processing row 16240
# processing row 16260
# processing row 16280
# processing row 16300
# processing row 16320
# processing row 16340
# processing row 16360
# processing row 16380
# processing row 16400
# processing row 16420
# processing row 16440
# processing row 16460
# processing row 16480
# processing row 16500
# processing row 16520
# processing row 16540
# processing row 16560
# processing row 16580
# processing row 16600
# processing row 16620
# processing row 16640
# processing row 16660
# processing row 16680
# processing row 16700
# processing row 16720
# processing row 16740
# processing row 16760
# processing row 16780
# processing row 16800
# processing row 16820
# processing row 16840
# processing row 16860
# processing row 16880
# processing row 16900
# processing row 16920
# processing row 16940
# processing row 16960
# processing row 16980
# processing row 17000
# processing row 17020
# processing row 17040
# processing row 17060
# processing row 17080
# processing row 17100
# processing row 17120
# processing row 17140
# processing row 17160
# processing row 17180
# processing row 17200
# processing row 17220
# processing row 17240
# processing row 17260
# processing row 17280
# processing row 17300
# processing row 17320
# processing row 17340
# processing row 17360
# processing row 17380
# processing row 17400
# processing row 17420
# processing row 17440
# processing row 17460
# processing row 17480
# processing row 17500
# processing row 17520
# processing row 17540
# processing row 17560
# processing row 17580
# processing row 17600
# processing row 17620
# processing row 17640
# processing row 17660
# processing row 17680
# processing row 17700
# processing row 17720
# processing row 17740
# processing row 17760
# processing row 17780
# processing row 17800
# processing row 17820
# processing row 17840
# processing row 17860
# processing row 17880
# processing row 17900
# processing row 17920
# processing row 17940
# processing row 17960
# processing row 17980
# processing row 18000
# processing row 18020
# processing row 18040
# processing row 18060
# processing row 18080
# processing row 18100
# processing row 18120
# processing row 18140
# processing row 18160
# processing row 18180
# processing row 18200
# processing row 18220
# processing row 18240
# processing row 18260
# processing row 18280
# processing row 18300
# processing row 18320
# processing row 18340
# processing row 18360
# processing row 18380
# processing row 18400
# processing row 18420
# processing row 18440
# processing row 18460
# processing row 18480
# processing row 18500
# processing row 18520
# processing row 18540
# processing row 18560
# processing row 18580
# processing row 18600
# processing row 18620
# processing row 18640
# processing row 18660
# processing row 18680
# processing row 18700
# processing row 18720
# processing row 18740
# processing row 18760
# processing row 18780
# processing row 18800
# processing row 18820
# processing row 18840
# processing row 18860
# processing row 18880
# processing row 18900
# processing row 18920
# processing row 18940
# processing row 18960
# processing row 18980
# processing row 19000
# processing row 19020
# processing row 19040
# processing row 19060
# processing row 19080
# processing row 19100
# processing row 19120
# processing row 19140
# processing row 19160
# processing row 19180
# processing row 19200
# processing row 19220
# processing row 19240
# processing row 19260
# processing row 19280
# processing row 19300
# processing row 19320
# processing row 19340
# processing row 19360
# processing row 19380
# processing row 19400
# processing row 19420
# processing row 19440
# processing row 19460
# processing row 19480
# processing row 19500
# processing row 19520
# processing row 19540
# processing row 19560
# processing row 19580
# processing row 19600
# processing row 19620
# processing row 19640
# processing row 19660
# processing row 19680
# processing row 19700
# processing row 19720
# processing row 19740
# processing row 19760
# processing row 19780
# processing row 19800
# processing row 19820
# processing row 19840
# processing row 19860
# processing row 19880
# processing row 19900
# processing row 19920
# processing row 19940
# processing row 19960
# processing row 19980
# processing row 20000
# processing row 20020
# processing row 20040
# processing row 20060

# %%
thirtyA.head()
# Out:
#                   time     open     high      low    close         %K  \
# 0  2019-01-06 22:00:00  138.091  138.179  138.011  138.020  81.448525
# 1  2019-01-06 22:30:00  138.020  138.084  137.922  138.074  77.059060
# 2  2019-01-06 23:00:00  138.074  138.302  137.935  138.273  80.000922
# 3  2019-01-06 23:30:00  138.273  138.334  138.168  138.210  81.073987
# 4  2019-01-07 00:00:00  138.210  138.254  138.099  138.228  82.464591
#
#           %D        RSI      Plot thirty_trend   4h_plot four_trend  \
# 0  86.245303  65.524837  0.070389      unknown  0.005608    unknown
# 1  82.185586  66.849987  0.061890      unknown  0.005608    unknown
# 2  79.502836  71.237596  0.058952      unknown  0.005608    unknown
# 3  79.377990  68.161801  0.053267      unknown  0.005608    unknown
# 4  81.179833  68.579229  0.047715      unknown  0.005608    unknown
#
#   candle_dir dt_signal sent_signal simple_result running_result  profit  \
# 0      short   unknown    no_trade      no_trade       no_trade     0.0
# 1       long      long    no_trade      no_trade       no_trade     0.0
# 2       long  no_trade    no_trade      no_trade       no_trade     0.0
# 3      short     short    no_trade      no_trade       no_trade     0.0
# 4       long      long    no_trade      no_trade       no_trade     0.0
#
#   no_sig_stop
# 0    no_trade
# 1    no_trade
# 2    no_trade
# 3    no_trade
# 4    no_trade

# %%
#Let's check that our old sig stop count has now been replaced by runners. 
thirty.simple_result.value_counts()
# Out:
# no_trade         17489
# win                793
# sig_stop           693
# loss               530
# running_long       290
# running_short      267
# Name: simple_result, dtype: int64

# %%
thirtyA.no_sig_stop.value_counts()
#we originally had 693 sig stops, we can see here that these rows have now been converted into long and short runners
# Out:
# no_trade         17489
# win                793
# running_long       650
# running_short      600
# loss               530
# Name: no_sig_stop, dtype: int64

# %% [markdown]
# Ok good, we've added our strategy tweak by removing the sig stop feature. No we'll add our real trade value feature.

# %% [markdown]
# ## Real Win Pip Value
# ### (Including Signal Stops)

# %% [markdown]
# ### Rules
# * if profit <= 0, then value = profit
# * if profit == 7, then value = profit
# * if profit == 17 and sent_signal == long, then value is the max high of next 4 candles - trade level
# * if profit == 17 and sent_signal == short, value is the trade level - min low of next 4 candles

# %%
thirtyA.head(2)
# Out:
#                   time     open     high      low    close         %K  \
# 0  2019-01-06 22:00:00  138.091  138.179  138.011  138.020  81.448525
# 1  2019-01-06 22:30:00  138.020  138.084  137.922  138.074  77.059060
#
#           %D        RSI      Plot thirty_trend   4h_plot four_trend  \
# 0  86.245303  65.524837  0.070389      unknown  0.005608    unknown
# 1  82.185586  66.849987  0.061890      unknown  0.005608    unknown
#
#   candle_dir dt_signal sent_signal simple_result running_result  profit  \
# 0      short   unknown    no_trade      no_trade       no_trade     0.0
# 1       long      long    no_trade      no_trade       no_trade     0.0
#
#   no_sig_stop
# 0    no_trade
# 1    no_trade

# %%
thirtyA.sent_signal.value_counts()
# Out:
# no_trade       17489
# long_trade      1325
# short_trade     1248
# Name: sent_signal, dtype: int64

# %%
x = 0 #Set our external counter so we can access rows as we move through the dataframe

def real_win_value(row):
    global x #make our counter accessible
    
    if x%5 == 0: 
        print("processing row {}".format(x))
    
    #Set up individual feature variables
    profit = thirtyA['profit']
    sig = thirtyA['sent_signal']
    close = thirtyA['close']
    high = thirtyA['high']
    low = thirtyA['low']
    
    
        
    #Basic conditional 
    if profit[x] <= 0:
        x+=1
        return profit[x-1]
    elif profit[x] == 0.07:
        x+=1
        return profit[x-1]
    elif sig[x] == 'no_trade':
        x+=1
        return 0.0
        
    
    
    can_list = []

    for i, (j, k, m) in enumerate(zip(high[x+1:], low[x+1:], close[x+1:])): 
        if len(can_list) < 5:
            if profit[x] == 0.17 and sig[x] == "short_trade":
                
                can_list.append(abs(close[x] - k))
                
            elif profit[x]  == 0.17 and sig[x] == "long_trade":
                
                can_list.append(abs(j - close[x]))
            
            else: 
                value = profit[x]
                x+=1
                return value
            
        
        
                
    x+=1
    
    return max(can_list)

# %%
value1 = thirtyA.apply(real_win_value, axis='columns').to_frame()
thirtyA = thirtyA.join(value1)
thirtyA.rename(columns={0: 'ext_profit'}, inplace=True)
# Out:
# processing row 0
# processing row 5
# processing row 10
# processing row 15
# processing row 20
# processing row 25
# processing row 30
# processing row 35
# processing row 40
# processing row 45
# processing row 50
# processing row 55
# processing row 60
# processing row 65
# processing row 70
# processing row 75
# processing row 80
# processing row 85
# processing row 90
# processing row 95
# processing row 100
# processing row 105
# processing row 110
# processing row 115
# processing row 120
# processing row 125
# processing row 130
# processing row 135
# processing row 140
# processing row 145
# processing row 150
# processing row 155
# processing row 160
# processing row 165
# processing row 170
# processing row 175
# processing row 180
# processing row 185
# processing row 190
# processing row 195
# processing row 200
# processing row 205
# processing row 210
# processing row 215
# processing row 220
# processing row 225
# processing row 230
# processing row 235
# processing row 240
# processing row 245
# processing row 250
# processing row 255
# processing row 260
# processing row 265
# processing row 270
# processing row 275
# processing row 280
# processing row 285
# processing row 290
# processing row 295
# processing row 300
# processing row 305
# processing row 310
# processing row 315
# processing row 320
# processing row 325
# processing row 330
# processing row 335
# processing row 340
# processing row 345
# processing row 350
# processing row 355
# processing row 360
# processing row 365
# processing row 370
# processing row 375
# processing row 380
# processing row 385
# processing row 390
# processing row 395
# processing row 400
# processing row 405
# processing row 410
# processing row 415
# processing row 420
# processing row 425
# processing row 430
# processing row 435
# processing row 440
# processing row 445
# processing row 450
# processing row 455
# processing row 460
# processing row 465
# processing row 470
# processing row 475
# processing row 480
# processing row 485
# processing row 490
# processing row 495
# processing row 500
# processing row 505
# processing row 510
# processing row 515
# processing row 520
# processing row 525
# processing row 530
# processing row 535
# processing row 540
# processing row 545
# processing row 550
# processing row 555
# processing row 560
# processing row 565
# processing row 570
# processing row 575
# processing row 580
# processing row 585
# processing row 590
# processing row 595
# processing row 600
# processing row 605
# processing row 610
# processing row 615
# processing row 620
# processing row 625
# processing row 630
# processing row 635
# processing row 640
# processing row 645
# processing row 650
# processing row 655
# processing row 660
# processing row 665
# processing row 670
# processing row 675
# processing row 680
# processing row 685
# processing row 690
# processing row 695
# processing row 700
# processing row 705
# processing row 710
# processing row 715
# processing row 720
# processing row 725
# processing row 730
# processing row 735
# processing row 740
# processing row 745
# processing row 750
# processing row 755
# processing row 760
# processing row 765
# processing row 770
# processing row 775
# processing row 780
# processing row 785
# processing row 790
# processing row 795
# processing row 800
# processing row 805
# processing row 810
# processing row 815
# processing row 820
# processing row 825
# processing row 830
# processing row 835
# processing row 840
# processing row 845
# processing row 850
# processing row 855
# processing row 860
# processing row 865
# processing row 870
# processing row 875
# processing row 880
# processing row 885
# processing row 890
# processing row 895
# processing row 900
# processing row 905
# processing row 910
# processing row 915
# processing row 920
# processing row 925
# processing row 930
# processing row 935
# processing row 940
# processing row 945
# processing row 950
# processing row 955
# processing row 960
# processing row 965
# processing row 970
# processing row 975
# processing row 980
# processing row 985
# processing row 990
# processing row 995
# processing row 1000
# processing row 1005
# processing row 1010
# processing row 1015
# processing row 1020
# processing row 1025
# processing row 1030
# processing row 1035
# processing row 1040
# processing row 1045
# processing row 1050
# processing row 1055
# processing row 1060
# processing row 1065
# processing row 1070
# processing row 1075
# processing row 1080
# processing row 1085
# processing row 1090
# processing row 1095
# processing row 1100
# processing row 1105
# processing row 1110
# processing row 1115
# processing row 1120
# processing row 1125
# processing row 1130
# processing row 1135
# processing row 1140
# processing row 1145
# processing row 1150
# processing row 1155
# processing row 1160
# processing row 1165
# processing row 1170
# processing row 1175
# processing row 1180
# processing row 1185
# processing row 1190
# processing row 1195
# processing row 1200
# processing row 1205
# processing row 1210
# processing row 1215
# processing row 1220
# processing row 1225
# processing row 1230
# processing row 1235
# processing row 1240
# processing row 1245
# processing row 1250
# processing row 1255
# processing row 1260
# processing row 1265
# processing row 1270
# processing row 1275
# processing row 1280
# processing row 1285
# processing row 1290
# processing row 1295
# processing row 1300
# processing row 1305
# processing row 1310
# processing row 1315
# processing row 1320
# processing row 1325
# processing row 1330
# processing row 1335
# processing row 1340
# processing row 1345
# processing row 1350
# processing row 1355
# processing row 1360
# processing row 1365
# processing row 1370
# processing row 1375
# processing row 1380
# processing row 1385
# processing row 1390
# processing row 1395
# processing row 1400
# processing row 1405
# processing row 1410
# processing row 1415
# processing row 1420
# processing row 1425
# processing row 1430
# processing row 1435
# processing row 1440
# processing row 1445
# processing row 1450
# processing row 1455
# processing row 1460
# processing row 1465
# processing row 1470
# processing row 1475
# processing row 1480
# processing row 1485
# processing row 1490
# processing row 1495
# processing row 1500
# processing row 1505
# processing row 1510
# processing row 1515
# processing row 1520
# processing row 1525
# processing row 1530
# processing row 1535
# processing row 1540
# processing row 1545
# processing row 1550
# processing row 1555
# processing row 1560
# processing row 1565
# processing row 1570
# processing row 1575
# processing row 1580
# processing row 1585
# processing row 1590
# processing row 1595
# processing row 1600
# processing row 1605
# processing row 1610
# processing row 1615
# processing row 1620
# processing row 1625
# processing row 1630
# processing row 1635
# processing row 1640
# processing row 1645
# processing row 1650
# processing row 1655
# processing row 1660
# processing row 1665
# processing row 1670
# processing row 1675
# processing row 1680
# processing row 1685
# processing row 1690
# processing row 1695
# processing row 1700
# processing row 1705
# processing row 1710
# processing row 1715
# processing row 1720
# processing row 1725
# processing row 1730
# processing row 1735
# processing row 1740
# processing row 1745
# processing row 1750
# processing row 1755
# processing row 1760
# processing row 1765
# processing row 1770
# processing row 1775
# processing row 1780
# processing row 1785
# processing row 1790
# processing row 1795
# processing row 1800
# processing row 1805
# processing row 1810
# processing row 1815
# processing row 1820
# processing row 1825
# processing row 1830
# processing row 1835
# processing row 1840
# processing row 1845
# processing row 1850
# processing row 1855
# processing row 1860
# processing row 1865
# processing row 1870
# processing row 1875
# processing row 1880
# processing row 1885
# processing row 1890
# processing row 1895
# processing row 1900
# processing row 1905
# processing row 1910
# processing row 1915
# processing row 1920
# processing row 1925
# processing row 1930
# processing row 1935
# processing row 1940
# processing row 1945
# processing row 1950
# processing row 1955
# processing row 1960
# processing row 1965
# processing row 1970
# processing row 1975
# processing row 1980
# processing row 1985
# processing row 1990
# processing row 1995
# processing row 2000
# processing row 2005
# processing row 2010
# processing row 2015
# processing row 2020
# processing row 2025
# processing row 2030
# processing row 2035
# processing row 2040
# processing row 2045
# processing row 2050
# processing row 2055
# processing row 2060
# processing row 2065
# processing row 2070
# processing row 2075
# processing row 2080
# processing row 2085
# processing row 2090
# processing row 2095
# processing row 2100
# processing row 2105
# processing row 2110
# processing row 2115
# processing row 2120
# processing row 2125
# processing row 2130
# processing row 2135
# processing row 2140
# processing row 2145
# processing row 2150
# processing row 2155
# processing row 2160
# processing row 2165
# processing row 2170
# processing row 2175
# processing row 2180
# processing row 2185
# processing row 2190
# processing row 2195
# processing row 2200
# processing row 2205
# processing row 2210
# processing row 2215
# processing row 2220
# processing row 2225
# processing row 2230
# processing row 2235
# processing row 2240
# processing row 2245
# processing row 2250
# processing row 2255
# processing row 2260
# processing row 2265
# processing row 2270
# processing row 2275
# processing row 2280
# processing row 2285
# processing row 2290
# processing row 2295
# processing row 2300
# processing row 2305
# processing row 2310
# processing row 2315
# processing row 2320
# processing row 2325
# processing row 2330
# processing row 2335
# processing row 2340
# processing row 2345
# processing row 2350
# processing row 2355
# processing row 2360
# processing row 2365
# processing row 2370
# processing row 2375
# processing row 2380
# processing row 2385
# processing row 2390
# processing row 2395
# processing row 2400
# processing row 2405
# processing row 2410
# processing row 2415
# processing row 2420
# processing row 2425
# processing row 2430
# processing row 2435
# processing row 2440
# processing row 2445
# processing row 2450
# processing row 2455
# processing row 2460
# processing row 2465
# processing row 2470
# processing row 2475
# processing row 2480
# processing row 2485
# processing row 2490
# processing row 2495
# processing row 2500
# processing row 2505
# processing row 2510
# processing row 2515
# processing row 2520
# processing row 2525
# processing row 2530
# processing row 2535
# processing row 2540
# processing row 2545
# processing row 2550
# processing row 2555
# processing row 2560
# processing row 2565
# processing row 2570
# processing row 2575
# processing row 2580
# processing row 2585
# processing row 2590
# processing row 2595
# processing row 2600
# processing row 2605
# processing row 2610
# processing row 2615
# processing row 2620
# processing row 2625
# processing row 2630
# processing row 2635
# processing row 2640
# processing row 2645
# processing row 2650
# processing row 2655
# processing row 2660
# processing row 2665
# processing row 2670
# processing row 2675
# processing row 2680
# processing row 2685
# processing row 2690
# processing row 2695
# processing row 2700
# processing row 2705
# processing row 2710
# processing row 2715
# processing row 2720
# processing row 2725
# processing row 2730
# processing row 2735
# processing row 2740
# processing row 2745
# processing row 2750
# processing row 2755
# processing row 2760
# processing row 2765
# processing row 2770
# processing row 2775
# processing row 2780
# processing row 2785
# processing row 2790
# processing row 2795
# processing row 2800
# processing row 2805
# processing row 2810
# processing row 2815
# processing row 2820
# processing row 2825
# processing row 2830
# processing row 2835
# processing row 2840
# processing row 2845
# processing row 2850
# processing row 2855
# processing row 2860
# processing row 2865
# processing row 2870
# processing row 2875
# processing row 2880
# processing row 2885
# processing row 2890
# processing row 2895
# processing row 2900
# processing row 2905
# processing row 2910
# processing row 2915
# processing row 2920
# processing row 2925
# processing row 2930
# processing row 2935
# processing row 2940
# processing row 2945
# processing row 2950
# processing row 2955
# processing row 2960
# processing row 2965
# processing row 2970
# processing row 2975
# processing row 2980
# processing row 2985
# processing row 2990
# processing row 2995
# processing row 3000
# processing row 3005
# processing row 3010
# processing row 3015
# processing row 3020
# processing row 3025
# processing row 3030
# processing row 3035
# processing row 3040
# processing row 3045
# processing row 3050
# processing row 3055
# processing row 3060
# processing row 3065
# processing row 3070
# processing row 3075
# processing row 3080
# processing row 3085
# processing row 3090
# processing row 3095
# processing row 3100
# processing row 3105
# processing row 3110
# processing row 3115
# processing row 3120
# processing row 3125
# processing row 3130
# processing row 3135
# processing row 3140
# processing row 3145
# processing row 3150
# processing row 3155
# processing row 3160
# processing row 3165
# processing row 3170
# processing row 3175
# processing row 3180
# processing row 3185
# processing row 3190
# processing row 3195
# processing row 3200
# processing row 3205
# processing row 3210
# processing row 3215
# processing row 3220
# processing row 3225
# processing row 3230
# processing row 3235
# processing row 3240
# processing row 3245
# processing row 3250
# processing row 3255
# processing row 3260
# processing row 3265
# processing row 3270
# processing row 3275
# processing row 3280
# processing row 3285
# processing row 3290
# processing row 3295
# processing row 3300
# processing row 3305
# processing row 3310
# processing row 3315
# processing row 3320
# processing row 3325
# processing row 3330
# processing row 3335
# processing row 3340
# processing row 3345
# processing row 3350
# processing row 3355
# processing row 3360
# processing row 3365
# processing row 3370
# processing row 3375
# processing row 3380
# processing row 3385
# processing row 3390
# processing row 3395
# processing row 3400
# processing row 3405
# processing row 3410
# processing row 3415
# processing row 3420
# processing row 3425
# processing row 3430
# processing row 3435
# processing row 3440
# processing row 3445
# processing row 3450
# processing row 3455
# processing row 3460
# processing row 3465
# processing row 3470
# processing row 3475
# processing row 3480
# processing row 3485
# processing row 3490
# processing row 3495
# processing row 3500
# processing row 3505
# processing row 3510
# processing row 3515
# processing row 3520
# processing row 3525
# processing row 3530
# processing row 3535
# processing row 3540
# processing row 3545
# processing row 3550
# processing row 3555
# processing row 3560
# processing row 3565
# processing row 3570
# processing row 3575
# processing row 3580
# processing row 3585
# processing row 3590
# processing row 3595
# processing row 3600
# processing row 3605
# processing row 3610
# processing row 3615
# processing row 3620
# processing row 3625
# processing row 3630
# processing row 3635
# processing row 3640
# processing row 3645
# processing row 3650
# processing row 3655
# processing row 3660
# processing row 3665
# processing row 3670
# processing row 3675
# processing row 3680
# processing row 3685
# processing row 3690
# processing row 3695
# processing row 3700
# processing row 3705
# processing row 3710
# processing row 3715
# processing row 3720
# processing row 3725
# processing row 3730
# processing row 3735
# processing row 3740
# processing row 3745
# processing row 3750
# processing row 3755
# processing row 3760
# processing row 3765
# processing row 3770
# processing row 3775
# processing row 3780
# processing row 3785
# processing row 3790
# processing row 3795
# processing row 3800
# processing row 3805
# processing row 3810
# processing row 3815
# processing row 3820
# processing row 3825
# processing row 3830
# processing row 3835
# processing row 3840
# processing row 3845
# processing row 3850
# processing row 3855
# processing row 3860
# processing row 3865
# processing row 3870
# processing row 3875
# processing row 3880
# processing row 3885
# processing row 3890
# processing row 3895
# processing row 3900
# processing row 3905
# processing row 3910
# processing row 3915
# processing row 3920
# processing row 3925
# processing row 3930
# processing row 3935
# processing row 3940
# processing row 3945
# processing row 3950
# processing row 3955
# processing row 3960
# processing row 3965
# processing row 3970
# processing row 3975
# processing row 3980
# processing row 3985
# processing row 3990
# processing row 3995
# processing row 4000
# processing row 4005
# processing row 4010
# processing row 4015
# processing row 4020
# processing row 4025
# processing row 4030
# processing row 4035
# processing row 4040
# processing row 4045
# processing row 4050
# processing row 4055
# processing row 4060
# processing row 4065
# processing row 4070
# processing row 4075
# processing row 4080
# processing row 4085
# processing row 4090
# processing row 4095
# processing row 4100
# processing row 4105
# processing row 4110
# processing row 4115
# processing row 4120
# processing row 4125
# processing row 4130
# processing row 4135
# processing row 4140
# processing row 4145
# processing row 4150
# processing row 4155
# processing row 4160
# processing row 4165
# processing row 4170
# processing row 4175
# processing row 4180
# processing row 4185
# processing row 4190
# processing row 4195
# processing row 4200
# processing row 4205
# processing row 4210
# processing row 4215
# processing row 4220
# processing row 4225
# processing row 4230
# processing row 4235
# processing row 4240
# processing row 4245
# processing row 4250
# processing row 4255
# processing row 4260
# processing row 4265
# processing row 4270
# processing row 4275
# processing row 4280
# processing row 4285
# processing row 4290
# processing row 4295
# processing row 4300
# processing row 4305
# processing row 4310
# processing row 4315
# processing row 4320
# processing row 4325
# processing row 4330
# processing row 4335
# processing row 4340
# processing row 4345
# processing row 4350
# processing row 4355
# processing row 4360
# processing row 4365
# processing row 4370
# processing row 4375
# processing row 4380
# processing row 4385
# processing row 4390
# processing row 4395
# processing row 4400
# processing row 4405
# processing row 4410
# processing row 4415
# processing row 4420
# processing row 4425
# processing row 4430
# processing row 4435
# processing row 4440
# processing row 4445
# processing row 4450
# processing row 4455
# processing row 4460
# processing row 4465
# processing row 4470
# processing row 4475
# processing row 4480
# processing row 4485
# processing row 4490
# processing row 4495
# processing row 4500
# processing row 4505
# processing row 4510
# processing row 4515
# processing row 4520
# processing row 4525
# processing row 4530
# processing row 4535
# processing row 4540
# processing row 4545
# processing row 4550
# processing row 4555
# processing row 4560
# processing row 4565
# processing row 4570
# processing row 4575
# processing row 4580
# processing row 4585
# processing row 4590
# processing row 4595
# processing row 4600
# processing row 4605
# processing row 4610
# processing row 4615
# processing row 4620
# processing row 4625
# processing row 4630
# processing row 4635
# processing row 4640
# processing row 4645
# processing row 4650
# processing row 4655
# processing row 4660
# processing row 4665
# processing row 4670
# processing row 4675
# processing row 4680
# processing row 4685
# processing row 4690
# processing row 4695
# processing row 4700
# processing row 4705
# processing row 4710
# processing row 4715
# processing row 4720
# processing row 4725
# processing row 4730
# processing row 4735
# processing row 4740
# processing row 4745
# processing row 4750
# processing row 4755
# processing row 4760
# processing row 4765
# processing row 4770
# processing row 4775
# processing row 4780
# processing row 4785
# processing row 4790
# processing row 4795
# processing row 4800
# processing row 4805
# processing row 4810
# processing row 4815
# processing row 4820
# processing row 4825
# processing row 4830
# processing row 4835
# processing row 4840
# processing row 4845
# processing row 4850
# processing row 4855
# processing row 4860
# processing row 4865
# processing row 4870
# processing row 4875
# processing row 4880
# processing row 4885
# processing row 4890
# processing row 4895
# processing row 4900
# processing row 4905
# processing row 4910
# processing row 4915
# processing row 4920
# processing row 4925
# processing row 4930
# processing row 4935
# processing row 4940
# processing row 4945
# processing row 4950
# processing row 4955
# processing row 4960
# processing row 4965
# processing row 4970
# processing row 4975
# processing row 4980
# processing row 4985
# processing row 4990
# processing row 4995
# processing row 5000
# processing row 5005
# processing row 5010
# processing row 5015
# processing row 5020
# processing row 5025
# processing row 5030
# processing row 5035
# processing row 5040
# processing row 5045
# processing row 5050
# processing row 5055
# processing row 5060
# processing row 5065
# processing row 5070
# processing row 5075
# processing row 5080
# processing row 5085
# processing row 5090
# processing row 5095
# processing row 5100
# processing row 5105
# processing row 5110
# processing row 5115
# processing row 5120
# processing row 5125
# processing row 5130
# processing row 5135
# processing row 5140
# processing row 5145
# processing row 5150
# processing row 5155
# processing row 5160
# processing row 5165
# processing row 5170
# processing row 5175
# processing row 5180
# processing row 5185
# processing row 5190
# processing row 5195
# processing row 5200
# processing row 5205
# processing row 5210
# processing row 5215
# processing row 5220
# processing row 5225
# processing row 5230
# processing row 5235
# processing row 5240
# processing row 5245
# processing row 5250
# processing row 5255
# processing row 5260
# processing row 5265
# processing row 5270
# processing row 5275
# processing row 5280
# processing row 5285
# processing row 5290
# processing row 5295
# processing row 5300
# processing row 5305
# processing row 5310
# processing row 5315
# processing row 5320
# processing row 5325
# processing row 5330
# processing row 5335
# processing row 5340
# processing row 5345
# processing row 5350
# processing row 5355
# processing row 5360
# processing row 5365
# processing row 5370
# processing row 5375
# processing row 5380
# processing row 5385
# processing row 5390
# processing row 5395
# processing row 5400
# processing row 5405
# processing row 5410
# processing row 5415
# processing row 5420
# processing row 5425
# processing row 5430
# processing row 5435
# processing row 5440
# processing row 5445
# processing row 5450
# processing row 5455
# processing row 5460
# processing row 5465
# processing row 5470
# processing row 5475
# processing row 5480
# processing row 5485
# processing row 5490
# processing row 5495
# processing row 5500
# processing row 5505
# processing row 5510
# processing row 5515
# processing row 5520
# processing row 5525
# processing row 5530
# processing row 5535
# processing row 5540
# processing row 5545
# processing row 5550
# processing row 5555
# processing row 5560
# processing row 5565
# processing row 5570
# processing row 5575
# processing row 5580
# processing row 5585
# processing row 5590
# processing row 5595
# processing row 5600
# processing row 5605
# processing row 5610
# processing row 5615
# processing row 5620
# processing row 5625
# processing row 5630
# processing row 5635
# processing row 5640
# processing row 5645
# processing row 5650
# processing row 5655
# processing row 5660
# processing row 5665
# processing row 5670
# processing row 5675
# processing row 5680
# processing row 5685
# processing row 5690
# processing row 5695
# processing row 5700
# processing row 5705
# processing row 5710
# processing row 5715
# processing row 5720
# processing row 5725
# processing row 5730
# processing row 5735
# processing row 5740
# processing row 5745
# processing row 5750
# processing row 5755
# processing row 5760
# processing row 5765
# processing row 5770
# processing row 5775
# processing row 5780
# processing row 5785
# processing row 5790
# processing row 5795
# processing row 5800
# processing row 5805
# processing row 5810
# processing row 5815
# processing row 5820
# processing row 5825
# processing row 5830
# processing row 5835
# processing row 5840
# processing row 5845
# processing row 5850
# processing row 5855
# processing row 5860
# processing row 5865
# processing row 5870
# processing row 5875
# processing row 5880
# processing row 5885
# processing row 5890
# processing row 5895
# processing row 5900
# processing row 5905
# processing row 5910
# processing row 5915
# processing row 5920
# processing row 5925
# processing row 5930
# processing row 5935
# processing row 5940
# processing row 5945
# processing row 5950
# processing row 5955
# processing row 5960
# processing row 5965
# processing row 5970
# processing row 5975
# processing row 5980
# processing row 5985
# processing row 5990
# processing row 5995
# processing row 6000
# processing row 6005
# processing row 6010
# processing row 6015
# processing row 6020
# processing row 6025
# processing row 6030
# processing row 6035
# processing row 6040
# processing row 6045
# processing row 6050
# processing row 6055
# processing row 6060
# processing row 6065
# processing row 6070
# processing row 6075
# processing row 6080
# processing row 6085
# processing row 6090
# processing row 6095
# processing row 6100
# processing row 6105
# processing row 6110
# processing row 6115
# processing row 6120
# processing row 6125
# processing row 6130
# processing row 6135
# processing row 6140
# processing row 6145
# processing row 6150
# processing row 6155
# processing row 6160
# processing row 6165
# processing row 6170
# processing row 6175
# processing row 6180
# processing row 6185
# processing row 6190
# processing row 6195
# processing row 6200
# processing row 6205
# processing row 6210
# processing row 6215
# processing row 6220
# processing row 6225
# processing row 6230
# processing row 6235
# processing row 6240
# processing row 6245
# processing row 6250
# processing row 6255
# processing row 6260
# processing row 6265
# processing row 6270
# processing row 6275
# processing row 6280
# processing row 6285
# processing row 6290
# processing row 6295
# processing row 6300
# processing row 6305
# processing row 6310
# processing row 6315
# processing row 6320
# processing row 6325
# processing row 6330
# processing row 6335
# processing row 6340
# processing row 6345
# processing row 6350
# processing row 6355
# processing row 6360
# processing row 6365
# processing row 6370
# processing row 6375
# processing row 6380
# processing row 6385
# processing row 6390
# processing row 6395
# processing row 6400
# processing row 6405
# processing row 6410
# processing row 6415
# processing row 6420
# processing row 6425
# processing row 6430
# processing row 6435
# processing row 6440
# processing row 6445
# processing row 6450
# processing row 6455
# processing row 6460
# processing row 6465
# processing row 6470
# processing row 6475
# processing row 6480
# processing row 6485
# processing row 6490
# processing row 6495
# processing row 6500
# processing row 6505
# processing row 6510
# processing row 6515
# processing row 6520
# processing row 6525
# processing row 6530
# processing row 6535
# processing row 6540
# processing row 6545
# processing row 6550
# processing row 6555
# processing row 6560
# processing row 6565
# processing row 6570
# processing row 6575
# processing row 6580
# processing row 6585
# processing row 6590
# processing row 6595
# processing row 6600
# processing row 6605
# processing row 6610
# processing row 6615
# processing row 6620
# processing row 6625
# processing row 6630
# processing row 6635
# processing row 6640
# processing row 6645
# processing row 6650
# processing row 6655
# processing row 6660
# processing row 6665
# processing row 6670
# processing row 6675
# processing row 6680
# processing row 6685
# processing row 6690
# processing row 6695
# processing row 6700
# processing row 6705
# processing row 6710
# processing row 6715
# processing row 6720
# processing row 6725
# processing row 6730
# processing row 6735
# processing row 6740
# processing row 6745
# processing row 6750
# processing row 6755
# processing row 6760
# processing row 6765
# processing row 6770
# processing row 6775
# processing row 6780
# processing row 6785
# processing row 6790
# processing row 6795
# processing row 6800
# processing row 6805
# processing row 6810
# processing row 6815
# processing row 6820
# processing row 6825
# processing row 6830
# processing row 6835
# processing row 6840
# processing row 6845
# processing row 6850
# processing row 6855
# processing row 6860
# processing row 6865
# processing row 6870
# processing row 6875
# processing row 6880
# processing row 6885
# processing row 6890
# processing row 6895
# processing row 6900
# processing row 6905
# processing row 6910
# processing row 6915
# processing row 6920
# processing row 6925
# processing row 6930
# processing row 6935
# processing row 6940
# processing row 6945
# processing row 6950
# processing row 6955
# processing row 6960
# processing row 6965
# processing row 6970
# processing row 6975
# processing row 6980
# processing row 6985
# processing row 6990
# processing row 6995
# processing row 7000
# processing row 7005
# processing row 7010
# processing row 7015
# processing row 7020
# processing row 7025
# processing row 7030
# processing row 7035
# processing row 7040
# processing row 7045
# processing row 7050
# processing row 7055
# processing row 7060
# processing row 7065
# processing row 7070
# processing row 7075
# processing row 7080
# processing row 7085
# processing row 7090
# processing row 7095
# processing row 7100
# processing row 7105
# processing row 7110
# processing row 7115
# processing row 7120
# processing row 7125
# processing row 7130
# processing row 7135
# processing row 7140
# processing row 7145
# processing row 7150
# processing row 7155
# processing row 7160
# processing row 7165
# processing row 7170
# processing row 7175
# processing row 7180
# processing row 7185
# processing row 7190
# processing row 7195
# processing row 7200
# processing row 7205
# processing row 7210
# processing row 7215
# processing row 7220
# processing row 7225
# processing row 7230
# processing row 7235
# processing row 7240
# processing row 7245
# processing row 7250
# processing row 7255
# processing row 7260
# processing row 7265
# processing row 7270
# processing row 7275
# processing row 7280
# processing row 7285
# processing row 7290
# processing row 7295
# processing row 7300
# processing row 7305
# processing row 7310
# processing row 7315
# processing row 7320
# processing row 7325
# processing row 7330
# processing row 7335
# processing row 7340
# processing row 7345
# processing row 7350
# processing row 7355
# processing row 7360
# processing row 7365
# processing row 7370
# processing row 7375
# processing row 7380
# processing row 7385
# processing row 7390
# processing row 7395
# processing row 7400
# processing row 7405
# processing row 7410
# processing row 7415
# processing row 7420
# processing row 7425
# processing row 7430
# processing row 7435
# processing row 7440
# processing row 7445
# processing row 7450
# processing row 7455
# processing row 7460
# processing row 7465
# processing row 7470
# processing row 7475
# processing row 7480
# processing row 7485
# processing row 7490
# processing row 7495
# processing row 7500
# processing row 7505
# processing row 7510
# processing row 7515
# processing row 7520
# processing row 7525
# processing row 7530
# processing row 7535
# processing row 7540
# processing row 7545
# processing row 7550
# processing row 7555
# processing row 7560
# processing row 7565
# processing row 7570
# processing row 7575
# processing row 7580
# processing row 7585
# processing row 7590
# processing row 7595
# processing row 7600
# processing row 7605
# processing row 7610
# processing row 7615
# processing row 7620
# processing row 7625
# processing row 7630
# processing row 7635
# processing row 7640
# processing row 7645
# processing row 7650
# processing row 7655
# processing row 7660
# processing row 7665
# processing row 7670
# processing row 7675
# processing row 7680
# processing row 7685
# processing row 7690
# processing row 7695
# processing row 7700
# processing row 7705
# processing row 7710
# processing row 7715
# processing row 7720
# processing row 7725
# processing row 7730
# processing row 7735
# processing row 7740
# processing row 7745
# processing row 7750
# processing row 7755
# processing row 7760
# processing row 7765
# processing row 7770
# processing row 7775
# processing row 7780
# processing row 7785
# processing row 7790
# processing row 7795
# processing row 7800
# processing row 7805
# processing row 7810
# processing row 7815
# processing row 7820
# processing row 7825
# processing row 7830
# processing row 7835
# processing row 7840
# processing row 7845
# processing row 7850
# processing row 7855
# processing row 7860
# processing row 7865
# processing row 7870
# processing row 7875
# processing row 7880
# processing row 7885
# processing row 7890
# processing row 7895
# processing row 7900
# processing row 7905
# processing row 7910
# processing row 7915
# processing row 7920
# processing row 7925
# processing row 7930
# processing row 7935
# processing row 7940
# processing row 7945
# processing row 7950
# processing row 7955
# processing row 7960
# processing row 7965
# processing row 7970
# processing row 7975
# processing row 7980
# processing row 7985
# processing row 7990
# processing row 7995
# processing row 8000
# processing row 8005
# processing row 8010
# processing row 8015
# processing row 8020
# processing row 8025
# processing row 8030
# processing row 8035
# processing row 8040
# processing row 8045
# processing row 8050
# processing row 8055
# processing row 8060
# processing row 8065
# processing row 8070
# processing row 8075
# processing row 8080
# processing row 8085
# processing row 8090
# processing row 8095
# processing row 8100
# processing row 8105
# processing row 8110
# processing row 8115
# processing row 8120
# processing row 8125
# processing row 8130
# processing row 8135
# processing row 8140
# processing row 8145
# processing row 8150
# processing row 8155
# processing row 8160
# processing row 8165
# processing row 8170
# processing row 8175
# processing row 8180
# processing row 8185
# processing row 8190
# processing row 8195
# processing row 8200
# processing row 8205
# processing row 8210
# processing row 8215
# processing row 8220
# processing row 8225
# processing row 8230
# processing row 8235
# processing row 8240
# processing row 8245
# processing row 8250
# processing row 8255
# processing row 8260
# processing row 8265
# processing row 8270
# processing row 8275
# processing row 8280
# processing row 8285
# processing row 8290
# processing row 8295
# processing row 8300
# processing row 8305
# processing row 8310
# processing row 8315
# processing row 8320
# processing row 8325
# processing row 8330
# processing row 8335
# processing row 8340
# processing row 8345
# processing row 8350
# processing row 8355
# processing row 8360
# processing row 8365
# processing row 8370
# processing row 8375
# processing row 8380
# processing row 8385
# processing row 8390
# processing row 8395
# processing row 8400
# processing row 8405
# processing row 8410
# processing row 8415
# processing row 8420
# processing row 8425
# processing row 8430
# processing row 8435
# processing row 8440
# processing row 8445
# processing row 8450
# processing row 8455
# processing row 8460
# processing row 8465
# processing row 8470
# processing row 8475
# processing row 8480
# processing row 8485
# processing row 8490
# processing row 8495
# processing row 8500
# processing row 8505
# processing row 8510
# processing row 8515
# processing row 8520
# processing row 8525
# processing row 8530
# processing row 8535
# processing row 8540
# processing row 8545
# processing row 8550
# processing row 8555
# processing row 8560
# processing row 8565
# processing row 8570
# processing row 8575
# processing row 8580
# processing row 8585
# processing row 8590
# processing row 8595
# processing row 8600
# processing row 8605
# processing row 8610
# processing row 8615
# processing row 8620
# processing row 8625
# processing row 8630
# processing row 8635
# processing row 8640
# processing row 8645
# processing row 8650
# processing row 8655
# processing row 8660
# processing row 8665
# processing row 8670
# processing row 8675
# processing row 8680
# processing row 8685
# processing row 8690
# processing row 8695
# processing row 8700
# processing row 8705
# processing row 8710
# processing row 8715
# processing row 8720
# processing row 8725
# processing row 8730
# processing row 8735
# processing row 8740
# processing row 8745
# processing row 8750
# processing row 8755
# processing row 8760
# processing row 8765
# processing row 8770
# processing row 8775
# processing row 8780
# processing row 8785
# processing row 8790
# processing row 8795
# processing row 8800
# processing row 8805
# processing row 8810
# processing row 8815
# processing row 8820
# processing row 8825
# processing row 8830
# processing row 8835
# processing row 8840
# processing row 8845
# processing row 8850
# processing row 8855
# processing row 8860
# processing row 8865
# processing row 8870
# processing row 8875
# processing row 8880
# processing row 8885
# processing row 8890
# processing row 8895
# processing row 8900
# processing row 8905
# processing row 8910
# processing row 8915
# processing row 8920
# processing row 8925
# processing row 8930
# processing row 8935
# processing row 8940
# processing row 8945
# processing row 8950
# processing row 8955
# processing row 8960
# processing row 8965
# processing row 8970
# processing row 8975
# processing row 8980
# processing row 8985
# processing row 8990
# processing row 8995
# processing row 9000
# processing row 9005
# processing row 9010
# processing row 9015
# processing row 9020
# processing row 9025
# processing row 9030
# processing row 9035
# processing row 9040
# processing row 9045
# processing row 9050
# processing row 9055
# processing row 9060
# processing row 9065
# processing row 9070
# processing row 9075
# processing row 9080
# processing row 9085
# processing row 9090
# processing row 9095
# processing row 9100
# processing row 9105
# processing row 9110
# processing row 9115
# processing row 9120
# processing row 9125
# processing row 9130
# processing row 9135
# processing row 9140
# processing row 9145
# processing row 9150
# processing row 9155
# processing row 9160
# processing row 9165
# processing row 9170
# processing row 9175
# processing row 9180
# processing row 9185
# processing row 9190
# processing row 9195
# processing row 9200
# processing row 9205
# processing row 9210
# processing row 9215
# processing row 9220
# processing row 9225
# processing row 9230
# processing row 9235
# processing row 9240
# processing row 9245
# processing row 9250
# processing row 9255
# processing row 9260
# processing row 9265
# processing row 9270
# processing row 9275
# processing row 9280
# processing row 9285
# processing row 9290
# processing row 9295
# processing row 9300
# processing row 9305
# processing row 9310
# processing row 9315
# processing row 9320
# processing row 9325
# processing row 9330
# processing row 9335
# processing row 9340
# processing row 9345
# processing row 9350
# processing row 9355
# processing row 9360
# processing row 9365
# processing row 9370
# processing row 9375
# processing row 9380
# processing row 9385
# processing row 9390
# processing row 9395
# processing row 9400
# processing row 9405
# processing row 9410
# processing row 9415
# processing row 9420
# processing row 9425
# processing row 9430
# processing row 9435
# processing row 9440
# processing row 9445
# processing row 9450
# processing row 9455
# processing row 9460
# processing row 9465
# processing row 9470
# processing row 9475
# processing row 9480
# processing row 9485
# processing row 9490
# processing row 9495
# processing row 9500
# processing row 9505
# processing row 9510
# processing row 9515
# processing row 9520
# processing row 9525
# processing row 9530
# processing row 9535
# processing row 9540
# processing row 9545
# processing row 9550
# processing row 9555
# processing row 9560
# processing row 9565
# processing row 9570
# processing row 9575
# processing row 9580
# processing row 9585
# processing row 9590
# processing row 9595
# processing row 9600
# processing row 9605
# processing row 9610
# processing row 9615
# processing row 9620
# processing row 9625
# processing row 9630
# processing row 9635
# processing row 9640
# processing row 9645
# processing row 9650
# processing row 9655
# processing row 9660
# processing row 9665
# processing row 9670
# processing row 9675
# processing row 9680
# processing row 9685
# processing row 9690
# processing row 9695
# processing row 9700
# processing row 9705
# processing row 9710
# processing row 9715
# processing row 9720
# processing row 9725
# processing row 9730
# processing row 9735
# processing row 9740
# processing row 9745
# processing row 9750
# processing row 9755
# processing row 9760
# processing row 9765
# processing row 9770
# processing row 9775
# processing row 9780
# processing row 9785
# processing row 9790
# processing row 9795
# processing row 9800
# processing row 9805
# processing row 9810
# processing row 9815
# processing row 9820
# processing row 9825
# processing row 9830
# processing row 9835
# processing row 9840
# processing row 9845
# processing row 9850
# processing row 9855
# processing row 9860
# processing row 9865
# processing row 9870
# processing row 9875
# processing row 9880
# processing row 9885
# processing row 9890
# processing row 9895
# processing row 9900
# processing row 9905
# processing row 9910
# processing row 9915
# processing row 9920
# processing row 9925
# processing row 9930
# processing row 9935
# processing row 9940
# processing row 9945
# processing row 9950
# processing row 9955
# processing row 9960
# processing row 9965
# processing row 9970
# processing row 9975
# processing row 9980
# processing row 9985
# processing row 9990
# processing row 9995
# processing row 10000
# processing row 10005
# processing row 10010
# processing row 10015
# processing row 10020
# processing row 10025
# processing row 10030
# processing row 10035
# processing row 10040
# processing row 10045
# processing row 10050
# processing row 10055
# processing row 10060
# processing row 10065
# processing row 10070
# processing row 10075
# processing row 10080
# processing row 10085
# processing row 10090
# processing row 10095
# processing row 10100
# processing row 10105
# processing row 10110
# processing row 10115
# processing row 10120
# processing row 10125
# processing row 10130
# processing row 10135
# processing row 10140
# processing row 10145
# processing row 10150
# processing row 10155
# processing row 10160
# processing row 10165
# processing row 10170
# processing row 10175
# processing row 10180
# processing row 10185
# processing row 10190
# processing row 10195
# processing row 10200
# processing row 10205
# processing row 10210
# processing row 10215
# processing row 10220
# processing row 10225
# processing row 10230
# processing row 10235
# processing row 10240
# processing row 10245
# processing row 10250
# processing row 10255
# processing row 10260
# processing row 10265
# processing row 10270
# processing row 10275
# processing row 10280
# processing row 10285
# processing row 10290
# processing row 10295
# processing row 10300
# processing row 10305
# processing row 10310
# processing row 10315
# processing row 10320
# processing row 10325
# processing row 10330
# processing row 10335
# processing row 10340
# processing row 10345
# processing row 10350
# processing row 10355
# processing row 10360
# processing row 10365
# processing row 10370
# processing row 10375
# processing row 10380
# processing row 10385
# processing row 10390
# processing row 10395
# processing row 10400
# processing row 10405
# processing row 10410
# processing row 10415
# processing row 10420
# processing row 10425
# processing row 10430
# processing row 10435
# processing row 10440
# processing row 10445
# processing row 10450
# processing row 10455
# processing row 10460
# processing row 10465
# processing row 10470
# processing row 10475
# processing row 10480
# processing row 10485
# processing row 10490
# processing row 10495
# processing row 10500
# processing row 10505
# processing row 10510
# processing row 10515
# processing row 10520
# processing row 10525
# processing row 10530
# processing row 10535
# processing row 10540
# processing row 10545
# processing row 10550
# processing row 10555
# processing row 10560
# processing row 10565
# processing row 10570
# processing row 10575
# processing row 10580
# processing row 10585
# processing row 10590
# processing row 10595
# processing row 10600
# processing row 10605
# processing row 10610
# processing row 10615
# processing row 10620
# processing row 10625
# processing row 10630
# processing row 10635
# processing row 10640
# processing row 10645
# processing row 10650
# processing row 10655
# processing row 10660
# processing row 10665
# processing row 10670
# processing row 10675
# processing row 10680
# processing row 10685
# processing row 10690
# processing row 10695
# processing row 10700
# processing row 10705
# processing row 10710
# processing row 10715
# processing row 10720
# processing row 10725
# processing row 10730
# processing row 10735
# processing row 10740
# processing row 10745
# processing row 10750
# processing row 10755
# processing row 10760
# processing row 10765
# processing row 10770
# processing row 10775
# processing row 10780
# processing row 10785
# processing row 10790
# processing row 10795
# processing row 10800
# processing row 10805
# processing row 10810
# processing row 10815
# processing row 10820
# processing row 10825
# processing row 10830
# processing row 10835
# processing row 10840
# processing row 10845
# processing row 10850
# processing row 10855
# processing row 10860
# processing row 10865
# processing row 10870
# processing row 10875
# processing row 10880
# processing row 10885
# processing row 10890
# processing row 10895
# processing row 10900
# processing row 10905
# processing row 10910
# processing row 10915
# processing row 10920
# processing row 10925
# processing row 10930
# processing row 10935
# processing row 10940
# processing row 10945
# processing row 10950
# processing row 10955
# processing row 10960
# processing row 10965
# processing row 10970
# processing row 10975
# processing row 10980
# processing row 10985
# processing row 10990
# processing row 10995
# processing row 11000
# processing row 11005
# processing row 11010
# processing row 11015
# processing row 11020
# processing row 11025
# processing row 11030
# processing row 11035
# processing row 11040
# processing row 11045
# processing row 11050
# processing row 11055
# processing row 11060
# processing row 11065
# processing row 11070
# processing row 11075
# processing row 11080
# processing row 11085
# processing row 11090
# processing row 11095
# processing row 11100
# processing row 11105
# processing row 11110
# processing row 11115
# processing row 11120
# processing row 11125
# processing row 11130
# processing row 11135
# processing row 11140
# processing row 11145
# processing row 11150
# processing row 11155
# processing row 11160
# processing row 11165
# processing row 11170
# processing row 11175
# processing row 11180
# processing row 11185
# processing row 11190
# processing row 11195
# processing row 11200
# processing row 11205
# processing row 11210
# processing row 11215
# processing row 11220
# processing row 11225
# processing row 11230
# processing row 11235
# processing row 11240
# processing row 11245
# processing row 11250
# processing row 11255
# processing row 11260
# processing row 11265
# processing row 11270
# processing row 11275
# processing row 11280
# processing row 11285
# processing row 11290
# processing row 11295
# processing row 11300
# processing row 11305
# processing row 11310
# processing row 11315
# processing row 11320
# processing row 11325
# processing row 11330
# processing row 11335
# processing row 11340
# processing row 11345
# processing row 11350
# processing row 11355
# processing row 11360
# processing row 11365
# processing row 11370
# processing row 11375
# processing row 11380
# processing row 11385
# processing row 11390
# processing row 11395
# processing row 11400
# processing row 11405
# processing row 11410
# processing row 11415
# processing row 11420
# processing row 11425
# processing row 11430
# processing row 11435
# processing row 11440
# processing row 11445
# processing row 11450
# processing row 11455
# processing row 11460
# processing row 11465
# processing row 11470
# processing row 11475
# processing row 11480
# processing row 11485
# processing row 11490
# processing row 11495
# processing row 11500
# processing row 11505
# processing row 11510
# processing row 11515
# processing row 11520
# processing row 11525
# processing row 11530
# processing row 11535
# processing row 11540
# processing row 11545
# processing row 11550
# processing row 11555
# processing row 11560
# processing row 11565
# processing row 11570
# processing row 11575
# processing row 11580
# processing row 11585
# processing row 11590
# processing row 11595
# processing row 11600
# processing row 11605
# processing row 11610
# processing row 11615
# processing row 11620
# processing row 11625
# processing row 11630
# processing row 11635
# processing row 11640
# processing row 11645
# processing row 11650
# processing row 11655
# processing row 11660
# processing row 11665
# processing row 11670
# processing row 11675
# processing row 11680
# processing row 11685
# processing row 11690
# processing row 11695
# processing row 11700
# processing row 11705
# processing row 11710
# processing row 11715
# processing row 11720
# processing row 11725
# processing row 11730
# processing row 11735
# processing row 11740
# processing row 11745
# processing row 11750
# processing row 11755
# processing row 11760
# processing row 11765
# processing row 11770
# processing row 11775
# processing row 11780
# processing row 11785
# processing row 11790
# processing row 11795
# processing row 11800
# processing row 11805
# processing row 11810
# processing row 11815
# processing row 11820
# processing row 11825
# processing row 11830
# processing row 11835
# processing row 11840
# processing row 11845
# processing row 11850
# processing row 11855
# processing row 11860
# processing row 11865
# processing row 11870
# processing row 11875
# processing row 11880
# processing row 11885
# processing row 11890
# processing row 11895
# processing row 11900
# processing row 11905
# processing row 11910
# processing row 11915
# processing row 11920
# processing row 11925
# processing row 11930
# processing row 11935
# processing row 11940
# processing row 11945
# processing row 11950
# ...
# processing row 16260
# processing row 16265
# processing row 16270
# processing row 16275
# processing row 16280
# processing row 16285
# processing row 16290
# processing row 16295
# processing row 16300
# processing row 16305
# processing row 16310
# processing row 16315
# processing row 16320
# processing row 16325
# processing row 16330
# processing row 16335
# processing row 16340
# processing row 16345
# processing row 16350
# processing row 16355
# processing row 16360
# processing row 16365
# processing row 16370
# processing row 16375
# processing row 16380
# processing row 16385
# processing row 16390
# processing row 16395
# processing row 16400
# processing row 16405
# processing row 16410
# processing row 16415
# processing row 16420
# processing row 16425
# processing row 16430
# processing row 16435
# processing row 16440
# processing row 16445
# processing row 16450
# processing row 16455
# processing row 16460
# processing row 16465
# processing row 16470
# processing row 16475
# processing row 16480
# processing row 16485
# processing row 16490
# processing row 16495
# processing row 16500
# processing row 16505
# processing row 16510
# processing row 16515
# processing row 16520
# processing row 16525
# processing row 16530
# processing row 16535
# processing row 16540
# processing row 16545
# processing row 16550
# processing row 16555
# processing row 16560
# processing row 16565
# processing row 16570
# processing row 16575
# processing row 16580
# processing row 16585
# processing row 16590
# processing row 16595
# processing row 16600
# processing row 16605
# processing row 16610
# processing row 16615
# processing row 16620
# processing row 16625
# processing row 16630
# processing row 16635
# processing row 16640
# processing row 16645
# processing row 16650
# processing row 16655
# processing row 16660
# processing row 16665
# processing row 16670
# processing row 16675
# processing row 16680
# processing row 16685
# processing row 16690
# processing row 16695
# processing row 16700
# processing row 16705
# processing row 16710
# processing row 16715
# processing row 16720
# processing row 16725
# processing row 16730
# processing row 16735
# processing row 16740
# processing row 16745
# processing row 16750
# processing row 16755
# processing row 16760
# processing row 16765
# processing row 16770
# processing row 16775
# processing row 16780
# processing row 16785
# processing row 16790
# processing row 16795
# processing row 16800
# processing row 16805
# processing row 16810
# processing row 16815
# processing row 16820
# processing row 16825
# processing row 16830
# processing row 16835
# processing row 16840
# processing row 16845
# processing row 16850
# processing row 16855
# processing row 16860
# processing row 16865
# processing row 16870
# processing row 16875
# processing row 16880
# processing row 16885
# processing row 16890
# processing row 16895
# processing row 16900
# processing row 16905
# processing row 16910
# processing row 16915
# processing row 16920
# processing row 16925
# processing row 16930
# processing row 16935
# processing row 16940
# processing row 16945
# processing row 16950
# processing row 16955
# processing row 16960
# processing row 16965
# processing row 16970
# processing row 16975
# processing row 16980
# processing row 16985
# processing row 16990
# processing row 16995
# processing row 17000
# processing row 17005
# processing row 17010
# processing row 17015
# processing row 17020
# processing row 17025
# processing row 17030
# processing row 17035
# processing row 17040
# processing row 17045
# processing row 17050
# processing row 17055
# processing row 17060
# processing row 17065
# processing row 17070
# processing row 17075
# processing row 17080
# processing row 17085
# processing row 17090
# processing row 17095
# processing row 17100
# processing row 17105
# processing row 17110
# processing row 17115
# processing row 17120
# processing row 17125
# processing row 17130
# processing row 17135
# processing row 17140
# processing row 17145
# processing row 17150
# processing row 17155
# processing row 17160
# processing row 17165
# processing row 17170
# processing row 17175
# processing row 17180
# processing row 17185
# processing row 17190
# processing row 17195
# processing row 17200
# processing row 17205
# processing row 17210
# processing row 17215
# processing row 17220
# processing row 17225
# processing row 17230
# processing row 17235
# processing row 17240
# processing row 17245
# processing row 17250
# processing row 17255
# processing row 17260
# processing row 17265
# processing row 17270
# processing row 17275
# processing row 17280
# processing row 17285
# processing row 17290
# processing row 17295
# processing row 17300
# processing row 17305
# processing row 17310
# processing row 17315
# processing row 17320
# processing row 17325
# processing row 17330
# processing row 17335
# processing row 17340
# processing row 17345
# processing row 17350
# processing row 17355
# processing row 17360
# processing row 17365
# processing row 17370
# processing row 17375
# processing row 17380
# processing row 17385
# processing row 17390
# processing row 17395
# processing row 17400
# processing row 17405
# processing row 17410
# processing row 17415
# processing row 17420
# processing row 17425
# processing row 17430
# processing row 17435
# processing row 17440
# processing row 17445
# processing row 17450
# processing row 17455
# processing row 17460
# processing row 17465
# processing row 17470
# processing row 17475
# processing row 17480
# processing row 17485
# processing row 17490
# processing row 17495
# processing row 17500
# processing row 17505
# processing row 17510
# processing row 17515
# processing row 17520
# processing row 17525
# processing row 17530
# processing row 17535
# processing row 17540
# processing row 17545
# processing row 17550
# processing row 17555
# processing row 17560
# processing row 17565
# processing row 17570
# processing row 17575
# processing row 17580
# processing row 17585
# processing row 17590
# processing row 17595
# processing row 17600
# processing row 17605
# processing row 17610
# processing row 17615
# processing row 17620
# processing row 17625
# processing row 17630
# processing row 17635
# processing row 17640
# processing row 17645
# processing row 17650
# processing row 17655
# processing row 17660
# processing row 17665
# processing row 17670
# processing row 17675
# processing row 17680
# processing row 17685
# processing row 17690
# processing row 17695
# processing row 17700
# processing row 17705
# processing row 17710
# processing row 17715
# processing row 17720
# processing row 17725
# processing row 17730
# processing row 17735
# processing row 17740
# processing row 17745
# processing row 17750
# processing row 17755
# processing row 17760
# processing row 17765
# processing row 17770
# processing row 17775
# processing row 17780
# processing row 17785
# processing row 17790
# processing row 17795
# processing row 17800
# processing row 17805
# processing row 17810
# processing row 17815
# processing row 17820
# processing row 17825
# processing row 17830
# processing row 17835
# processing row 17840
# processing row 17845
# processing row 17850
# processing row 17855
# processing row 17860
# processing row 17865
# processing row 17870
# processing row 17875
# processing row 17880
# processing row 17885
# processing row 17890
# processing row 17895
# processing row 17900
# processing row 17905
# processing row 17910
# processing row 17915
# processing row 17920
# processing row 17925
# processing row 17930
# processing row 17935
# processing row 17940
# processing row 17945
# processing row 17950
# processing row 17955
# processing row 17960
# processing row 17965
# processing row 17970
# processing row 17975
# processing row 17980
# processing row 17985
# processing row 17990
# processing row 17995
# processing row 18000
# processing row 18005
# processing row 18010
# processing row 18015
# processing row 18020
# processing row 18025
# processing row 18030
# processing row 18035
# processing row 18040
# processing row 18045
# processing row 18050
# processing row 18055
# processing row 18060
# processing row 18065
# processing row 18070
# processing row 18075
# processing row 18080
# processing row 18085
# processing row 18090
# processing row 18095
# processing row 18100
# processing row 18105
# processing row 18110
# processing row 18115
# processing row 18120
# processing row 18125
# processing row 18130
# processing row 18135
# processing row 18140
# processing row 18145
# processing row 18150
# processing row 18155
# processing row 18160
# processing row 18165
# processing row 18170
# processing row 18175
# processing row 18180
# processing row 18185
# processing row 18190
# processing row 18195
# processing row 18200
# processing row 18205
# processing row 18210
# processing row 18215
# processing row 18220
# processing row 18225
# processing row 18230
# processing row 18235
# processing row 18240
# processing row 18245
# processing row 18250
# processing row 18255
# processing row 18260
# processing row 18265
# processing row 18270
# processing row 18275
# processing row 18280
# processing row 18285
# processing row 18290
# processing row 18295
# processing row 18300
# processing row 18305
# processing row 18310
# processing row 18315
# processing row 18320
# processing row 18325
# processing row 18330
# processing row 18335
# processing row 18340
# processing row 18345
# processing row 18350
# processing row 18355
# processing row 18360
# processing row 18365
# processing row 18370
# processing row 18375
# processing row 18380
# processing row 18385
# processing row 18390
# processing row 18395
# processing row 18400
# processing row 18405
# processing row 18410
# processing row 18415
# processing row 18420
# processing row 18425
# processing row 18430
# processing row 18435
# processing row 18440
# processing row 18445
# processing row 18450
# processing row 18455
# processing row 18460
# processing row 18465
# processing row 18470
# processing row 18475
# processing row 18480
# processing row 18485
# processing row 18490
# processing row 18495
# processing row 18500
# processing row 18505
# processing row 18510
# processing row 18515
# processing row 18520
# processing row 18525
# processing row 18530
# processing row 18535
# processing row 18540
# processing row 18545
# processing row 18550
# processing row 18555
# processing row 18560
# processing row 18565
# processing row 18570
# processing row 18575
# processing row 18580
# processing row 18585
# processing row 18590
# processing row 18595
# processing row 18600
# processing row 18605
# processing row 18610
# processing row 18615
# processing row 18620
# processing row 18625
# processing row 18630
# processing row 18635
# processing row 18640
# processing row 18645
# processing row 18650
# processing row 18655
# processing row 18660
# processing row 18665
# processing row 18670
# processing row 18675
# processing row 18680
# processing row 18685
# processing row 18690
# processing row 18695
# processing row 18700
# processing row 18705
# processing row 18710
# processing row 18715
# processing row 18720
# processing row 18725
# processing row 18730
# processing row 18735
# processing row 18740
# processing row 18745
# processing row 18750
# processing row 18755
# processing row 18760
# processing row 18765
# processing row 18770
# processing row 18775
# processing row 18780
# processing row 18785
# processing row 18790
# processing row 18795
# processing row 18800
# processing row 18805
# processing row 18810
# processing row 18815
# processing row 18820
# processing row 18825
# processing row 18830
# processing row 18835
# processing row 18840
# processing row 18845
# processing row 18850
# processing row 18855
# processing row 18860
# processing row 18865
# processing row 18870
# processing row 18875
# processing row 18880
# processing row 18885
# processing row 18890
# processing row 18895
# processing row 18900
# processing row 18905
# processing row 18910
# processing row 18915
# processing row 18920
# processing row 18925
# processing row 18930
# processing row 18935
# processing row 18940
# processing row 18945
# processing row 18950
# processing row 18955
# processing row 18960
# processing row 18965
# processing row 18970
# processing row 18975
# processing row 18980
# processing row 18985
# processing row 18990
# processing row 18995
# processing row 19000
# processing row 19005
# processing row 19010
# processing row 19015
# processing row 19020
# processing row 19025
# processing row 19030
# processing row 19035
# processing row 19040
# processing row 19045
# processing row 19050
# processing row 19055
# processing row 19060
# processing row 19065
# processing row 19070
# processing row 19075
# processing row 19080
# processing row 19085
# processing row 19090
# processing row 19095
# processing row 19100
# processing row 19105
# processing row 19110
# processing row 19115
# processing row 19120
# processing row 19125
# processing row 19130
# processing row 19135
# processing row 19140
# processing row 19145
# processing row 19150
# processing row 19155
# processing row 19160
# processing row 19165
# processing row 19170
# processing row 19175
# processing row 19180
# processing row 19185
# processing row 19190
# processing row 19195
# processing row 19200
# processing row 19205
# processing row 19210
# processing row 19215
# processing row 19220
# processing row 19225
# processing row 19230
# processing row 19235
# processing row 19240
# processing row 19245
# processing row 19250
# processing row 19255
# processing row 19260
# processing row 19265
# processing row 19270
# processing row 19275
# processing row 19280
# processing row 19285
# processing row 19290
# processing row 19295
# processing row 19300
# processing row 19305
# processing row 19310
# processing row 19315
# processing row 19320
# processing row 19325
# processing row 19330
# processing row 19335
# processing row 19340
# processing row 19345
# processing row 19350
# processing row 19355
# processing row 19360
# processing row 19365
# processing row 19370
# processing row 19375
# processing row 19380
# processing row 19385
# processing row 19390
# processing row 19395
# processing row 19400
# processing row 19405
# processing row 19410
# processing row 19415
# processing row 19420
# processing row 19425
# processing row 19430
# processing row 19435
# processing row 19440
# processing row 19445
# processing row 19450
# processing row 19455
# processing row 19460
# processing row 19465
# processing row 19470
# processing row 19475
# processing row 19480
# processing row 19485
# processing row 19490
# processing row 19495
# processing row 19500
# processing row 19505
# processing row 19510
# processing row 19515
# processing row 19520
# processing row 19525
# processing row 19530
# processing row 19535
# processing row 19540
# processing row 19545
# processing row 19550
# processing row 19555
# processing row 19560
# processing row 19565
# processing row 19570
# processing row 19575
# processing row 19580
# processing row 19585
# processing row 19590
# processing row 19595
# processing row 19600
# processing row 19605
# processing row 19610
# processing row 19615
# processing row 19620
# processing row 19625
# processing row 19630
# processing row 19635
# processing row 19640
# processing row 19645
# processing row 19650
# processing row 19655
# processing row 19660
# processing row 19665
# processing row 19670
# processing row 19675
# processing row 19680
# processing row 19685
# processing row 19690
# processing row 19695
# processing row 19700
# processing row 19705
# processing row 19710
# processing row 19715
# processing row 19720
# processing row 19725
# processing row 19730
# processing row 19735
# processing row 19740
# processing row 19745
# processing row 19750
# processing row 19755
# processing row 19760
# processing row 19765
# processing row 19770
# processing row 19775
# processing row 19780
# processing row 19785
# processing row 19790
# processing row 19795
# processing row 19800
# processing row 19805
# processing row 19810
# processing row 19815
# processing row 19820
# processing row 19825
# processing row 19830
# processing row 19835
# processing row 19840
# processing row 19845
# processing row 19850
# processing row 19855
# processing row 19860
# processing row 19865
# processing row 19870
# processing row 19875
# processing row 19880
# processing row 19885
# processing row 19890
# processing row 19895
# processing row 19900
# processing row 19905
# processing row 19910
# processing row 19915
# processing row 19920
# processing row 19925
# processing row 19930
# processing row 19935
# processing row 19940
# processing row 19945
# processing row 19950
# processing row 19955
# processing row 19960
# processing row 19965
# processing row 19970
# processing row 19975
# processing row 19980
# processing row 19985
# processing row 19990
# processing row 19995
# processing row 20000
# processing row 20005
# processing row 20010
# processing row 20015
# processing row 20020
# processing row 20025
# processing row 20030
# processing row 20035
# processing row 20040
# processing row 20045
# processing row 20050
# processing row 20055
# processing row 20060

# %%
thirtyA.head(2)
# Out:
#                   time     open     high      low    close         %K  \
# 0  2019-01-06 22:00:00  138.091  138.179  138.011  138.020  81.448525
# 1  2019-01-06 22:30:00  138.020  138.084  137.922  138.074  77.059060
#
#           %D        RSI      Plot thirty_trend   4h_plot four_trend  \
# 0  86.245303  65.524837  0.070389      unknown  0.005608    unknown
# 1  82.185586  66.849987  0.061890      unknown  0.005608    unknown
#
#   candle_dir dt_signal sent_signal simple_result running_result  profit  \
# 0      short   unknown    no_trade      no_trade       no_trade     0.0
# 1       long      long    no_trade      no_trade       no_trade     0.0
#
#   no_sig_stop  ext_profit
# 0    no_trade         0.0
# 1    no_trade         0.0

# %%
#Let's compare total potential profits over the course over the available period

# %%
thirtyA.describe()
# Out:
#                open          high           low         close            %K  \
# count  20062.000000  20062.000000  20062.000000  20062.000000  20062.000000
# mean     138.144640    138.232240    138.054454    138.144777     50.219404
# std        5.233734      5.223079      5.244954      5.233700     26.257287
# min      124.966000    125.240000    124.044000    124.966000      0.843684
# 25%      134.010000    134.112500    133.893500    134.010000     26.828583
# 50%      138.221500    138.294000    138.134500    138.222000     50.213946
# 75%      142.714000    142.780000    142.643750    142.714000     73.591649
# max      148.781000    148.880000    148.515000    148.781000     98.952152
#
#                  %D           RSI          Plot       4h_plot        profit  \
# count  20062.000000  20062.000000  20062.000000  20062.000000  20062.000000
# mean      50.222958     49.932427     -0.000099      0.003688      0.001425
# std       25.473706     12.026455      0.043391      0.126595      0.041504
# min        1.435329     11.745697     -0.248254     -0.424180     -0.821000
# 25%       27.674665     41.935919     -0.024098     -0.068811      0.000000
# 50%       50.153327     49.905516     -0.000369      0.003843      0.000000
# 75%       72.804695     57.837821      0.021618      0.075193      0.000000
# max       98.222683     90.376228      0.357740      0.522878      0.170000
#
#          ext_profit
# count  20062.000000
# mean       0.008333
# std        0.093677
# min       -0.821000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        4.134000

# %%
thirtyA.profit.sum()
# Out:
# 28.591999999992865

# %%
thirtyA.ext_profit.sum()
# Out:
# 167.17949999999246

# %%
print(f'The total pip profit when restricting wins is {round(thirtyA.profit.sum(),2)} \n\
and the total pip profit when allowing wins to run is {round(thirtyA.ext_profit.sum(),2)} ')
# Out:
# The total pip profit when restricting wins is 28.59
# and the total pip profit when allowing wins to run is 167.18

# %% [markdown]
# So our original method allowed the potential of 2859 pips whereas unrestricted wins allows the potential of 16718 pips!!! That's in a period of 18 months.

# %%
#Let's compare our restricted wins with our extended wins
check2 = thirtyA[(thirtyA['simple_result']=='win') & (thirtyA['running_result']=='win')]

# %%
check2
# Out:
#                       time     open     high      low    close         %K  \
# 35     2019-01-07 15:30:00  138.578  138.687  138.346  138.492  89.649879
# 54     2019-01-08 01:00:00  138.949  138.976  138.678  138.743  69.958848
# 76     2019-01-08 12:00:00  138.888  138.930  138.722  138.810  27.874818
# 111    2019-01-09 05:30:00  138.732  138.732  138.654  138.704  75.143606
# 118    2019-01-09 09:00:00  139.010  139.074  138.936  138.969  82.223417
# ...                    ...      ...      ...      ...      ...        ...
# 19957  2020-08-12 16:30:00  139.472  139.529  139.326  139.344  63.569820
# 20000  2020-08-13 14:00:00  140.139  140.158  139.980  140.066  86.765256
# 20008  2020-08-13 18:00:00  139.850  139.863  139.660  139.736  19.691413
# 20035  2020-08-14 07:30:00  139.454  139.540  139.402  139.478  19.081350
# 20039  2020-08-14 09:30:00  139.414  139.558  139.404  139.553  49.211045
#
#               %D        RSI      Plot thirty_trend   4h_plot four_trend  \
# 35     90.104441  64.826891  0.002249      bullish  0.134107    bullish
# 54     78.189077  55.415844  0.005141      bullish  0.183445    bullish
# 76     19.238050  48.276827 -0.041435      bullish  0.221967    bullish
# 111    75.803518  59.996231  0.024531      bullish  0.200412    bullish
# 118    78.274574  63.639286  0.033199      bullish  0.204901    bullish
# ...          ...        ...       ...          ...       ...        ...
# 19957  71.775008  52.633428  0.004612      bullish -0.005206    bullish
# 20000  84.665076  71.487664  0.045974      bullish  0.024092    bullish
# 20008  19.970834  46.918194 -0.004763      bullish  0.023863    bullish
# 20035  13.734119  37.029787 -0.032327      bearish  0.007972    bearish
# 20039  47.663164  46.818996 -0.027676      bearish  0.010346    bearish
#
#       candle_dir dt_signal  sent_signal simple_result running_result  profit  \
# 35         short     short  short_trade           win            win    0.17
# 54         short     short  short_trade           win            win    0.17
# 76         short     short  short_trade           win            win    0.17
# 111        short     short  short_trade           win            win    0.17
# 118        short     short  short_trade           win            win    0.17
# ...          ...       ...          ...           ...            ...     ...
# 19957      short     short  short_trade           win            win    0.17
# 20000      short     short  short_trade           win            win    0.17
# 20008      short     short  short_trade           win            win    0.17
# 20035       long      long   long_trade           win            win    0.17
# 20039       long      long   long_trade           win            win    0.17
#
#       no_sig_stop  ext_profit
# 35            win       0.227
# 54            win       0.199
# 76            win       0.328
# 111           win       0.144
# 118           win       0.456
# ...           ...         ...
# 19957         win       0.153
# 20000         win       0.344
# 20008         win       0.236
# 20035         win       0.276
# 20039         win       0.300
#
# [628 rows x 20 columns]

# %% [markdown]
# ## Running Result Ignore Signal Stops

# %% [markdown]
# For this feature we're essentially reworking the Running Result feature but without taking signal stops. Again to re-iterate, in our original strategy if a candle closes in the opposite direction of a trade it is taken as a new signal and the original trade is closed and a new trade taken in the direction of newly closed candle. The logic of this clearly up for debate.
#
# What we're trying to see with these new result features is does it make sense to close out trades on the event of a reversed signal? The idea is to count profits on this tuned strategy and compare with the original strategy!
#
# #### Rules:
# * Based on next four candle metrics
# * If no_sig_stop is win, and we gain an extra 10 pips, then win.
# * If no_sig_stop is loss, then no_runner.
# * if no_sig_stop is runner and value hits stop, then loss
# * if no_sig_stop is runner, and we gain 10 pips, then win.
# * if no_sig_stop is runner, and we neither hit stop or gain 10 pips, then runner

# %%
thirtyA.head(1)
# Out:
#                   time     open     high      low   close         %K  \
# 0  2019-01-06 22:00:00  138.091  138.179  138.011  138.02  81.448525
#
#           %D        RSI      Plot thirty_trend   4h_plot four_trend  \
# 0  86.245303  65.524837  0.070389      unknown  0.005608    unknown
#
#   candle_dir dt_signal sent_signal simple_result running_result  profit  \
# 0      short   unknown    no_trade      no_trade       no_trade     0.0
#
#   no_sig_stop  ext_profit
# 0    no_trade         0.0

# %%
thirtyA.no_sig_stop.value_counts()
# Out:
# no_trade         17489
# win                793
# running_long       650
# running_short      600
# loss               530
# Name: no_sig_stop, dtype: int64

# %%
x=0

def run_no_sig_stop(row):
    global x
    
    #We'll add a print report to show the progress we're making mid function execute
    if x%50 == 0: 
        print("processing row {}".format(x))
    
    #First we store our features in variables for use when iterating
    result = thirtyA['no_sig_stop']
    open_ = thirtyA['open']
    high = thirtyA['high']
    low = thirtyA['low']
    close = thirtyA['close']
    signal = thirtyA['sent_signal']
    
    #Create a variable to store whether the current trade is long, short or no trade
    long_short = ''
    
    if signal.loc[x] == "short_trade":
        long_short = "short"
    elif signal.loc[x] == "long_trade":
        long_short = "long"
    else: 
        x+=1
        return "no_trade"
    
    #set counters 
    short_count = 0
    long_count = 0
    
    #set an empty list to store our individual candle outcomes
    can_list = []
    
    #First we check the first part of our rules... what do our wins convert to?
    for i, (j, k, l, m) in enumerate(zip(open_[x+2:], high[x+2:], low[x+2:], close[x+2:])):
        
        
        if len(can_list) < 4 and long_short == 'short' and result[x] == 'win':
            if high[x] < k:
                can_list.append('loss')
                    
            elif close[x] - l > 0.10:
                can_list.append('win')
                    
            else:
                can_list.append('runner')
                    
                    
        elif len(can_list) < 4 and long_short == 'long' and result[x] == 'win':
            if low[x] > l:
                can_list.append('loss')
                    
            elif k - close[x] > 0.10:
                can_list.append('win')
                    
            else:
                can_list.append('runner')
        
        elif result[x] == 'loss':
            x+=1
            return 'no_runner'
        
      
        
                    
                    
    #Next we create a new loop to check the runners to see what they convert to
    for i, (j, k, l, m, n) in enumerate(zip(open_[x+2:], high[x+2:], low[x+2:], close[x+2:], result[x+2:])):
        
        if len(can_list) < 4 and long_short == 'short' and result[x] == 'running_short':
            if high[x] < k:
                can_list.append('loss')
                    
            elif close[x] - l > 0.10:
                can_list.append('win')
                    
            else:
                can_list.append('runner')
                    
        elif len(can_list) < 4 and long_short == 'long' and result[x] == 'running_long':
            if low[x] > l:
                can_list.append('loss')
                    
            elif k - close[x] > 0.10:
                can_list.append('win')
                    
            else:
                can_list.append('runner') 
                
    
    #Now we check what order the results are sent to our can list. If we get a loss first then the trade will lose
    # if get a win first then the trade has made a win, if we get a sig_stop first then we've been stopped by a new
    #signal. Else if none of these things happen our trade remains as a runner
    
    if len(can_list)==4: #If our container has stored the next 3 candle outcomes, proceed. 
        if can_list[0] == 'loss':
            x+=1 #increment x by one
            return 'loss' #and return the trade outcome
        elif can_list[0] == 'win':
            x+=1
            return 'win'
        elif can_list[0] == 'runner' and can_list[1] == 'loss':
            x+=1
            return 'loss'
        elif can_list[0] == 'runner' and can_list[1] == 'win':
            x+=1
            return 'win'
        elif can_list[1] == 'runner' and can_list[2] == 'loss':
            x+=1
            return 'loss'
        elif can_list[1] == 'runner' and can_list[2] == 'win':
            x+=1
            return 'win'
        elif can_list[2] == 'runner' and can_list[3] =='loss':
            x+=1
            return 'loss'
        elif can_list[2] == 'runner' and can_list[3] =='win':
            x+=1
            return 'win'
        else:
            x+=1
            return 'runner'

# %%
run_no_sig = thirtyA.apply(run_no_sig_stop, axis='columns').to_frame()
thirtyA = thirtyA.join(run_no_sig)
thirtyA.rename(columns={0: 'running_nosig'}, inplace=True)
# Out:
# processing row 0
# processing row 50
# processing row 100
# processing row 150
# processing row 200
# processing row 250
# processing row 300
# processing row 350
# processing row 400
# processing row 450
# processing row 500
# processing row 550
# processing row 600
# processing row 650
# processing row 700
# processing row 750
# processing row 800
# processing row 850
# processing row 900
# processing row 950
# processing row 1000
# processing row 1050
# processing row 1100
# processing row 1150
# processing row 1200
# processing row 1250
# processing row 1300
# processing row 1350
# processing row 1400
# processing row 1450
# processing row 1500
# processing row 1550
# processing row 1600
# processing row 1650
# processing row 1700
# processing row 1750
# processing row 1800
# processing row 1850
# processing row 1900
# processing row 1950
# processing row 2000
# processing row 2050
# processing row 2100
# processing row 2150
# processing row 2200
# processing row 2250
# processing row 2300
# processing row 2350
# processing row 2400
# processing row 2450
# processing row 2500
# processing row 2550
# processing row 2600
# processing row 2650
# processing row 2700
# processing row 2750
# processing row 2800
# processing row 2850
# processing row 2900
# processing row 2950
# processing row 3000
# processing row 3050
# processing row 3100
# processing row 3150
# processing row 3200
# processing row 3250
# processing row 3300
# processing row 3350
# processing row 3400
# processing row 3450
# processing row 3500
# processing row 3550
# processing row 3600
# processing row 3650
# processing row 3700
# processing row 3750
# processing row 3800
# processing row 3850
# processing row 3900
# processing row 3950
# processing row 4000
# processing row 4050
# processing row 4100
# processing row 4150
# processing row 4200
# processing row 4250
# processing row 4300
# processing row 4350
# processing row 4400
# processing row 4450
# processing row 4500
# processing row 4550
# processing row 4600
# processing row 4650
# processing row 4700
# processing row 4750
# processing row 4800
# processing row 4850
# processing row 4900
# processing row 4950
# processing row 5000
# processing row 5050
# processing row 5100
# processing row 5150
# processing row 5200
# processing row 5250
# processing row 5300
# processing row 5350
# processing row 5400
# processing row 5450
# processing row 5500
# processing row 5550
# processing row 5600
# processing row 5650
# processing row 5700
# processing row 5750
# processing row 5800
# processing row 5850
# processing row 5900
# processing row 5950
# processing row 6000
# processing row 6050
# processing row 6100
# processing row 6150
# processing row 6200
# processing row 6250
# processing row 6300
# processing row 6350
# processing row 6400
# processing row 6450
# processing row 6500
# processing row 6550
# processing row 6600
# processing row 6650
# processing row 6700
# processing row 6750
# processing row 6800
# processing row 6850
# processing row 6900
# processing row 6950
# processing row 7000
# processing row 7050
# processing row 7100
# processing row 7150
# processing row 7200
# processing row 7250
# processing row 7300
# processing row 7350
# processing row 7400
# processing row 7450
# processing row 7500
# processing row 7550
# processing row 7600
# processing row 7650
# processing row 7700
# processing row 7750
# processing row 7800
# processing row 7850
# processing row 7900
# processing row 7950
# processing row 8000
# processing row 8050
# processing row 8100
# processing row 8150
# processing row 8200
# processing row 8250
# processing row 8300
# processing row 8350
# processing row 8400
# processing row 8450
# processing row 8500
# processing row 8550
# processing row 8600
# processing row 8650
# processing row 8700
# processing row 8750
# processing row 8800
# processing row 8850
# processing row 8900
# processing row 8950
# processing row 9000
# processing row 9050
# processing row 9100
# processing row 9150
# processing row 9200
# processing row 9250
# processing row 9300
# processing row 9350
# processing row 9400
# processing row 9450
# processing row 9500
# processing row 9550
# processing row 9600
# processing row 9650
# processing row 9700
# processing row 9750
# processing row 9800
# processing row 9850
# processing row 9900
# processing row 9950
# processing row 10000
# processing row 10050
# processing row 10100
# processing row 10150
# processing row 10200
# processing row 10250
# processing row 10300
# processing row 10350
# processing row 10400
# processing row 10450
# processing row 10500
# processing row 10550
# processing row 10600
# processing row 10650
# processing row 10700
# processing row 10750
# processing row 10800
# processing row 10850
# processing row 10900
# processing row 10950
# processing row 11000
# processing row 11050
# processing row 11100
# processing row 11150
# processing row 11200
# processing row 11250
# processing row 11300
# processing row 11350
# processing row 11400
# processing row 11450
# processing row 11500
# processing row 11550
# processing row 11600
# processing row 11650
# processing row 11700
# processing row 11750
# processing row 11800
# processing row 11850
# processing row 11900
# processing row 11950
# processing row 12000
# processing row 12050
# processing row 12100
# processing row 12150
# processing row 12200
# processing row 12250
# processing row 12300
# processing row 12350
# processing row 12400
# processing row 12450
# processing row 12500
# processing row 12550
# processing row 12600
# processing row 12650
# processing row 12700
# processing row 12750
# processing row 12800
# processing row 12850
# processing row 12900
# processing row 12950
# processing row 13000
# processing row 13050
# processing row 13100
# processing row 13150
# processing row 13200
# processing row 13250
# processing row 13300
# processing row 13350
# processing row 13400
# processing row 13450
# processing row 13500
# processing row 13550
# processing row 13600
# processing row 13650
# processing row 13700
# processing row 13750
# processing row 13800
# processing row 13850
# processing row 13900
# processing row 13950
# processing row 14000
# processing row 14050
# processing row 14100
# processing row 14150
# processing row 14200
# processing row 14250
# processing row 14300
# processing row 14350
# processing row 14400
# processing row 14450
# processing row 14500
# processing row 14550
# processing row 14600
# processing row 14650
# processing row 14700
# processing row 14750
# processing row 14800
# processing row 14850
# processing row 14900
# processing row 14950
# processing row 15000
# processing row 15050
# processing row 15100
# processing row 15150
# processing row 15200
# processing row 15250
# processing row 15300
# processing row 15350
# processing row 15400
# processing row 15450
# processing row 15500
# processing row 15550
# processing row 15600
# processing row 15650
# processing row 15700
# processing row 15750
# processing row 15800
# processing row 15850
# processing row 15900
# processing row 15950
# processing row 16000
# processing row 16050
# processing row 16100
# processing row 16150
# processing row 16200
# processing row 16250
# processing row 16300
# processing row 16350
# processing row 16400
# processing row 16450
# processing row 16500
# processing row 16550
# processing row 16600
# processing row 16650
# processing row 16700
# processing row 16750
# processing row 16800
# processing row 16850
# processing row 16900
# processing row 16950
# processing row 17000
# processing row 17050
# processing row 17100
# processing row 17150
# processing row 17200
# processing row 17250
# processing row 17300
# processing row 17350
# processing row 17400
# processing row 17450
# processing row 17500
# processing row 17550
# processing row 17600
# processing row 17650
# processing row 17700
# processing row 17750
# processing row 17800
# processing row 17850
# processing row 17900
# processing row 17950
# processing row 18000
# processing row 18050
# processing row 18100
# processing row 18150
# processing row 18200
# processing row 18250
# processing row 18300
# processing row 18350
# processing row 18400
# processing row 18450
# processing row 18500
# processing row 18550
# processing row 18600
# processing row 18650
# processing row 18700
# processing row 18750
# processing row 18800
# processing row 18850
# processing row 18900
# processing row 18950
# processing row 19000
# processing row 19050
# processing row 19100
# processing row 19150
# processing row 19200
# processing row 19250
# processing row 19300
# processing row 19350
# processing row 19400
# processing row 19450
# processing row 19500
# processing row 19550
# processing row 19600
# processing row 19650
# processing row 19700
# processing row 19750
# processing row 19800
# processing row 19850
# processing row 19900
# processing row 19950
# processing row 20000
# processing row 20050

# %%
thirtyA.simple_result.value_counts()
# Out:
# no_trade         17489
# win                793
# sig_stop           693
# loss               530
# running_long       290
# running_short      267
# Name: simple_result, dtype: int64

# %%
thirtyA.no_sig_stop.value_counts()
# Out:
# no_trade         17489
# win                793
# running_long       650
# running_short      600
# loss               530
# Name: no_sig_stop, dtype: int64

# %%
thirtyA.running_nosig.value_counts()
# Out:
# no_trade     17489
# win           1084
# loss           741
# no_runner      530
# runner         218
# Name: running_nosig, dtype: int64

# %%
thirtyA.running_result.value_counts()
# Out:
# no_trade     17489
# no_runner     1223
# win            835
# sig_stop       250
# loss           239
# runner          26
# Name: running_result, dtype: int64

# %% [markdown]
# #### Quick Comparisons
# At a glance the comparison between the two different features exposes the following: \
# 1) Around 250 more wins for the tuned feature \
# 2) Around 500 more losses for the tuned \
# 3) Around 200 more non completed, runner trades \
# 4) We have a net overall increase in lost trades, but we won't know the impact until we calculate the tuned profit and value features.

# %% [markdown]
# So now we have got our features for the tuned strategy we should create the profit feature.

# %% [markdown]
# ## No Signal Stop Profit Feature

# %%
thirtyA.columns
# Out:
# Index(['time', 'open', 'high', 'low', 'close', '%K', '%D', 'RSI', 'Plot',
#        'thirty_trend', '4h_plot', 'four_trend', 'candle_dir', 'dt_signal',
#        'sent_signal', 'simple_result', 'running_result', 'profit',
#        'no_sig_stop', 'ext_profit', 'running_nosig'],
#       dtype='object')

# %%
thirtyA.head()
# Out:
#                   time     open     high      low    close         %K  \
# 0  2019-01-06 22:00:00  138.091  138.179  138.011  138.020  81.448525
# 1  2019-01-06 22:30:00  138.020  138.084  137.922  138.074  77.059060
# 2  2019-01-06 23:00:00  138.074  138.302  137.935  138.273  80.000922
# 3  2019-01-06 23:30:00  138.273  138.334  138.168  138.210  81.073987
# 4  2019-01-07 00:00:00  138.210  138.254  138.099  138.228  82.464591
#
#           %D        RSI      Plot thirty_trend   4h_plot four_trend  \
# 0  86.245303  65.524837  0.070389      unknown  0.005608    unknown
# 1  82.185586  66.849987  0.061890      unknown  0.005608    unknown
# 2  79.502836  71.237596  0.058952      unknown  0.005608    unknown
# 3  79.377990  68.161801  0.053267      unknown  0.005608    unknown
# 4  81.179833  68.579229  0.047715      unknown  0.005608    unknown
#
#   candle_dir dt_signal sent_signal simple_result running_result  profit  \
# 0      short   unknown    no_trade      no_trade       no_trade     0.0
# 1       long      long    no_trade      no_trade       no_trade     0.0
# 2       long  no_trade    no_trade      no_trade       no_trade     0.0
# 3      short     short    no_trade      no_trade       no_trade     0.0
# 4       long      long    no_trade      no_trade       no_trade     0.0
#
#   no_sig_stop  ext_profit running_nosig
# 0    no_trade         0.0      no_trade
# 1    no_trade         0.0      no_trade
# 2    no_trade         0.0      no_trade
# 3    no_trade         0.0      no_trade
# 4    no_trade         0.0      no_trade

# %% [markdown]
# #### Rules:
# * If both results are wins and trade is long, then high of next 5 candles - close DONE
# * If initial result is win and running result is loss, then 0.07 DONE
# * If initial result is loss and trade is long, then low of signal candle - close of signal candle DONE
# * If initial result is loss and trade is short, then close of signal candle - high if signal candle DONE
# * if initial result is running_long and running result is loss, then low of signal candle - close of signal candle DONE
# * if initial result is running_short and running result is loss, close of signal candle - high of signal candle DONE
# * If running result is runner, then return 0.00 DONE

# %%
x=0

def tuned_profit(row):
    global x
    
    if x%50 == 0: #set a printout to monitor the progress of function when called
        print(f'processing row {x}')
    
    #Set our variables for each feature for iteration
    result = thirtyA['no_sig_stop']
    running = thirtyA['running_nosig']
    open_ = thirtyA['open']
    high = thirtyA['high']
    low = thirtyA['low']
    close = thirtyA['close']
    signal = thirtyA['sent_signal']
    
    #create an empty variable to store our trade direction
    long_short = ''
    
    if signal.loc[x] == "short_trade":
        long_short = "short"
    elif signal.loc[x] == "long_trade":
        long_short = "long"
    else: 
        x+=1
        return 0.00
    
    
    # Solve our basic conditionals
    if result[x] == 'win' and running[x] == 'loss':
        x+=1
        return 0.07
    elif result[x] == 'loss' and long_short == 'short':
        value = close[x] - (high[x]+0.02)
        x+=1
        return value
    elif result[x] == 'loss' and long_short == 'long':
        value = (low[x]-0.02) - close[x]
        x+=1
        return value
    elif result[x] == 'running_long' and running[x] == 'loss':
        value = (low[x]-0.02) - close[x]
        x+=1
        return value
    elif result[x] == 'running_short' and running[x] == 'loss':
        value = close[x] - (high[x]+0.02)
        x+=1
        return value
    elif running[x] == 'runner':
        x+=1
        return 0.00

    
    can_list = []
    
    
    #Solve for running wins, the only result where we need to loop through the later candles. 
    for i, (k, l) in enumerate(zip(high[x+1:], low[x+1:])):
        if len(can_list) < 5 and running[x] == 'win' and long_short == 'short':
            
            can_list.append(close[x]-l)
            
        elif len(can_list) < 5 and running[x] == 'win' and long_short == 'long':
            
            can_list.append(k - close[x])
    
    x+=1
    
    return max(can_list)

# %%
profit_no_sig = thirtyA.apply(tuned_profit, axis='columns').to_frame()
thirtyA = thirtyA.join(profit_no_sig)
thirtyA.rename(columns={0: 'tuned_profit'}, inplace=True)
# Out:
# processing row 0
# processing row 50
# processing row 100
# processing row 150
# processing row 200
# processing row 250
# processing row 300
# processing row 350
# processing row 400
# processing row 450
# processing row 500
# processing row 550
# processing row 600
# processing row 650
# processing row 700
# processing row 750
# processing row 800
# processing row 850
# processing row 900
# processing row 950
# processing row 1000
# processing row 1050
# processing row 1100
# processing row 1150
# processing row 1200
# processing row 1250
# processing row 1300
# processing row 1350
# processing row 1400
# processing row 1450
# processing row 1500
# processing row 1550
# processing row 1600
# processing row 1650
# processing row 1700
# processing row 1750
# processing row 1800
# processing row 1850
# processing row 1900
# processing row 1950
# processing row 2000
# processing row 2050
# processing row 2100
# processing row 2150
# processing row 2200
# processing row 2250
# processing row 2300
# processing row 2350
# processing row 2400
# processing row 2450
# processing row 2500
# processing row 2550
# processing row 2600
# processing row 2650
# processing row 2700
# processing row 2750
# processing row 2800
# processing row 2850
# processing row 2900
# processing row 2950
# processing row 3000
# processing row 3050
# processing row 3100
# processing row 3150
# processing row 3200
# processing row 3250
# processing row 3300
# processing row 3350
# processing row 3400
# processing row 3450
# processing row 3500
# processing row 3550
# processing row 3600
# processing row 3650
# processing row 3700
# processing row 3750
# processing row 3800
# processing row 3850
# processing row 3900
# processing row 3950
# processing row 4000
# processing row 4050
# processing row 4100
# processing row 4150
# processing row 4200
# processing row 4250
# processing row 4300
# processing row 4350
# processing row 4400
# processing row 4450
# processing row 4500
# processing row 4550
# processing row 4600
# processing row 4650
# processing row 4700
# processing row 4750
# processing row 4800
# processing row 4850
# processing row 4900
# processing row 4950
# processing row 5000
# processing row 5050
# processing row 5100
# processing row 5150
# processing row 5200
# processing row 5250
# processing row 5300
# processing row 5350
# processing row 5400
# processing row 5450
# processing row 5500
# processing row 5550
# processing row 5600
# processing row 5650
# processing row 5700
# processing row 5750
# processing row 5800
# processing row 5850
# processing row 5900
# processing row 5950
# processing row 6000
# processing row 6050
# processing row 6100
# processing row 6150
# processing row 6200
# processing row 6250
# processing row 6300
# processing row 6350
# processing row 6400
# processing row 6450
# processing row 6500
# processing row 6550
# processing row 6600
# processing row 6650
# processing row 6700
# processing row 6750
# processing row 6800
# processing row 6850
# processing row 6900
# processing row 6950
# processing row 7000
# processing row 7050
# processing row 7100
# processing row 7150
# processing row 7200
# processing row 7250
# processing row 7300
# processing row 7350
# processing row 7400
# processing row 7450
# processing row 7500
# processing row 7550
# processing row 7600
# processing row 7650
# processing row 7700
# processing row 7750
# processing row 7800
# processing row 7850
# processing row 7900
# processing row 7950
# processing row 8000
# processing row 8050
# processing row 8100
# processing row 8150
# processing row 8200
# processing row 8250
# processing row 8300
# processing row 8350
# processing row 8400
# processing row 8450
# processing row 8500
# processing row 8550
# processing row 8600
# processing row 8650
# processing row 8700
# processing row 8750
# processing row 8800
# processing row 8850
# processing row 8900
# processing row 8950
# processing row 9000
# processing row 9050
# processing row 9100
# processing row 9150
# processing row 9200
# processing row 9250
# processing row 9300
# processing row 9350
# processing row 9400
# processing row 9450
# processing row 9500
# processing row 9550
# processing row 9600
# processing row 9650
# processing row 9700
# processing row 9750
# processing row 9800
# processing row 9850
# processing row 9900
# processing row 9950
# processing row 10000
# processing row 10050
# processing row 10100
# processing row 10150
# processing row 10200
# processing row 10250
# processing row 10300
# processing row 10350
# processing row 10400
# processing row 10450
# processing row 10500
# processing row 10550
# processing row 10600
# processing row 10650
# processing row 10700
# processing row 10750
# processing row 10800
# processing row 10850
# processing row 10900
# processing row 10950
# processing row 11000
# processing row 11050
# processing row 11100
# processing row 11150
# processing row 11200
# processing row 11250
# processing row 11300
# processing row 11350
# processing row 11400
# processing row 11450
# processing row 11500
# processing row 11550
# processing row 11600
# processing row 11650
# processing row 11700
# processing row 11750
# processing row 11800
# processing row 11850
# processing row 11900
# processing row 11950
# processing row 12000
# processing row 12050
# processing row 12100
# processing row 12150
# processing row 12200
# processing row 12250
# processing row 12300
# processing row 12350
# processing row 12400
# processing row 12450
# processing row 12500
# processing row 12550
# processing row 12600
# processing row 12650
# processing row 12700
# processing row 12750
# processing row 12800
# processing row 12850
# processing row 12900
# processing row 12950
# processing row 13000
# processing row 13050
# processing row 13100
# processing row 13150
# processing row 13200
# processing row 13250
# processing row 13300
# processing row 13350
# processing row 13400
# processing row 13450
# processing row 13500
# processing row 13550
# processing row 13600
# processing row 13650
# processing row 13700
# processing row 13750
# processing row 13800
# processing row 13850
# processing row 13900
# processing row 13950
# processing row 14000
# processing row 14050
# processing row 14100
# processing row 14150
# processing row 14200
# processing row 14250
# processing row 14300
# processing row 14350
# processing row 14400
# processing row 14450
# processing row 14500
# processing row 14550
# processing row 14600
# processing row 14650
# processing row 14700
# processing row 14750
# processing row 14800
# processing row 14850
# processing row 14900
# processing row 14950
# processing row 15000
# processing row 15050
# processing row 15100
# processing row 15150
# processing row 15200
# processing row 15250
# processing row 15300
# processing row 15350
# processing row 15400
# processing row 15450
# processing row 15500
# processing row 15550
# processing row 15600
# processing row 15650
# processing row 15700
# processing row 15750
# processing row 15800
# processing row 15850
# processing row 15900
# processing row 15950
# processing row 16000
# processing row 16050
# processing row 16100
# processing row 16150
# processing row 16200
# processing row 16250
# processing row 16300
# processing row 16350
# processing row 16400
# processing row 16450
# processing row 16500
# processing row 16550
# processing row 16600
# processing row 16650
# processing row 16700
# processing row 16750
# processing row 16800
# processing row 16850
# processing row 16900
# processing row 16950
# processing row 17000
# processing row 17050
# processing row 17100
# processing row 17150
# processing row 17200
# processing row 17250
# processing row 17300
# processing row 17350
# processing row 17400
# processing row 17450
# processing row 17500
# processing row 17550
# processing row 17600
# processing row 17650
# processing row 17700
# processing row 17750
# processing row 17800
# processing row 17850
# processing row 17900
# processing row 17950
# processing row 18000
# processing row 18050
# processing row 18100
# processing row 18150
# processing row 18200
# processing row 18250
# processing row 18300
# processing row 18350
# processing row 18400
# processing row 18450
# processing row 18500
# processing row 18550
# processing row 18600
# processing row 18650
# processing row 18700
# processing row 18750
# processing row 18800
# processing row 18850
# processing row 18900
# processing row 18950
# processing row 19000
# processing row 19050
# processing row 19100
# processing row 19150
# processing row 19200
# processing row 19250
# processing row 19300
# processing row 19350
# processing row 19400
# processing row 19450
# processing row 19500
# processing row 19550
# processing row 19600
# processing row 19650
# processing row 19700
# processing row 19750
# processing row 19800
# processing row 19850
# processing row 19900
# processing row 19950
# processing row 20000
# processing row 20050

# %%
thirtyA[thirtyA.tuned_profit!=0.0]
# Out:
#                       time     open     high      low    close         %K  \
# 32     2019-01-07 14:00:00  138.322  138.408  138.268  138.272  91.285107
# 35     2019-01-07 15:30:00  138.578  138.687  138.346  138.492  89.649879
# 41     2019-01-07 18:30:00  138.802  138.824  138.532  138.622  86.898499
# 45     2019-01-07 20:30:00  138.829  138.874  138.762  138.816  88.437094
# 50     2019-01-07 23:00:00  138.926  138.966  138.878  138.887  90.241474
# ...                    ...      ...      ...      ...      ...        ...
# 20023  2020-08-14 01:30:00  139.653  139.720  139.618  139.664  43.062606
# 20027  2020-08-14 03:30:00  139.596  139.653  139.592  139.617  18.868069
# 20030  2020-08-14 05:00:00  139.573  139.618  139.562  139.615  12.974052
# 20035  2020-08-14 07:30:00  139.454  139.540  139.402  139.478  19.081350
# 20039  2020-08-14 09:30:00  139.414  139.558  139.404  139.553  49.211045
#
#               %D        RSI      Plot thirty_trend   4h_plot four_trend  \
# 32     86.681139  60.939545 -0.018425      bullish  0.134107    bullish
# 35     90.104441  64.826891  0.002249      bullish  0.134107    bullish
# 41     91.325175  61.871256  0.022497      bullish  0.167150    bullish
# 45     81.676800  66.758711  0.021740      bullish  0.167150    bullish
# 50     91.861208  67.107538  0.019568      bullish  0.183445    bullish
# ...          ...        ...       ...          ...       ...        ...
# 20023  54.653130  45.154066 -0.023564      bearish  0.014485    bearish
# 20027  25.480404  42.865134 -0.028536      bearish  0.014485    bearish
# 20030  13.872255  43.995929 -0.028545      bearish  0.007972    bearish
# 20035  13.734119  37.029787 -0.032327      bearish  0.007972    bearish
# 20039  47.663164  46.818996 -0.027676      bearish  0.010346    bearish
#
#       candle_dir dt_signal  sent_signal  simple_result running_result  profit  \
# 32         short     short  short_trade            win           loss   0.070
# 35         short     short  short_trade            win            win   0.170
# 41         short     short  short_trade  running_short       sig_stop  -0.059
# 45         short     short  short_trade  running_short           loss  -0.078
# 50         short     short  short_trade       sig_stop      no_runner  -0.001
# ...          ...       ...          ...            ...            ...     ...
# 20023       long      long   long_trade       sig_stop      no_runner  -0.030
# 20027       long      long   long_trade   running_long           loss  -0.045
# 20030       long      long   long_trade   running_long           loss  -0.073
# 20035       long      long   long_trade            win            win   0.170
# 20039       long      long   long_trade            win            win   0.170
#
#          no_sig_stop  ext_profit running_nosig  tuned_profit
# 32               win       0.070          loss         0.070
# 35               win       0.227           win         0.154
# 41     running_short      -0.059          loss        -0.222
# 45     running_short      -0.078          loss        -0.078
# 50     running_short      -0.001          loss        -0.099
# ...              ...         ...           ...           ...
# 20023   running_long      -0.030          loss        -0.066
# 20027   running_long      -0.045          loss        -0.045
# 20030   running_long      -0.073          loss        -0.073
# 20035            win       0.276           win         0.276
# 20039            win       0.300           win         0.300
#
# [2355 rows x 22 columns]

# %%
print(f'Our potential profit before tuning was {round(thirtyA.ext_profit.sum(), 2)} \
and our potential tuned profit is {round(thirtyA.tuned_profit.sum(), 2)}')
# Out:
# Our potential profit before tuning was 170.43 and our potential tuned profit is 230.36

# %% [markdown]
# So the possible lesson here is that we should let runners run to either gain a win or allow them to stop out. However we must understand that we're ignoring signals when they stop out any running trades but not for new trades, this could mean we would have multiple conflicting trades open at any single point. This could be a confusing and impractical way to trade. Iyt would be better to tune the system even further and react in a bespoke manner to a given trading environment.
#
# For example counteractive signal stops could be ignored during breakouts but fully employed during ranging. All signals could be ingnored during periods of flat market activity. |

# %%
#Largest single win!
thirtyA.tuned_profit.max()
#This win must surely have been concurrent with some great news for this forex pair!
# Out:
# 4.133999999999986

# %%
# Let's check when this 400 pip win would have come
# thirtyA[thirtyA.tuned_profit>4]
thirtyA.loc[11707:11712]
# Out:
#                       time     open     high      low    close         %K  \
# 11707  2019-12-12 19:30:00  142.867  143.658  142.865  143.610  59.224718
# 11708  2019-12-12 20:00:00  143.610  144.078  143.602  143.946  74.398196
# 11709  2019-12-12 20:30:00  143.946  144.156  143.868  143.994  92.284471
# 11710  2019-12-12 21:00:00  143.994  144.012  143.846  143.918  88.364326
# 11711  2019-12-12 21:30:00  143.918  144.074  143.690  143.944  86.418109
# 11712  2019-12-12 22:00:00  143.944  147.744  143.870  147.719  89.849596
#
#               %D        RSI      Plot thirty_trend   4h_plot four_trend  \
# 11707  54.504947  59.073655 -0.017008      bearish -0.003100    bearish
# 11708  59.993646  64.969491  0.004018      bullish -0.003100    bearish
# 11709  75.302461  65.729039  0.021531      bullish -0.003100    bearish
# 11710  85.015664  63.385585  0.032670      bullish -0.003100    bearish
# 11711  89.022302  63.860295  0.041429      bullish -0.003100    bearish
# 11712  88.210677  88.061817  0.149654      bullish  0.113875    bullish
#
#       candle_dir dt_signal sent_signal simple_result running_result  profit  \
# 11707       long      long  long_trade           win            win    0.17
# 11708       long  no_trade    no_trade      no_trade       no_trade    0.00
# 11709       long  no_trade    no_trade      no_trade       no_trade    0.00
# 11710      short     short    no_trade      no_trade       no_trade    0.00
# 11711       long      long    no_trade      no_trade       no_trade    0.00
# 11712       long  no_trade    no_trade      no_trade       no_trade    0.00
#
#       no_sig_stop  ext_profit running_nosig  tuned_profit
# 11707         win       4.134           win         4.134
# 11708    no_trade       0.000      no_trade         0.000
# 11709    no_trade       0.000      no_trade         0.000
# 11710    no_trade       0.000      no_trade         0.000
# 11711    no_trade       0.000      no_trade         0.000
# 11712    no_trade       0.000      no_trade         0.000

# %% [markdown]
# ## Snapshot Of Candlestick Chart at Time of Max Win
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Admin and restructure

# %% [markdown]
# Let's rename some of the features and also re-organise the columns as some are not in a sensible order.

# %%
#Let's start by getting rid of the no trade signal rows
thirtyB = thirtyA[thirtyA.sent_signal != 'no_trade']

# %%
#reset the index as we now have great gaps between our original index values
thirtyB.reset_index(inplace=True)

# %%
#Now we'll drop out any redundant columns and also rename any features that need this!
thirtyB.drop(columns=['index'], inplace=True)
thirtyB.rename(columns={'%K': 'fast_stoch', 
                     '%D': 'slow_stoch',
                     'RSI': 'rsi',
                     'Plot': '30_sent',
                     '4h_plot': '4h_sent'}, inplace=True)

# %%
thirtyB.head(2)
# Out:
#                   time     open     high      low    close  fast_stoch  \
# 0  2019-01-07 14:00:00  138.322  138.408  138.268  138.272   91.285107
# 1  2019-01-07 15:30:00  138.578  138.687  138.346  138.492   89.649879
#
#    slow_stoch        rsi   30_sent thirty_trend   4h_sent four_trend  \
# 0   86.681139  60.939545 -0.018425      bullish  0.134107    bullish
# 1   90.104441  64.826891  0.002249      bullish  0.134107    bullish
#
#   candle_dir dt_signal  sent_signal simple_result running_result  profit  \
# 0      short     short  short_trade           win           loss    0.07
# 1      short     short  short_trade           win            win    0.17
#
#   no_sig_stop  ext_profit running_nosig  tuned_profit
# 0         win       0.070          loss         0.070
# 1         win       0.227           win         0.154

# %%
#Now we need to alter the column order slightly
thirtyB = thirtyB[['time', 'open', 'high', 'low', 'close', 'fast_stoch', 'slow_stoch', 'rsi', '30_sent',
                   'thirty_trend', '4h_sent', 'four_trend', 'candle_dir', 'dt_signal', 'sent_signal',
                   'simple_result', 'running_result', 'profit', 'ext_profit', 'no_sig_stop', 'running_nosig',
                   'tuned_profit']]

# %%
thirtyB.head(3)
# Out:
#                   time     open     high      low    close  fast_stoch  \
# 0  2019-01-07 14:00:00  138.322  138.408  138.268  138.272   91.285107
# 1  2019-01-07 15:30:00  138.578  138.687  138.346  138.492   89.649879
# 2  2019-01-07 18:30:00  138.802  138.824  138.532  138.622   86.898499
#
#    slow_stoch        rsi   30_sent thirty_trend   4h_sent four_trend  \
# 0   86.681139  60.939545 -0.018425      bullish  0.134107    bullish
# 1   90.104441  64.826891  0.002249      bullish  0.134107    bullish
# 2   91.325175  61.871256  0.022497      bullish  0.167150    bullish
#
#   candle_dir dt_signal  sent_signal  simple_result running_result  profit  \
# 0      short     short  short_trade            win           loss   0.070
# 1      short     short  short_trade            win            win   0.170
# 2      short     short  short_trade  running_short       sig_stop  -0.059
#
#    ext_profit    no_sig_stop running_nosig  tuned_profit
# 0       0.070            win          loss         0.070
# 1       0.227            win           win         0.154
# 2      -0.059  running_short          loss        -0.222

# %%
thirtyB.shape
# Out:
# (2573, 22)

# %%
thirtyB.loc[250:256]
# Out:
#                     time     open     high      low    close  fast_stoch  \
# 250  2019-03-04 19:30:00  147.130  147.178  147.110  147.164    6.676980
# 251  2019-03-04 20:30:00  147.162  147.192  147.140  147.177    7.186298
# 252  2019-03-05 10:00:00  147.648  147.668  147.474  147.548   65.531552
# 253  2019-03-05 12:00:00  147.540  147.566  147.388  147.432   37.777778
# 254  2019-03-05 22:00:00  147.443  147.443  147.348  147.358   93.846460
# 255  2019-03-06 06:30:00  146.826  146.940  146.813  146.928   33.908313
# 256  2019-03-06 07:30:00  146.792  146.966  146.750  146.904   41.629437
#
#      slow_stoch        rsi   30_sent thirty_trend   4h_sent four_trend  \
# 250    9.381121  30.446296 -0.067596      bearish -0.036556    bearish
# 251    6.201579  31.426362 -0.061650      bearish -0.036556    bearish
# 252   66.628093  57.555107  0.037926      bullish -0.110408    bullish
# 253   34.757898  51.428553  0.030835      bullish -0.110408    bullish
# 254   94.853614  53.597211  0.038862      bullish -0.137266    bullish
# 255   27.142099  45.772430 -0.016220      bearish -0.154517    bearish
# 256   35.465696  46.008237 -0.013773      bearish -0.154517    bearish
#
#     candle_dir dt_signal  sent_signal simple_result running_result  profit  \
# 250       long      long   long_trade      sig_stop      no_runner  -0.002
# 251       long      long   long_trade  running_long            win   0.070
# 252      short     short  short_trade           win            win   0.170
# 253      short     short  short_trade           win            win   0.170
# 254      short     short  short_trade           win            win   0.170
# 255       long      long   long_trade          loss      no_runner  -0.135
# 256       long      long   long_trade           win            win   0.170
#
#      ext_profit   no_sig_stop running_nosig  tuned_profit
# 250      -0.002  running_long           win         0.139
# 251       0.070  running_long           win         0.126
# 252       0.790           win           win         0.790
# 253       0.820           win           win         0.820
# 254       0.431           win           win         0.431
# 255      -0.135          loss     no_runner        -0.135
# 256       0.280           win           win         0.280

# %%
#### Note that the second lot of features were not exported #####

# %% [markdown]
# ## Trade Size

# %%
## This section remains incomplete

# %% [markdown]
# ### Rules
#
# The sizes below are arbitrary, it's the escalation that is important. i.e the first trade could be 0.02, 0.5 or 10 lot. Obviously these different lot sizes represent different risk profiles, as this is an experimental strategy we'll start with a very low starting size to limit our risk exposure.
#
# * The first trade has a size of 1 (but it could be anything)
# * If the first trade loses then the next trade lot size is doubled
# * An so on if that trade loses the next size is doubled
# * If a trade wins then the next trade returns to a size of 1

# %%
max(lstA)
# Out:
# 9

# %%
thirtyB.loc[665:680]
# Out:
#                     time     open     high      low    close  fast_stoch  \
# 665  2019-06-06 11:00:00  137.287  137.632  137.282  137.401   72.742200
# 666  2019-06-06 20:00:00  137.730  137.745  137.652  137.676   81.428871
# 667  2019-06-07 00:00:00  137.684  137.706  137.590  137.646   60.605715
# 668  2019-06-07 02:00:00  137.724  137.724  137.657  137.657   50.000000
# 669  2019-06-07 03:00:00  137.709  137.738  137.664  137.686   61.152584
# 670  2019-06-07 04:00:00  137.716  137.725  137.674  137.712   72.245467
# 671  2019-06-07 05:00:00  137.714  137.747  137.625  137.653   65.494993
# 672  2019-06-07 07:30:00  137.884  138.009  137.842  137.857   81.181167
# 673  2019-06-07 10:00:00  138.071  138.108  138.010  138.054   84.977181
# 674  2019-06-10 05:00:00  138.108  138.110  138.035  138.037   64.544479
# 675  2019-06-10 07:00:00  138.124  138.124  138.034  138.052   78.806060
# 676  2019-06-10 08:30:00  138.182  138.182  137.794  137.830   55.475366
# 677  2019-06-10 13:00:00  137.487  137.574  137.484  137.538    4.773766
# 678  2019-06-10 15:30:00  137.608  137.718  137.568  137.701   32.447937
# 679  2019-06-10 19:00:00  137.580  137.644  137.575  137.614   34.408602
# 680  2019-06-11 06:30:00  137.759  137.813  137.604  137.624   65.771812
#
#      slow_stoch        rsi   30_sent thirty_trend   4h_sent four_trend  \
# 665   78.188287  54.111014 -0.007782      bearish  0.097013    bearish
# 666   77.187886  58.721541  0.021983      bullish  0.105468    bullish
# 667   58.469274  55.702448  0.010723      bullish  0.109970    bullish
# 668   48.720016  54.851433  0.008439      bullish  0.114657    bullish
# 669   57.949456  56.164129  0.008031      bullish  0.114657    bullish
# 670   68.408370  57.733052  0.007752      bullish  0.114657    bullish
# 671   71.094107  52.093082  0.005070      bullish  0.124731    bullish
# 672   83.500937  64.428943  0.011789      bullish  0.124731    bullish
# 673   87.013293  72.719958  0.024762      bullish  0.121811    bullish
# 674   58.455694  56.537641  0.004365      bullish  0.128339    bullish
# 675   71.674099  55.498954  0.003554      bullish  0.128339    bullish
# 676   71.383887  41.693683 -0.002045      bullish  0.128339    bullish
# 677    5.718331  35.118000 -0.048492      bearish  0.108826    bearish
# 678   25.486245  46.489302 -0.034496      bearish  0.108826    bearish
# 679   41.696290  42.446916 -0.020002      bearish  0.099221    bearish
# 680   70.059657  45.414178  0.010186      bullish  0.095437    bullish
#
#     candle_dir dt_signal  sent_signal  simple_result running_result  profit  \
# 665       long      long   long_trade            win            win   0.170
# 666      short     short  short_trade            win            win   0.170
# 667      short     short  short_trade           loss      no_runner  -0.080
# 668      short     short  short_trade           loss      no_runner  -0.087
# 669      short     short  short_trade       sig_stop      no_runner  -0.030
# 670      short     short  short_trade       sig_stop      no_runner  -0.002
# 671      short     short  short_trade       sig_stop      no_runner  -0.025
# 672      short     short  short_trade       sig_stop      no_runner  -0.045
# 673      short     short  short_trade  running_short            win   0.070
# 674      short     short  short_trade  running_short       sig_stop  -0.011
# 675      short     short  short_trade       sig_stop      no_runner  -0.038
# 676      short     short  short_trade            win            win   0.170
# 677       long      long   long_trade            win            win   0.170
# 678       long      long   long_trade   running_long       sig_stop   0.039
# 679       long      long   long_trade   running_long       sig_stop   0.007
# 680      short     short  short_trade       sig_stop      no_runner  -0.118
#
#      ext_profit    no_sig_stop running_nosig  tuned_profit
# 665       0.301            win           win         0.301
# 666       0.144            win           win         0.144
# 667      -0.080           loss     no_runner        -0.080
# 668      -0.087           loss     no_runner        -0.087
# 669      -0.030  running_short          loss        -0.072
# 670      -0.002  running_short          loss        -0.033
# 671      -0.025  running_short          loss        -0.114
# 672      -0.045  running_short          loss        -0.172
# 673       0.070  running_short           win         0.467
# 674      -0.011  running_short          loss        -0.093
# 675      -0.038  running_short          loss        -0.092
# 676       0.254            win           win         0.254
# 677       0.200            win           win         0.200
# 678       0.039   running_long           win         0.124
# 679       0.007   running_long          loss        -0.059
# 680      -0.118  running_short          loss        -0.209

# %%
thirtyB[thirtyB.tuned_profit<=0]
# Out:
#                      time     open     high      low    close  fast_stoch  \
# 2     2019-01-07 18:30:00  138.802  138.824  138.532  138.622   86.898499
# 3     2019-01-07 20:30:00  138.829  138.874  138.762  138.816   88.437094
# 4     2019-01-07 23:00:00  138.926  138.966  138.878  138.887   90.241474
# 10    2019-01-09 03:00:00  138.708  138.774  138.673  138.704   81.652014
# 14    2019-01-09 12:00:00  138.702  138.728  138.614  138.696   22.462567
# ...                   ...      ...      ...      ...      ...         ...
# 2564  2020-08-13 09:00:00  139.692  139.743  139.628  139.662   85.030630
# 2565  2020-08-13 11:30:00  140.076  140.164  140.024  140.066   85.201818
# 2568  2020-08-14 01:30:00  139.653  139.720  139.618  139.664   43.062606
# 2569  2020-08-14 03:30:00  139.596  139.653  139.592  139.617   18.868069
# 2570  2020-08-14 05:00:00  139.573  139.618  139.562  139.615   12.974052
#
#       slow_stoch        rsi   30_sent thirty_trend   4h_sent four_trend  \
# 2      91.325175  61.871256  0.022497      bullish  0.167150    bullish
# 3      81.676800  66.758711  0.021740      bullish  0.167150    bullish
# 4      91.861208  67.107538  0.019568      bullish  0.183445    bullish
# 10     86.384929  61.318828  0.016403      bullish  0.200412    bullish
# 14     16.048574  51.003854  0.005486      bullish  0.196126    bullish
# ...          ...        ...       ...          ...       ...        ...
# 2564   82.990430  68.041436  0.014273      bullish  0.020513    bullish
# 2565   90.062279  80.396909  0.044657      bullish  0.020513    bullish
# 2568   54.653130  45.154066 -0.023564      bearish  0.014485    bearish
# 2569   25.480404  42.865134 -0.028536      bearish  0.014485    bearish
# 2570   13.872255  43.995929 -0.028545      bearish  0.007972    bearish
#
#      candle_dir dt_signal  sent_signal  simple_result running_result  profit  \
# 2         short     short  short_trade  running_short       sig_stop  -0.059
# 3         short     short  short_trade  running_short           loss  -0.078
# 4         short     short  short_trade       sig_stop      no_runner  -0.001
# 10        short     short  short_trade  running_short       sig_stop   0.000
# 14        short     short  short_trade           loss      no_runner  -0.052
# ...         ...       ...          ...            ...            ...     ...
# 2564      short     short  short_trade           loss      no_runner  -0.101
# 2565      short     short  short_trade  running_short           loss  -0.118
# 2568       long      long   long_trade       sig_stop      no_runner  -0.030
# 2569       long      long   long_trade   running_long           loss  -0.045
# 2570       long      long   long_trade   running_long           loss  -0.073
#
#       ext_profit    no_sig_stop running_nosig  tuned_profit
# 2         -0.059  running_short          loss        -0.222
# 3         -0.078  running_short          loss        -0.078
# 4         -0.001  running_short          loss        -0.099
# 10         0.000  running_short          loss        -0.090
# 14        -0.052           loss     no_runner        -0.052
# ...          ...            ...           ...           ...
# 2564      -0.101           loss     no_runner        -0.101
# 2565      -0.118  running_short          loss        -0.118
# 2568      -0.030   running_long          loss        -0.066
# 2569      -0.045   running_long          loss        -0.045
# 2570      -0.073   running_long          loss        -0.073
#
# [1349 rows x 22 columns]

# %%
thirtyB.tuned_profit
# Out:
# -0.07800000000000296

# %%
date_list = []
date = []
size = []
size_list = []
for i, (j, k) in enumerate(zip(thirtyB.tuned_profit, thirtyB.time)):
    if j <= 0.00:
        size_list.append(j)
    elif j > 0.00 and len(size_list) > 0:
#         print(len(size_list), k, j)
        size.append(len(size_list))
        size_list = []
        
print(max(size))
        
            
# for i in size:
#     if i > 10:
#         print(i)
#     else:
#         continue
# Out:
# 21

# %%
thirtyB[thirtyB.time == '2019-01-28 06:00:00']
# Out:
#                     time     open    high      low    close  fast_stoch  \
# 101  2019-01-28 06:00:00  144.201  144.28  144.192  144.231   16.617456
#
#      slow_stoch        rsi   30_sent thirty_trend  4h_sent four_trend  \
# 101   26.464592  44.674705 -0.046322      bearish  0.09207    bearish
#
#     candle_dir dt_signal sent_signal simple_result running_result  profit  \
# 101       long      long  long_trade          loss      no_runner  -0.059
#
#      ext_profit no_sig_stop running_nosig  tuned_profit
# 101      -0.059        loss     no_runner        -0.059

# %%
thirtyB[80:105]
# Out:
#                     time     open     high      low    close  fast_stoch  \
# 80   2019-01-22 14:00:00  141.423  141.434  141.306  141.352   78.377386
# 81   2019-01-22 16:00:00  141.782  141.884  141.724  141.735   87.048882
# 82   2019-01-22 17:30:00  141.800  141.843  141.728  141.729   77.141788
# 83   2019-01-22 19:00:00  141.714  141.736  141.610  141.612   66.518871
# 84   2019-01-22 21:00:00  141.716  141.772  141.692  141.713   64.251447
# 85   2019-01-22 22:30:00  141.714  141.750  141.644  141.679   56.786800
# 86   2019-01-23 00:30:00  141.758  141.804  141.738  141.754   74.634290
# 87   2019-01-23 15:00:00  143.409  143.500  143.316  143.360   93.188466
# 88   2019-01-23 19:30:00  143.194  143.208  143.131  143.176   47.520228
# 89   2019-01-23 21:00:00  143.288  143.291  143.178  143.182   45.763498
# 90   2019-01-24 14:00:00  142.824  143.006  142.806  142.856   25.136991
# 91   2019-01-24 16:30:00  142.832  143.012  142.822  142.928   32.189156
# 92   2019-01-24 18:00:00  142.764  142.903  142.729  142.882   23.643948
# 93   2019-01-24 21:30:00  143.118  143.234  143.117  143.234   82.095238
# 94   2019-01-25 04:30:00  144.116  144.134  143.946  143.946   87.619739
# 95   2019-01-25 05:30:00  144.170  144.230  144.118  144.140   88.852133
# 96   2019-01-25 19:00:00  144.783  144.846  144.592  144.601   91.214069
# 97   2019-01-25 20:00:00  144.696  144.732  144.659  144.668   82.298424
# 98   2019-01-25 21:00:00  144.704  144.748  144.494  144.524   79.591428
# 99   2019-01-27 22:30:00  144.733  144.733  144.659  144.684   78.641068
# 100  2019-01-28 03:00:00  144.262  144.331  144.204  144.327   15.805499
# 101  2019-01-28 06:00:00  144.201  144.280  144.192  144.231   16.617456
# 102  2019-01-28 09:30:00  143.858  144.006  143.830  143.950    9.587700
# 103  2019-01-28 12:00:00  143.912  144.057  143.892  144.032   35.074403
# 104  2019-01-28 13:30:00  143.922  144.110  143.842  144.046   33.443266
#
#      slow_stoch        rsi   30_sent thirty_trend   4h_sent four_trend  \
# 80    69.273128  57.248848  0.019911      bullish  0.030417    bullish
# 81    89.625994  66.844718  0.049163      bullish  0.030417    bullish
# 82    77.137667  63.305487  0.055003      bullish  0.030417    bullish
# 83    71.025491  56.540206  0.045317      bullish  0.030797    bullish
# 84    63.246865  59.886074  0.034891      bullish  0.030797    bullish
# 85    61.198876  57.521270  0.026291      bullish  0.038404    bullish
# 86    66.635869  60.736448  0.018095      bullish  0.038404    bullish
# 87    95.382710  78.921810  0.083912      bullish  0.095682    bullish
# 88    48.335264  65.722125  0.022018      bullish  0.110884    bullish
# 89    46.354646  62.445534  0.009125      bullish  0.110884    bullish
# 90    21.133739  40.557952 -0.064201      bearish  0.090044    bearish
# 91    36.967047  46.466287 -0.052777      bearish  0.090044    bearish
# 92    24.265816  46.130111 -0.050521      bearish  0.086946    bearish
# 93    81.608098  59.909025 -0.007387      bearish  0.086946    bearish
# 94    91.744357  67.004461  0.066081      bullish  0.110409    bullish
# 95    88.600082  70.594601  0.066737      bullish  0.110409    bullish
# 96    94.993991  66.133318  0.048079      bullish  0.125657    bullish
# 97    86.960173  66.929127  0.046433      bullish  0.125657    bullish
# 98    82.456745  59.351951  0.037203      bullish  0.125657    bullish
# 99    76.907385  62.809025  0.027343      bullish  0.122839    bullish
# 100   16.577267  48.778459 -0.036970      bearish  0.111384    bearish
# 101   26.464592  44.674705 -0.046322      bearish  0.092070    bearish
# 102    8.427744  37.319366 -0.071173      bearish  0.092070    bearish
# 103   41.296275  44.609353 -0.054019      bearish  0.076324    bearish
# 104   28.627981  46.678052 -0.049963      bearish  0.076324    bearish
#
#     candle_dir dt_signal  sent_signal  simple_result running_result  profit  \
# 80       short     short  short_trade           loss      no_runner  -0.102
# 81       short     short  short_trade            win            win   0.170
# 82       short     short  short_trade            win            win   0.170
# 83       short     short  short_trade       sig_stop      no_runner  -0.019
# 84       short     short  short_trade  running_short           loss  -0.079
# 85       short     short  short_trade       sig_stop      no_runner  -0.018
# 86       short     short  short_trade           loss      no_runner  -0.070
# 87       short     short  short_trade           loss      no_runner  -0.160
# 88       short     short  short_trade  running_short           loss  -0.052
# 89       short     short  short_trade       sig_stop      no_runner  -0.064
# 90        long      long   long_trade           loss      no_runner  -0.070
# 91        long      long   long_trade           loss      no_runner  -0.126
# 92        long      long   long_trade   running_long            win   0.070
# 93        long      long   long_trade       sig_stop      no_runner  -0.067
# 94       short     short  short_trade           loss      no_runner  -0.208
# 95       short     short  short_trade            win            win   0.170
# 96       short     short  short_trade       sig_stop      no_runner  -0.095
# 97       short     short  short_trade       sig_stop      no_runner  -0.036
# 98       short     short  short_trade       sig_stop      no_runner  -0.058
# 99       short     short  short_trade  running_short            win   0.070
# 100       long      long   long_trade   running_long            win   0.070
# 101       long      long   long_trade           loss      no_runner  -0.059
# 102       long      long   long_trade            win            win   0.170
# 103       long      long   long_trade       sig_stop      no_runner  -0.103
# 104       long      long   long_trade           loss      no_runner  -0.224
#
#      ext_profit    no_sig_stop running_nosig  tuned_profit
# 80       -0.102           loss     no_runner        -0.102
# 81        0.283            win           win         0.283
# 82        0.277            win           win         0.277
# 83       -0.019  running_short          loss        -0.144
# 84       -0.079  running_short          loss        -0.079
# 85       -0.018  running_short          loss        -0.091
# 86       -0.070           loss     no_runner        -0.070
# 87       -0.160           loss     no_runner        -0.160
# 88       -0.052  running_short          loss        -0.052
# 89       -0.064  running_short          loss        -0.129
# 90       -0.070           loss     no_runner        -0.070
# 91       -0.126           loss     no_runner        -0.126
# 92        0.070   running_long           win         0.372
# 93       -0.067   running_long          loss        -0.137
# 94       -0.208           loss     no_runner        -0.208
# 95        0.598            win           win         0.598
# 96       -0.095  running_short           win         0.115
# 97       -0.036  running_short          loss        -0.084
# 98       -0.058  running_short        runner         0.000
# 99        0.070  running_short           win         0.452
# 100       0.070   running_long           win         0.165
# 101      -0.059           loss     no_runner        -0.059
# 102       0.360            win           win         0.360
# 103      -0.103   running_long          loss        -0.160
# 104      -0.224           loss     no_runner        -0.224

# %%
lst = [3, 6, 8, 5, 6, 2]

# %%
lst1 = lst[:: -1]

# %%
lst1
# Out:
# [2, 6, 5, 8, 6, 3]
